# %% [markdown]
# # Derive Spatial Maps

# %% [markdown]
# ## Load Data

# %%
from os import listdir, makedirs
from os.path import isfile, join, exists

from nilearn.image import concat_imgs
from nilearn.decomposition import CanICA
from nilearn.decomposition import DictLearning
from nilearn.plotting import plot_prob_atlas

# %%
aa_folder = 'BioBank_Analysis_All/'
saveresids_folder = 'aamod_firstlevel_modelestimate_saveresids_00001/'

# %% [markdown]
# ## Train both models (ICA and DictLearning)

# %%
canica = CanICA(n_components=20,
                memory="nilearn_cache", memory_level=2,
                verbose=1,
                mask_strategy='template',
                random_state=0)

# %%
for age in range(7, 16):
    print("Processing age:", age)
    age_dir = f'/imaging3/owenlab/wilson/MovieData/Release7/Age{age}'

    input_path = join(age_dir, aa_folder, saveresids_folder)

    # Grab all subjects
    subjects = [folder for folder in listdir(input_path) if folder.startswith("sub-")]

    for subject in subjects:
        subject_input_path = join(input_path, subject)
        subject_niftis = [join(subject_input_path, f) for f in listdir(subject_input_path) 
                          if isfile(join(subject_input_path, f)) and f.startswith('ResI')]

        if len(subject_niftis) != 745:
            print("Incomplete subject niftis:", len(subject_niftis))
            continue
        
        subject_4d_nifti = concat_imgs(subject_niftis)
        canica.fit(subject_4d_nifti)
# Out:
# Processing age: 7
# [MultiNiftiMasker.fit] Loading data from [Nifti1Image(
# shape=(79, 95, 68, 745),
# affine=array([[  -2.,    0.,    0.,   78.],
#        [   0.,    2.,    0., -112.],
#        [   0.,    0.,    2.,  -50.],
#        [   0.,    0.,    0.,    1.]])
# )]
# [MultiNiftiMasker.fit] Computing mask
# [MultiNiftiMasker.transform] Resampling mask
# [CanICA] Loading data
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image(
# shape=(79, 95, 68, 745),
# affine=array([[  -2.,    0.,    0.,   78.],
#        [   0.,    2.,    0., -112.],
#        [   0.,    0.,    2.,  -50.],
#        [   0.,    0.,    0.,    1.]])
# )
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# /home/bpho/.conda/envs/venv/lib/python3.7/site-packages/nilearn/input_data/nifti_masker.py:408: UserWarning: Persisting input arguments took 3.49s to run.
# If this happens often in your code, it can cause performance problems
# (results will be correct in all cases).
# The reason for this is probably some large input arguments for a wrapped
#  function (e.g. large strings).
# THIS IS A JOBLIB ISSUE. If you can, kindly provide the joblib's team with an
#  example so that they can fix the problem.
#   dtype=self.dtype
# /home/bpho/.conda/envs/venv/lib/python3.7/site-packages/nilearn/decomposition/base.py:223: UserWarning: Persisting input arguments took 0.77s to run.
# If this happens often in your code, it can cause performance problems
# (results will be correct in all cases).
# The reason for this is probably some large input arguments for a wrapped
#  function (e.g. large strings).
# THIS IS A JOBLIB ISSUE. If you can, kindly provide the joblib's team with an
#  example so that they can fix the problem.
#   random_state=random_state)
# ________________________________________________________________________________
# [Memory] Calling sklearn.utils.extmath.randomized_svd...
# randomized_svd(array([[-3.326410e-04, ...,  1.664966e-03],
#        ...,
#        [-8.953680e-05, ..., -1.574800e-03]], dtype=float32), n_components=20, transpose=True, random_state=0, n_iter=3)
# ___________________________________________________randomized_svd - 0.6s, 0.0min
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# ________________________________________________________________________________
# [Memory] Calling sklearn.decomposition._fastica.fastica...
# fastica(array([[0.001273, ..., 0.002765],
#        ...,
#        [0.003328, ..., 0.003424]]), whiten=True, fun='cube', random_state=209652396)
# /home/bpho/.conda/envs/venv/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:120: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   ConvergenceWarning)
# _________________________________________________________fastica - 23.0s, 0.4min
# ________________________________________________________________________________
# [Memory] Calling sklearn.decomposition._fastica.fastica...
# fastica(array([[0.001273, ..., 0.002765],
#        ...,
#        [0.003328, ..., 0.003424]]), whiten=True, fun='cube', random_state=398764591)
# /home/bpho/.conda/envs/venv/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:120: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   ConvergenceWarning)
# _________________________________________________________fastica - 26.8s, 0.4min
# ________________________________________________________________________________
# [Memory] Calling sklearn.decomposition._fastica.fastica...
# fastica(array([[0.001273, ..., 0.002765],
#        ...,
#        [0.003328, ..., 0.003424]]), whiten=True, fun='cube', random_state=924231285)
# /home/bpho/.conda/envs/venv/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:120: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   ConvergenceWarning)
# _________________________________________________________fastica - 25.5s, 0.4min
# ________________________________________________________________________________
# [Memory] Calling sklearn.decomposition._fastica.fastica...
# fastica(array([[0.001273, ..., 0.002765],
#        ...,
#        [0.003328, ..., 0.003424]]), whiten=True, fun='cube', random_state=1478610112)
# /home/bpho/.conda/envs/venv/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:120: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   ConvergenceWarning)
# _________________________________________________________fastica - 20.2s, 0.3min
# ________________________________________________________________________________
# [Memory] Calling sklearn.decomposition._fastica.fastica...
# fastica(array([[0.001273, ..., 0.002765],
#        ...,
#        [0.003328, ..., 0.003424]]), whiten=True, fun='cube', random_state=441365315)
# /home/bpho/.conda/envs/venv/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:120: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   ConvergenceWarning)
# _________________________________________________________fastica - 20.6s, 0.3min
# ________________________________________________________________________________
# [Memory] Calling sklearn.decomposition._fastica.fastica...
# fastica(array([[0.001273, ..., 0.002765],
#        ...,
#        [0.003328, ..., 0.003424]]), whiten=True, fun='cube', random_state=1537364731)
# /home/bpho/.conda/envs/venv/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:120: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   ConvergenceWarning)
# _________________________________________________________fastica - 20.4s, 0.3min
# ________________________________________________________________________________
# [Memory] Calling sklearn.decomposition._fastica.fastica...
# fastica(array([[0.001273, ..., 0.002765],
#        ...,
#        [0.003328, ..., 0.003424]]), whiten=True, fun='cube', random_state=192771779)
# /home/bpho/.conda/envs/venv/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:120: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   ConvergenceWarning)
# _________________________________________________________fastica - 20.2s, 0.3min
# ________________________________________________________________________________
# [Memory] Calling sklearn.decomposition._fastica.fastica...
# fastica(array([[0.001273, ..., 0.002765],
#        ...,
#        [0.003328, ..., 0.003424]]), whiten=True, fun='cube', random_state=1491434855)
# /home/bpho/.conda/envs/venv/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:120: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   ConvergenceWarning)
# _________________________________________________________fastica - 20.3s, 0.3min
# ________________________________________________________________________________
# [Memory] Calling sklearn.decomposition._fastica.fastica...
# fastica(array([[0.001273, ..., 0.002765],
#        ...,
#        [0.003328, ..., 0.003424]]), whiten=True, fun='cube', random_state=1819583497)
# /home/bpho/.conda/envs/venv/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:120: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   ConvergenceWarning)
# _________________________________________________________fastica - 22.3s, 0.4min
# ________________________________________________________________________________
# [Memory] Calling sklearn.decomposition._fastica.fastica...
# fastica(array([[0.001273, ..., 0.002765],
#        ...,
#        [0.003328, ..., 0.003424]]), whiten=True, fun='cube', random_state=530702035)
# /home/bpho/.conda/envs/venv/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:120: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   ConvergenceWarning)
# _________________________________________________________fastica - 28.6s, 0.5min
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:  3.8min finished
# [MultiNiftiMasker.fit] Loading data from [Nifti1Image(
# shape=(79, 95, 68, 745),
# affine=array([[  -2.,    0.,    0.,   78.],
#        [   0.,    2.,    0., -112.],
#        [   0.,    0.,    2.,  -50.],
#        [   0.,    0.,    0.,    1.]])
# )]
# [MultiNiftiMasker.fit] Computing mask
# ________________________________________________________________________________
# [Memory] Calling nilearn.masking.compute_multi_gray_matter_mask...
# compute_multi_gray_matter_mask([<nibabel.nifti1.Nifti1Image object at 0x7fba66aa39d0>], target_affine=None, target_shape=None, n_jobs=1, memory=Memory(location=nilearn_cache/joblib), verbose=0)
# ________________________________________________________________________________
# [Memory] Calling nilearn.image.resampling.resample_to_img...
# resample_to_img(<nibabel.nifti1.Nifti1Image object at 0x7fba974e7ed0>, <nibabel.nifti1.Nifti1Image object at 0x7fba66aa39d0>)
# /home/bpho/.conda/envs/venv/lib/python3.7/site-packages/nilearn/masking.py:627: UserWarning: Persisting input arguments took 3.46s to run.
# If this happens often in your code, it can cause performance problems
# (results will be correct in all cases).
# The reason for this is probably some large input arguments for a wrapped
#  function (e.g. large strings).
# THIS IS A JOBLIB ISSUE. If you can, kindly provide the joblib's team with an
#  example so that they can fix the problem.
#   resampled_template = cache(resample_to_img, memory)(template, target_img)
# __________________________________________________resample_to_img - 3.5s, 0.1min
# /home/bpho/.conda/envs/venv/lib/python3.7/site-packages/nilearn/input_data/multi_nifti_masker.py:207: UserWarning: Persisting input arguments took 3.48s to run.
# If this happens often in your code, it can cause performance problems
# (results will be correct in all cases).
# The reason for this is probably some large input arguments for a wrapped
#  function (e.g. large strings).
# THIS IS A JOBLIB ISSUE. If you can, kindly provide the joblib's team with an
#  example so that they can fix the problem.
#   **mask_args)
# __________________________________compute_multi_gray_matter_mask - 12.2s, 0.2min
# [MultiNiftiMasker.transform] Resampling mask
# [CanICA] Loading data
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.nifti_masker.filter_and_mask...
# filter_and_mask(<nibabel.nifti1.Nifti1Image object at 0x7fba66aa39d0>, <nibabel.nifti1.Nifti1Image object at 0x7fba974ea410>, { 'detrend': True,
#   'dtype': None,
#   'high_pass': None,
#   'low_pass': None,
#   'smoothing_fwhm': 6,
#   'standardize': True,
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, memory_level=1, memory=Memory(location=nilearn_cache/joblib), verbose=1, confounds=None, copy=True, dtype=None)
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image(
# shape=(79, 95, 68, 745),
# affine=array([[  -2.,    0.,    0.,   78.],
#        [   0.,    2.,    0., -112.],
#        [   0.,    0.,    2.,  -50.],
#        [   0.,    0.,    0.,    1.]])
# )
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# /home/bpho/.conda/envs/venv/lib/python3.7/site-packages/nilearn/input_data/nifti_masker.py:408: UserWarning: Persisting input arguments took 3.46s to run.
# If this happens often in your code, it can cause performance problems
# (results will be correct in all cases).
# The reason for this is probably some large input arguments for a wrapped
#  function (e.g. large strings).
# THIS IS A JOBLIB ISSUE. If you can, kindly provide the joblib's team with an
#  example so that they can fix the problem.
#   dtype=self.dtype
# _________________________________________________filter_and_mask - 37.9s, 0.6min
# ________________________________________________________________________________
# [Memory] Calling nilearn.decomposition.base.fast_svd...
# fast_svd(array([[ 0.667519, ...,  1.162974],
#        ...,
#        [ 0.650994, ..., -0.825363]], dtype=float32),
# 20, random_state=RandomState(MT19937) at 0x7FBA65F069E0)
# /home/bpho/.conda/envs/venv/lib/python3.7/site-packages/nilearn/decomposition/base.py:223: UserWarning: Persisting input arguments took 0.78s to run.
# If this happens often in your code, it can cause performance problems
# (results will be correct in all cases).
# The reason for this is probably some large input arguments for a wrapped
#  function (e.g. large strings).
# THIS IS A JOBLIB ISSUE. If you can, kindly provide the joblib's team with an
#  example so that they can fix the problem.
#   random_state=random_state)
# _________________________________________________________fast_svd - 1.8s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.utils.extmath.randomized_svd...
# randomized_svd(array([[-0.000245, ...,  0.00315 ],
#        ...,
#        [-0.000831, ..., -0.001666]], dtype=float32), n_components=20, transpose=True, random_state=0, n_iter=3)
# ___________________________________________________randomized_svd - 0.5s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling nilearn.masking.unmask...
# unmask(array([[-0.000548, ...,  0.004495],
#        ...,
#        [-0.000895, ..., -0.001712]], dtype=float32),
# <nibabel.nifti1.Nifti1Image object at 0x7fba974ea410>)
# ___________________________________________________________unmask - 0.6s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.decomposition._fastica.fastica...
# fastica(array([[-0.000548, ..., -0.000895],
#        ...,
#        [ 0.004495, ..., -0.001712]]), whiten=True, fun='cube', random_state=209652396)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# /home/bpho/.conda/envs/venv/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:120: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   ConvergenceWarning)
# _________________________________________________________fastica - 34.5s, 0.6min
# ________________________________________________________________________________
# [Memory] Calling sklearn.decomposition._fastica.fastica...
# fastica(array([[-0.000548, ..., -0.000895],
#        ...,
#        [ 0.004495, ..., -0.001712]]), whiten=True, fun='cube', random_state=398764591)
# /home/bpho/.conda/envs/venv/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:120: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   ConvergenceWarning)
# _________________________________________________________fastica - 38.0s, 0.6min
# ________________________________________________________________________________
# [Memory] Calling sklearn.decomposition._fastica.fastica...
# fastica(array([[-0.000548, ..., -0.000895],
#        ...,
#        [ 0.004495, ..., -0.001712]]), whiten=True, fun='cube', random_state=924231285)
# /home/bpho/.conda/envs/venv/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:120: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   ConvergenceWarning)
# _________________________________________________________fastica - 35.9s, 0.6min
# ________________________________________________________________________________
# [Memory] Calling sklearn.decomposition._fastica.fastica...
# fastica(array([[-0.000548, ..., -0.000895],
#        ...,
#        [ 0.004495, ..., -0.001712]]), whiten=True, fun='cube', random_state=1478610112)
# __________________________________________________________fastica - 5.9s, 0.1min
# ________________________________________________________________________________
# [Memory] Calling sklearn.decomposition._fastica.fastica...
# fastica(array([[-0.000548, ..., -0.000895],
#        ...,
#        [ 0.004495, ..., -0.001712]]), whiten=True, fun='cube', random_state=441365315)
# __________________________________________________________fastica - 5.3s, 0.1min
# ________________________________________________________________________________
# [Memory] Calling sklearn.decomposition._fastica.fastica...
# fastica(array([[-0.000548, ..., -0.000895],
#        ...,
#        [ 0.004495, ..., -0.001712]]), whiten=True, fun='cube', random_state=1537364731)
# /home/bpho/.conda/envs/venv/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:120: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   ConvergenceWarning)
# _________________________________________________________fastica - 20.8s, 0.3min
# ________________________________________________________________________________
# [Memory] Calling sklearn.decomposition._fastica.fastica...
# fastica(array([[-0.000548, ..., -0.000895],
#        ...,
#        [ 0.004495, ..., -0.001712]]), whiten=True, fun='cube', random_state=192771779)
# /home/bpho/.conda/envs/venv/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:120: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   ConvergenceWarning)
# _________________________________________________________fastica - 20.7s, 0.3min
# ________________________________________________________________________________
# [Memory] Calling sklearn.decomposition._fastica.fastica...
# fastica(array([[-0.000548, ..., -0.000895],
#        ...,
#        [ 0.004495, ..., -0.001712]]), whiten=True, fun='cube', random_state=1491434855)
# /home/bpho/.conda/envs/venv/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:120: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   ConvergenceWarning)
# _________________________________________________________fastica - 20.9s, 0.3min
# ________________________________________________________________________________
# [Memory] Calling sklearn.decomposition._fastica.fastica...
# fastica(array([[-0.000548, ..., -0.000895],
#        ...,
#        [ 0.004495, ..., -0.001712]]), whiten=True, fun='cube', random_state=1819583497)
# /home/bpho/.conda/envs/venv/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:120: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   ConvergenceWarning)
# _________________________________________________________fastica - 20.3s, 0.3min
# ________________________________________________________________________________
# [Memory] Calling sklearn.decomposition._fastica.fastica...
# fastica(array([[-0.000548, ..., -0.000895],
#        ...,
#        [ 0.004495, ..., -0.001712]]), whiten=True, fun='cube', random_state=530702035)
# /home/bpho/.conda/envs/venv/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:120: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   ConvergenceWarning)
# _________________________________________________________fastica - 23.4s, 0.4min
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:  3.8min finished
# ________________________________________________________________________________
# [Memory] Calling nilearn.masking.unmask...
# unmask(array([[ 0., ...,  0.],
#        ...,
#        [-0., ..., -0.]], dtype=float32), <nibabel.nifti1.Nifti1Image object at 0x7fba974ea410>)
# ___________________________________________________________unmask - 0.6s, 0.0min
# [MultiNiftiMasker.fit] Loading data from [Nifti1Image(
# shape=(79, 95, 68, 745),
# affine=array([[  -2.,    0.,    0.,   78.],
#        [   0.,    2.,    0., -112.],
#        [   0.,    0.,    2.,  -50.],
#        [   0.,    0.,    0.,    1.]])
# )]
# [MultiNiftiMasker.fit] Computing mask
# ________________________________________________________________________________
# [Memory] Calling nilearn.masking.compute_multi_gray_matter_mask...
# compute_multi_gray_matter_mask([<nibabel.nifti1.Nifti1Image object at 0x7fba66aa3890>], target_affine=None, target_shape=None, n_jobs=1, memory=Memory(location=nilearn_cache/joblib), verbose=0)
# ________________________________________________________________________________
# [Memory] Calling nilearn.image.resampling.resample_to_img...
# resample_to_img(<nibabel.nifti1.Nifti1Image object at 0x7fba65b5c9d0>, <nibabel.nifti1.Nifti1Image object at 0x7fba66aa3890>)
# /home/bpho/.conda/envs/venv/lib/python3.7/site-packages/nilearn/masking.py:627: UserWarning: Persisting input arguments took 3.50s to run.
# If this happens often in your code, it can cause performance problems
# (results will be correct in all cases).
# The reason for this is probably some large input arguments for a wrapped
#  function (e.g. large strings).
# THIS IS A JOBLIB ISSUE. If you can, kindly provide the joblib's team with an
#  example so that they can fix the problem.
#   resampled_template = cache(resample_to_img, memory)(template, target_img)
# __________________________________________________resample_to_img - 3.5s, 0.1min
# /home/bpho/.conda/envs/venv/lib/python3.7/site-packages/nilearn/input_data/multi_nifti_masker.py:207: UserWarning: Persisting input arguments took 3.47s to run.
# If this happens often in your code, it can cause performance problems
# (results will be correct in all cases).
# The reason for this is probably some large input arguments for a wrapped
#  function (e.g. large strings).
# THIS IS A JOBLIB ISSUE. If you can, kindly provide the joblib's team with an
#  example so that they can fix the problem.
#   **mask_args)
# __________________________________compute_multi_gray_matter_mask - 12.2s, 0.2min
# [MultiNiftiMasker.transform] Resampling mask
# [CanICA] Loading data
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.nifti_masker.filter_and_mask...
# filter_and_mask(<nibabel.nifti1.Nifti1Image object at 0x7fba66aa3890>, <nibabel.nifti1.Nifti1Image object at 0x7fba666e85d0>, { 'detrend': True,
#   'dtype': None,
#   'high_pass': None,
#   'low_pass': None,
#   'smoothing_fwhm': 6,
#   'standardize': True,
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, memory_level=1, memory=Memory(location=nilearn_cache/joblib), verbose=1, confounds=None, copy=True, dtype=None)
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image(
# shape=(79, 95, 68, 745),
# affine=array([[  -2.,    0.,    0.,   78.],
#        [   0.,    2.,    0., -112.],
#        [   0.,    0.,    2.,  -50.],
#        [   0.,    0.,    0.,    1.]])
# )
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# /home/bpho/.conda/envs/venv/lib/python3.7/site-packages/nilearn/input_data/nifti_masker.py:408: UserWarning: Persisting input arguments took 3.45s to run.
# If this happens often in your code, it can cause performance problems
# (results will be correct in all cases).
# The reason for this is probably some large input arguments for a wrapped
#  function (e.g. large strings).
# THIS IS A JOBLIB ISSUE. If you can, kindly provide the joblib's team with an
#  example so that they can fix the problem.
#   dtype=self.dtype
# _________________________________________________filter_and_mask - 41.1s, 0.7min
# ________________________________________________________________________________
# [Memory] Calling nilearn.decomposition.base.fast_svd...
# fast_svd(array([[ 0.441097, ...,  0.338971],
#        ...,
#        [-0.281643, ...,  0.185145]], dtype=float32),
# 20, random_state=RandomState(MT19937) at 0x7FBA65F069E0)
# /home/bpho/.conda/envs/venv/lib/python3.7/site-packages/nilearn/decomposition/base.py:223: UserWarning: Persisting input arguments took 0.76s to run.
# If this happens often in your code, it can cause performance problems
# (results will be correct in all cases).
# The reason for this is probably some large input arguments for a wrapped
#  function (e.g. large strings).
# THIS IS A JOBLIB ISSUE. If you can, kindly provide the joblib's team with an
#  example so that they can fix the problem.
#   random_state=random_state)
# _________________________________________________________fast_svd - 1.8s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.utils.extmath.randomized_svd...
# randomized_svd(array([[ 0.001416, ..., -0.000375],
#        ...,
#        [ 0.001548, ..., -0.005233]], dtype=float32), n_components=20, transpose=True, random_state=0, n_iter=3)
# ___________________________________________________randomized_svd - 0.6s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling nilearn.masking.unmask...
# unmask(array([[-0.000518, ..., -0.00073 ],
#        ...,
#        [ 0.002812, ..., -0.00067 ]], dtype=float32),
# <nibabel.nifti1.Nifti1Image object at 0x7fba666e85d0>)
# ___________________________________________________________unmask - 0.6s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.decomposition._fastica.fastica...
# fastica(array([[-0.000518, ...,  0.002812],
#        ...,
#        [-0.00073 , ..., -0.00067 ]]), whiten=True, fun='cube', random_state=209652396)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# __________________________________________________________fastica - 8.0s, 0.1min
# ________________________________________________________________________________
# [Memory] Calling sklearn.decomposition._fastica.fastica...
# fastica(array([[-0.000518, ...,  0.002812],
#        ...,
#        [-0.00073 , ..., -0.00067 ]]), whiten=True, fun='cube', random_state=398764591)
# __________________________________________________________fastica - 5.8s, 0.1min
# ________________________________________________________________________________
# [Memory] Calling sklearn.decomposition._fastica.fastica...
# fastica(array([[-0.000518, ...,  0.002812],
#        ...,
#        [-0.00073 , ..., -0.00067 ]]), whiten=True, fun='cube', random_state=924231285)
# __________________________________________________________fastica - 4.3s, 0.1min
# ________________________________________________________________________________
# [Memory] Calling sklearn.decomposition._fastica.fastica...
# fastica(array([[-0.000518, ...,  0.002812],
#        ...,
#        [-0.00073 , ..., -0.00067 ]]), whiten=True, fun='cube', random_state=1478610112)
# _________________________________________________________fastica - 11.9s, 0.2min
# ________________________________________________________________________________
# [Memory] Calling sklearn.decomposition._fastica.fastica...
# fastica(array([[-0.000518, ...,  0.002812],
#        ...,
#        [-0.00073 , ..., -0.00067 ]]), whiten=True, fun='cube', random_state=441365315)
# _________________________________________________________fastica - 14.3s, 0.2min
# ________________________________________________________________________________
# [Memory] Calling sklearn.decomposition._fastica.fastica...
# fastica(array([[-0.000518, ...,  0.002812],
#        ...,
#        [-0.00073 , ..., -0.00067 ]]), whiten=True, fun='cube', random_state=1537364731)
# __________________________________________________________fastica - 7.7s, 0.1min
# ________________________________________________________________________________
# [Memory] Calling sklearn.decomposition._fastica.fastica...
# fastica(array([[-0.000518, ...,  0.002812],
#        ...,
#        [-0.00073 , ..., -0.00067 ]]), whiten=True, fun='cube', random_state=192771779)
# __________________________________________________________fastica - 8.7s, 0.1min
# ________________________________________________________________________________
# [Memory] Calling sklearn.decomposition._fastica.fastica...
# fastica(array([[-0.000518, ...,  0.002812],
#        ...,
#        [-0.00073 , ..., -0.00067 ]]), whiten=True, fun='cube', random_state=1491434855)
# __________________________________________________________fastica - 4.7s, 0.1min
# ________________________________________________________________________________
# [Memory] Calling sklearn.decomposition._fastica.fastica...
# fastica(array([[-0.000518, ...,  0.002812],
#        ...,
#        [-0.00073 , ..., -0.00067 ]]), whiten=True, fun='cube', random_state=1819583497)
# __________________________________________________________fastica - 6.0s, 0.1min
# ________________________________________________________________________________
# [Memory] Calling sklearn.decomposition._fastica.fastica...
# fastica(array([[-0.000518, ...,  0.002812],
#        ...,
#        [-0.00073 , ..., -0.00067 ]]), whiten=True, fun='cube', random_state=530702035)
# _________________________________________________________fastica - 12.1s, 0.2min
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:  1.4min finished
# ________________________________________________________________________________
# [Memory] Calling nilearn.masking.unmask...
# unmask(array([[ 0., ...,  0.],
#        ...,
#        [-0., ..., -0.]], dtype=float32), <nibabel.nifti1.Nifti1Image object at 0x7fba666e85d0>)
# ___________________________________________________________unmask - 0.6s, 0.0min
# Incomplete subject niftis: 0
# [MultiNiftiMasker.fit] Loading data from [Nifti1Image(
# shape=(79, 95, 68, 745),
# affine=array([[  -2.,    0.,    0.,   78.],
#        [   0.,    2.,    0., -112.],
#        [   0.,    0.,    2.,  -50.],
#        [   0.,    0.,    0.,    1.]])
# )]
# [MultiNiftiMasker.fit] Computing mask
# ________________________________________________________________________________
# [Memory] Calling nilearn.masking.compute_multi_gray_matter_mask...
# compute_multi_gray_matter_mask([<nibabel.nifti1.Nifti1Image object at 0x7fba9446de90>], target_affine=None, target_shape=None, n_jobs=1, memory=Memory(location=nilearn_cache/joblib), verbose=0)
# ________________________________________________________________________________
# [Memory] Calling nilearn.image.resampling.resample_to_img...
# resample_to_img(<nibabel.nifti1.Nifti1Image object at 0x7fba65d36f90>, <nibabel.nifti1.Nifti1Image object at 0x7fba9446de90>)
# /home/bpho/.conda/envs/venv/lib/python3.7/site-packages/nilearn/masking.py:627: UserWarning: Persisting input arguments took 3.45s to run.
# If this happens often in your code, it can cause performance problems
# (results will be correct in all cases).
# The reason for this is probably some large input arguments for a wrapped
#  function (e.g. large strings).
# THIS IS A JOBLIB ISSUE. If you can, kindly provide the joblib's team with an
#  example so that they can fix the problem.
#   resampled_template = cache(resample_to_img, memory)(template, target_img)
# __________________________________________________resample_to_img - 3.5s, 0.1min
# /home/bpho/.conda/envs/venv/lib/python3.7/site-packages/nilearn/input_data/multi_nifti_masker.py:207: UserWarning: Persisting input arguments took 3.46s to run.
# If this happens often in your code, it can cause performance problems
# (results will be correct in all cases).
# The reason for this is probably some large input arguments for a wrapped
#  function (e.g. large strings).
# THIS IS A JOBLIB ISSUE. If you can, kindly provide the joblib's team with an
#  example so that they can fix the problem.
#   **mask_args)
# __________________________________compute_multi_gray_matter_mask - 12.2s, 0.2min
# [MultiNiftiMasker.transform] Resampling mask
# [CanICA] Loading data
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.nifti_masker.filter_and_mask...
# filter_and_mask(<nibabel.nifti1.Nifti1Image object at 0x7fba9446de90>, <nibabel.nifti1.Nifti1Image object at 0x7fba65b5cf10>, { 'detrend': True,
#   'dtype': None,
#   'high_pass': None,
#   'low_pass': None,
#   'smoothing_fwhm': 6,
#   'standardize': True,
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, memory_level=1, memory=Memory(location=nilearn_cache/joblib), verbose=1, confounds=None, copy=True, dtype=None)
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image(
# shape=(79, 95, 68, 745),
# affine=array([[  -2.,    0.,    0.,   78.],
#        [   0.,    2.,    0., -112.],
#        [   0.,    0.,    2.,  -50.],
#        [   0.,    0.,    0.,    1.]])
# )
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# /home/bpho/.conda/envs/venv/lib/python3.7/site-packages/nilearn/input_data/nifti_masker.py:408: UserWarning: Persisting input arguments took 3.46s to run.
# If this happens often in your code, it can cause performance problems
# (results will be correct in all cases).
# The reason for this is probably some large input arguments for a wrapped
#  function (e.g. large strings).
# THIS IS A JOBLIB ISSUE. If you can, kindly provide the joblib's team with an
#  example so that they can fix the problem.
#   dtype=self.dtype
# _________________________________________________filter_and_mask - 39.3s, 0.7min
# ________________________________________________________________________________
# [Memory] Calling nilearn.decomposition.base.fast_svd...
# fast_svd(array([[ 0.798236, ..., -1.10404 ],
#        ...,
#        [ 0.682772, ..., -0.878607]], dtype=float32),
# 20, random_state=RandomState(MT19937) at 0x7FBA65F069E0)
# /home/bpho/.conda/envs/venv/lib/python3.7/site-packages/nilearn/decomposition/base.py:223: UserWarning: Persisting input arguments took 0.76s to run.
# If this happens often in your code, it can cause performance problems
# (results will be correct in all cases).
# The reason for this is probably some large input arguments for a wrapped
#  function (e.g. large strings).
# THIS IS A JOBLIB ISSUE. If you can, kindly provide the joblib's team with an
#  example so that they can fix the problem.
#   random_state=random_state)
# _________________________________________________________fast_svd - 1.9s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.utils.extmath.randomized_svd...
# randomized_svd(array([[ 0.001997, ...,  0.000368],
#        ...,
#        [ 0.002788, ..., -0.001097]], dtype=float32), n_components=20, transpose=True, random_state=0, n_iter=3)
# ___________________________________________________randomized_svd - 0.6s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling nilearn.masking.unmask...
# unmask(array([[-0.001775, ..., -0.000609],
#        ...,
#        [ 0.002783, ...,  0.001166]], dtype=float32),
# <nibabel.nifti1.Nifti1Image object at 0x7fba65b5cf10>)
# ___________________________________________________________unmask - 0.6s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.decomposition._fastica.fastica...
# fastica(array([[-0.001775, ...,  0.002783],
#        ...,
#        [-0.000609, ...,  0.001166]]), whiten=True, fun='cube', random_state=209652396)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# /home/bpho/.conda/envs/venv/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:120: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   ConvergenceWarning)
# _________________________________________________________fastica - 20.8s, 0.3min
# ________________________________________________________________________________
# [Memory] Calling sklearn.decomposition._fastica.fastica...
# fastica(array([[-0.001775, ...,  0.002783],
#        ...,
#        [-0.000609, ...,  0.001166]]), whiten=True, fun='cube', random_state=398764591)
# /home/bpho/.conda/envs/venv/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:120: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   ConvergenceWarning)
# _________________________________________________________fastica - 20.7s, 0.3min
# ________________________________________________________________________________
# [Memory] Calling sklearn.decomposition._fastica.fastica...
# fastica(array([[-0.001775, ...,  0.002783],
#        ...,
#        [-0.000609, ...,  0.001166]]), whiten=True, fun='cube', random_state=924231285)
# /home/bpho/.conda/envs/venv/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:120: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   ConvergenceWarning)
# _________________________________________________________fastica - 20.5s, 0.3min
# ________________________________________________________________________________
# [Memory] Calling sklearn.decomposition._fastica.fastica...
# fastica(array([[-0.001775, ...,  0.002783],
#        ...,
#        [-0.000609, ...,  0.001166]]), whiten=True, fun='cube', random_state=1478610112)
# /home/bpho/.conda/envs/venv/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:120: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   ConvergenceWarning)
# _________________________________________________________fastica - 20.5s, 0.3min
# ________________________________________________________________________________
# [Memory] Calling sklearn.decomposition._fastica.fastica...
# fastica(array([[-0.001775, ...,  0.002783],
#        ...,
#        [-0.000609, ...,  0.001166]]), whiten=True, fun='cube', random_state=441365315)
# /home/bpho/.conda/envs/venv/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:120: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   ConvergenceWarning)
# _________________________________________________________fastica - 20.3s, 0.3min
# ________________________________________________________________________________
# [Memory] Calling sklearn.decomposition._fastica.fastica...
# fastica(array([[-0.001775, ...,  0.002783],
#        ...,
#        [-0.000609, ...,  0.001166]]), whiten=True, fun='cube', random_state=1537364731)
# /home/bpho/.conda/envs/venv/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:120: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   ConvergenceWarning)
# _________________________________________________________fastica - 20.4s, 0.3min
# ________________________________________________________________________________
# [Memory] Calling sklearn.decomposition._fastica.fastica...
# fastica(array([[-0.001775, ...,  0.002783],
#        ...,
#        [-0.000609, ...,  0.001166]]), whiten=True, fun='cube', random_state=192771779)
# /home/bpho/.conda/envs/venv/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:120: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   ConvergenceWarning)
# _________________________________________________________fastica - 20.5s, 0.3min
# ________________________________________________________________________________
# [Memory] Calling sklearn.decomposition._fastica.fastica...
# fastica(array([[-0.001775, ...,  0.002783],
#        ...,
#        [-0.000609, ...,  0.001166]]), whiten=True, fun='cube', random_state=1491434855)
# /home/bpho/.conda/envs/venv/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:120: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   ConvergenceWarning)
# _________________________________________________________fastica - 20.2s, 0.3min
# ________________________________________________________________________________
# [Memory] Calling sklearn.decomposition._fastica.fastica...
# fastica(array([[-0.001775, ...,  0.002783],
#        ...,
#        [-0.000609, ...,  0.001166]]), whiten=True, fun='cube', random_state=1819583497)
# /home/bpho/.conda/envs/venv/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:120: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   ConvergenceWarning)
# _________________________________________________________fastica - 20.3s, 0.3min
# ________________________________________________________________________________
# [Memory] Calling sklearn.decomposition._fastica.fastica...
# fastica(array([[-0.001775, ...,  0.002783],
#        ...,
#        [-0.000609, ...,  0.001166]]), whiten=True, fun='cube', random_state=530702035)
# /home/bpho/.conda/envs/venv/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:120: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   ConvergenceWarning)
# _________________________________________________________fastica - 21.0s, 0.4min
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:  3.4min finished
# ________________________________________________________________________________
# [Memory] Calling nilearn.masking.unmask...
# unmask(array([[-0., ..., -0.],
#        ...,
#        [ 0., ...,  0.]], dtype=float32), <nibabel.nifti1.Nifti1Image object at 0x7fba65b5cf10>)
# ___________________________________________________________unmask - 0.6s, 0.0min
# Incomplete subject niftis: 0
# [MultiNiftiMasker.fit] Loading data from [Nifti1Image(
# shape=(79, 95, 68, 745),
# affine=array([[  -2.,    0.,    0.,   78.],
#        [   0.,    2.,    0., -112.],
#        [   0.,    0.,    2.,  -50.],
#        [   0.,    0.,    0.,    1.]])
# )]
# [MultiNiftiMasker.fit] Computing mask
# ________________________________________________________________________________
# [Memory] Calling nilearn.masking.compute_multi_gray_matter_mask...
# compute_multi_gray_matter_mask([<nibabel.nifti1.Nifti1Image object at 0x7fba65b5c950>], target_affine=None, target_shape=None, n_jobs=1, memory=Memory(location=nilearn_cache/joblib), verbose=0)
# ________________________________________________________________________________
# [Memory] Calling nilearn.image.resampling.resample_to_img...
# resample_to_img(<nibabel.nifti1.Nifti1Image object at 0x7fba65b5cad0>, <nibabel.nifti1.Nifti1Image object at 0x7fba65b5c950>)
# /home/bpho/.conda/envs/venv/lib/python3.7/site-packages/nilearn/masking.py:627: UserWarning: Persisting input arguments took 3.47s to run.
# If this happens often in your code, it can cause performance problems
# (results will be correct in all cases).
# The reason for this is probably some large input arguments for a wrapped
#  function (e.g. large strings).
# THIS IS A JOBLIB ISSUE. If you can, kindly provide the joblib's team with an
#  example so that they can fix the problem.
#   resampled_template = cache(resample_to_img, memory)(template, target_img)
# __________________________________________________resample_to_img - 3.5s, 0.1min
# /home/bpho/.conda/envs/venv/lib/python3.7/site-packages/nilearn/input_data/multi_nifti_masker.py:207: UserWarning: Persisting input arguments took 3.45s to run.
# If this happens often in your code, it can cause performance problems
# (results will be correct in all cases).
# The reason for this is probably some large input arguments for a wrapped
#  function (e.g. large strings).
# THIS IS A JOBLIB ISSUE. If you can, kindly provide the joblib's team with an
#  example so that they can fix the problem.
#   **mask_args)
# __________________________________compute_multi_gray_matter_mask - 12.2s, 0.2min
# [MultiNiftiMasker.transform] Resampling mask
# [CanICA] Loading data
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.nifti_masker.filter_and_mask...
# filter_and_mask(<nibabel.nifti1.Nifti1Image object at 0x7fba65b5c950>, <nibabel.nifti1.Nifti1Image object at 0x7fba65d338d0>, { 'detrend': True,
#   'dtype': None,
#   'high_pass': None,
#   'low_pass': None,
#   'smoothing_fwhm': 6,
#   'standardize': True,
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, memory_level=1, memory=Memory(location=nilearn_cache/joblib), verbose=1, confounds=None, copy=True, dtype=None)
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image(
# shape=(79, 95, 68, 745),
# affine=array([[  -2.,    0.,    0.,   78.],
#        [   0.,    2.,    0., -112.],
#        [   0.,    0.,    2.,  -50.],
#        [   0.,    0.,    0.,    1.]])
# )
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# /home/bpho/.conda/envs/venv/lib/python3.7/site-packages/nilearn/input_data/nifti_masker.py:408: UserWarning: Persisting input arguments took 3.46s to run.
# If this happens often in your code, it can cause performance problems
# (results will be correct in all cases).
# The reason for this is probably some large input arguments for a wrapped
#  function (e.g. large strings).
# THIS IS A JOBLIB ISSUE. If you can, kindly provide the joblib's team with an
#  example so that they can fix the problem.
#   dtype=self.dtype
# _________________________________________________filter_and_mask - 39.7s, 0.7min
# ________________________________________________________________________________
# [Memory] Calling nilearn.decomposition.base.fast_svd...
# fast_svd(array([[ 0.461968, ...,  0.151236],
#        ...,
#        [-0.615075, ..., -1.597317]], dtype=float32),
# 20, random_state=RandomState(MT19937) at 0x7FBA65F069E0)
# /home/bpho/.conda/envs/venv/lib/python3.7/site-packages/nilearn/decomposition/base.py:223: UserWarning: Persisting input arguments took 0.79s to run.
# If this happens often in your code, it can cause performance problems
# (results will be correct in all cases).
# The reason for this is probably some large input arguments for a wrapped
#  function (e.g. large strings).
# THIS IS A JOBLIB ISSUE. If you can, kindly provide the joblib's team with an
#  example so that they can fix the problem.
#   random_state=random_state)
# _________________________________________________________fast_svd - 1.8s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.utils.extmath.randomized_svd...
# randomized_svd(array([[ 0.00347 , ..., -0.00093 ],
#        ...,
#        [ 0.002219, ..., -0.002567]], dtype=float32), n_components=20, transpose=True, random_state=0, n_iter=3)
# ___________________________________________________randomized_svd - 0.6s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling nilearn.masking.unmask...
# unmask(array([[-0.001787, ..., -0.003279],
#        ...,
#        [ 0.003288, ...,  0.005081]], dtype=float32),
# <nibabel.nifti1.Nifti1Image object at 0x7fba65d338d0>)
# ___________________________________________________________unmask - 0.6s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.decomposition._fastica.fastica...
# fastica(array([[-0.001787, ...,  0.003288],
#        ...,
#        [-0.003279, ...,  0.005081]]), whiten=True, fun='cube', random_state=209652396)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# /home/bpho/.conda/envs/venv/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:120: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   ConvergenceWarning)
# _________________________________________________________fastica - 20.6s, 0.3min
# ________________________________________________________________________________
# [Memory] Calling sklearn.decomposition._fastica.fastica...
# fastica(array([[-0.001787, ...,  0.003288],
#        ...,
#        [-0.003279, ...,  0.005081]]), whiten=True, fun='cube', random_state=398764591)
# /home/bpho/.conda/envs/venv/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:120: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   ConvergenceWarning)
# ...
# [Memory] Calling sklearn.utils.extmath.randomized_svd...
# randomized_svd(array([[ 0.000585, ...,  0.004098],
#        ...,
#        [-0.000696, ..., -0.001894]], dtype=float32), n_components=20, transpose=True, random_state=0, n_iter=3)
# ___________________________________________________randomized_svd - 0.6s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling nilearn.masking.unmask...
# unmask(array([[-0.00462 , ..., -0.004092],
#        ...,
#        [ 0.001361, ...,  0.001237]], dtype=float32),
# <nibabel.nifti1.Nifti1Image object at 0x7fba65d36ad0>)
# ___________________________________________________________unmask - 0.6s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.decomposition._fastica.fastica...
# fastica(array([[-0.00462 , ...,  0.001361],
#        ...,
#        [-0.004092, ...,  0.001237]]), whiten=True, fun='cube', random_state=209652396)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# __________________________________________________________fastica - 6.8s, 0.1min
# ________________________________________________________________________________
# [Memory] Calling sklearn.decomposition._fastica.fastica...
# fastica(array([[-0.00462 , ...,  0.001361],
#        ...,
#        [-0.004092, ...,  0.001237]]), whiten=True, fun='cube', random_state=398764591)
# /home/bpho/.conda/envs/venv/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:120: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   ConvergenceWarning)
# _________________________________________________________fastica - 20.4s, 0.3min
# ________________________________________________________________________________
# [Memory] Calling sklearn.decomposition._fastica.fastica...
# fastica(array([[-0.00462 , ...,  0.001361],
#        ...,
#        [-0.004092, ...,  0.001237]]), whiten=True, fun='cube', random_state=924231285)
# __________________________________________________________fastica - 6.4s, 0.1min
# ________________________________________________________________________________
# [Memory] Calling sklearn.decomposition._fastica.fastica...
# fastica(array([[-0.00462 , ...,  0.001361],
#        ...,
#        [-0.004092, ...,  0.001237]]), whiten=True, fun='cube', random_state=1478610112)
# __________________________________________________________fastica - 5.8s, 0.1min
# ________________________________________________________________________________
# [Memory] Calling sklearn.decomposition._fastica.fastica...
# fastica(array([[-0.00462 , ...,  0.001361],
#        ...,
#        [-0.004092, ...,  0.001237]]), whiten=True, fun='cube', random_state=441365315)
# /home/bpho/.conda/envs/venv/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:120: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   ConvergenceWarning)
# _________________________________________________________fastica - 20.1s, 0.3min
# ________________________________________________________________________________
# [Memory] Calling sklearn.decomposition._fastica.fastica...
# fastica(array([[-0.00462 , ...,  0.001361],
#        ...,
#        [-0.004092, ...,  0.001237]]), whiten=True, fun='cube', random_state=1537364731)
# _________________________________________________________fastica - 14.2s, 0.2min
# ________________________________________________________________________________
# [Memory] Calling sklearn.decomposition._fastica.fastica...
# fastica(array([[-0.00462 , ...,  0.001361],
#        ...,
#        [-0.004092, ...,  0.001237]]), whiten=True, fun='cube', random_state=192771779)
# /home/bpho/.conda/envs/venv/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:120: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   ConvergenceWarning)
# _________________________________________________________fastica - 20.1s, 0.3min
# ________________________________________________________________________________
# [Memory] Calling sklearn.decomposition._fastica.fastica...
# fastica(array([[-0.00462 , ...,  0.001361],
#        ...,
#        [-0.004092, ...,  0.001237]]), whiten=True, fun='cube', random_state=1491434855)
# /home/bpho/.conda/envs/venv/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:120: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   ConvergenceWarning)
# _________________________________________________________fastica - 20.1s, 0.3min
# ________________________________________________________________________________
# [Memory] Calling sklearn.decomposition._fastica.fastica...
# fastica(array([[-0.00462 , ...,  0.001361],
#        ...,
#        [-0.004092, ...,  0.001237]]), whiten=True, fun='cube', random_state=1819583497)
# _________________________________________________________fastica - 10.9s, 0.2min
# ________________________________________________________________________________
# [Memory] Calling sklearn.decomposition._fastica.fastica...
# fastica(array([[-0.00462 , ...,  0.001361],
#        ...,
#        [-0.004092, ...,  0.001237]]), whiten=True, fun='cube', random_state=530702035)
# /home/bpho/.conda/envs/venv/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:120: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   ConvergenceWarning)
# _________________________________________________________fastica - 20.1s, 0.3min
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:  2.4min finished
# ________________________________________________________________________________
# [Memory] Calling nilearn.masking.unmask...
# unmask(array([[-0., ..., -0.],
#        ...,
#        [-0., ..., -0.]], dtype=float32), <nibabel.nifti1.Nifti1Image object at 0x7fba65d36ad0>)
# ___________________________________________________________unmask - 0.6s, 0.0min
# [MultiNiftiMasker.fit] Loading data from [Nifti1Image(
# shape=(79, 95, 68, 745),
# affine=array([[  -2.,    0.,    0.,   78.],
#        [   0.,    2.,    0., -112.],
#        [   0.,    0.,    2.,  -50.],
#        [   0.,    0.,    0.,    1.]])
# )]
# [MultiNiftiMasker.fit] Computing mask
# ________________________________________________________________________________
# [Memory] Calling nilearn.masking.compute_multi_gray_matter_mask...
# compute_multi_gray_matter_mask([<nibabel.nifti1.Nifti1Image object at 0x7fba94465fd0>], target_affine=None, target_shape=None, n_jobs=1, memory=Memory(location=nilearn_cache/joblib), verbose=0)
# ________________________________________________________________________________
# [Memory] Calling nilearn.image.resampling.resample_to_img...
# resample_to_img(<nibabel.nifti1.Nifti1Image object at 0x7fba974ead90>, <nibabel.nifti1.Nifti1Image object at 0x7fba94465fd0>)
# /home/bpho/.conda/envs/venv/lib/python3.7/site-packages/nilearn/masking.py:627: UserWarning: Persisting input arguments took 3.43s to run.
# If this happens often in your code, it can cause performance problems
# (results will be correct in all cases).
# The reason for this is probably some large input arguments for a wrapped
#  function (e.g. large strings).
# THIS IS A JOBLIB ISSUE. If you can, kindly provide the joblib's team with an
#  example so that they can fix the problem.
#   resampled_template = cache(resample_to_img, memory)(template, target_img)
# __________________________________________________resample_to_img - 3.4s, 0.1min
# /home/bpho/.conda/envs/venv/lib/python3.7/site-packages/nilearn/input_data/multi_nifti_masker.py:207: UserWarning: Persisting input arguments took 3.43s to run.
# If this happens often in your code, it can cause performance problems
# (results will be correct in all cases).
# The reason for this is probably some large input arguments for a wrapped
#  function (e.g. large strings).
# THIS IS A JOBLIB ISSUE. If you can, kindly provide the joblib's team with an
#  example so that they can fix the problem.
#   **mask_args)
# __________________________________compute_multi_gray_matter_mask - 12.1s, 0.2min
# [MultiNiftiMasker.transform] Resampling mask
# [CanICA] Loading data
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.nifti_masker.filter_and_mask...
# filter_and_mask(<nibabel.nifti1.Nifti1Image object at 0x7fba94465fd0>, <nibabel.nifti1.Nifti1Image object at 0x7fba974e7850>, { 'detrend': True,
#   'dtype': None,
#   'high_pass': None,
#   'low_pass': None,
#   'smoothing_fwhm': 6,
#   'standardize': True,
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, memory_level=1, memory=Memory(location=nilearn_cache/joblib), verbose=1, confounds=None, copy=True, dtype=None)
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image(
# shape=(79, 95, 68, 745),
# affine=array([[  -2.,    0.,    0.,   78.],
#        [   0.,    2.,    0., -112.],
#        [   0.,    0.,    2.,  -50.],
#        [   0.,    0.,    0.,    1.]])
# )
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# /home/bpho/.conda/envs/venv/lib/python3.7/site-packages/nilearn/input_data/nifti_masker.py:408: UserWarning: Persisting input arguments took 3.46s to run.
# If this happens often in your code, it can cause performance problems
# (results will be correct in all cases).
# The reason for this is probably some large input arguments for a wrapped
#  function (e.g. large strings).
# THIS IS A JOBLIB ISSUE. If you can, kindly provide the joblib's team with an
#  example so that they can fix the problem.
#   dtype=self.dtype
# _________________________________________________filter_and_mask - 26.3s, 0.4min
# ________________________________________________________________________________
# [Memory] Calling nilearn.decomposition.base.fast_svd...
# fast_svd(array([[ 1.026088, ..., -0.761267],
#        ...,
#        [-0.187039, ..., -0.0798  ]], dtype=float32),
# 20, random_state=RandomState(MT19937) at 0x7FBA65F069E0)
# /home/bpho/.conda/envs/venv/lib/python3.7/site-packages/nilearn/decomposition/base.py:223: UserWarning: Persisting input arguments took 0.76s to run.
# If this happens often in your code, it can cause performance problems
# (results will be correct in all cases).
# The reason for this is probably some large input arguments for a wrapped
#  function (e.g. large strings).
# THIS IS A JOBLIB ISSUE. If you can, kindly provide the joblib's team with an
#  example so that they can fix the problem.
#   random_state=random_state)
# _________________________________________________________fast_svd - 1.8s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.utils.extmath.randomized_svd...
# randomized_svd(array([[0.00133 , ..., 0.002648],
#        ...,
#        [0.000806, ..., 0.002085]], dtype=float32), n_components=20, transpose=True, random_state=0, n_iter=3)
# ___________________________________________________randomized_svd - 0.6s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling nilearn.masking.unmask...
# unmask(array([[0.002926, ..., 0.002435],
#        ...,
#        [0.001717, ..., 0.003635]], dtype=float32),
# <nibabel.nifti1.Nifti1Image object at 0x7fba974e7850>)
# ___________________________________________________________unmask - 0.6s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.decomposition._fastica.fastica...
# fastica(array([[0.002926, ..., 0.001717],
#        ...,
#        [0.002435, ..., 0.003635]]), whiten=True, fun='cube', random_state=209652396)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# __________________________________________________________fastica - 5.8s, 0.1min
# ________________________________________________________________________________
# [Memory] Calling sklearn.decomposition._fastica.fastica...
# fastica(array([[0.002926, ..., 0.001717],
#        ...,
#        [0.002435, ..., 0.003635]]), whiten=True, fun='cube', random_state=398764591)
# __________________________________________________________fastica - 5.9s, 0.1min
# ________________________________________________________________________________
# [Memory] Calling sklearn.decomposition._fastica.fastica...
# fastica(array([[0.002926, ..., 0.001717],
#        ...,
#        [0.002435, ..., 0.003635]]), whiten=True, fun='cube', random_state=924231285)
# __________________________________________________________fastica - 5.4s, 0.1min
# ________________________________________________________________________________
# [Memory] Calling sklearn.decomposition._fastica.fastica...
# fastica(array([[0.002926, ..., 0.001717],
#        ...,
#        [0.002435, ..., 0.003635]]), whiten=True, fun='cube', random_state=1478610112)
# /home/bpho/.conda/envs/venv/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:120: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   ConvergenceWarning)
# _________________________________________________________fastica - 20.5s, 0.3min
# ________________________________________________________________________________
# [Memory] Calling sklearn.decomposition._fastica.fastica...
# fastica(array([[0.002926, ..., 0.001717],
#        ...,
#        [0.002435, ..., 0.003635]]), whiten=True, fun='cube', random_state=441365315)
# __________________________________________________________fastica - 5.5s, 0.1min
# ________________________________________________________________________________
# [Memory] Calling sklearn.decomposition._fastica.fastica...
# fastica(array([[0.002926, ..., 0.001717],
#        ...,
#        [0.002435, ..., 0.003635]]), whiten=True, fun='cube', random_state=1537364731)
# __________________________________________________________fastica - 5.2s, 0.1min
# ________________________________________________________________________________
# [Memory] Calling sklearn.decomposition._fastica.fastica...
# fastica(array([[0.002926, ..., 0.001717],
#        ...,
#        [0.002435, ..., 0.003635]]), whiten=True, fun='cube', random_state=192771779)
# __________________________________________________________fastica - 5.5s, 0.1min
# ________________________________________________________________________________
# [Memory] Calling sklearn.decomposition._fastica.fastica...
# fastica(array([[0.002926, ..., 0.001717],
#        ...,
#        [0.002435, ..., 0.003635]]), whiten=True, fun='cube', random_state=1491434855)
# __________________________________________________________fastica - 6.6s, 0.1min
# ________________________________________________________________________________
# [Memory] Calling sklearn.decomposition._fastica.fastica...
# fastica(array([[0.002926, ..., 0.001717],
#        ...,
#        [0.002435, ..., 0.003635]]), whiten=True, fun='cube', random_state=1819583497)
# /home/bpho/.conda/envs/venv/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:120: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   ConvergenceWarning)
# _________________________________________________________fastica - 20.4s, 0.3min
# ________________________________________________________________________________
# [Memory] Calling sklearn.decomposition._fastica.fastica...
# fastica(array([[0.002926, ..., 0.001717],
#        ...,
#        [0.002435, ..., 0.003635]]), whiten=True, fun='cube', random_state=530702035)
# __________________________________________________________fastica - 4.5s, 0.1min
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:  1.4min finished
# ________________________________________________________________________________
# [Memory] Calling nilearn.masking.unmask...
# unmask(array([[ 0., ...,  0.],
#        ...,
#        [-0., ..., -0.]], dtype=float32), <nibabel.nifti1.Nifti1Image object at 0x7fba974e7850>)
# ___________________________________________________________unmask - 0.6s, 0.0min

# %%
canica_components_img = canica.components_img_
canica_components_img.to_filename('/home/bpho/Documents/canica_resting_state.nii.gz')

# %%
plot_prob_atlas(canica_components_img, title='All ICA components')
