# %% [markdown]
# # Multiple Hypothesis Testing

# %%
from os.path import join

import pandas as pd
import numpy as np
from multipy.fwer import bonferroni
from multipy.fdr import lsu

from common.paths import PLS_RESULTS, RIDGE_RESULTS, CROSS_PRED_RESULTS

# %% [markdown]
# ## Get data

# %% [markdown]
# ### Manual Input

# %%
bin_all = [0.0003, 0.0003, 0.0003, 0.0003, 0.0100, 0.0643]
bin_1 = [0.0953, 0.0313, 0.0593, 0.6485, 0.6048, 0.8287]
bin_2 = [0.0003, 0.0247, 0.0003, 0.0020, 0.0107, 0.4159]
bin_3 = [0.1789, 0.0653, 0.3196, 0.4172, 0.2779, 0.3162]
pvals = np.array(bin_all + bin_1 + bin_2 + bin_3)
df = pd.DataFrame({'Features': ['Feature {}'.format(i) for i in range(1,len(pvals)+1  )], 'P-value':pvals})
display(df)
# Out:
#       Features  P-value
# 0    Feature 1   0.0003
# 1    Feature 2   0.0003
# 2    Feature 3   0.0003
# 3    Feature 4   0.0003
# 4    Feature 5   0.0100
# 5    Feature 6   0.0643
# 6    Feature 7   0.0953
# 7    Feature 8   0.0313
# 8    Feature 9   0.0593
# 9   Feature 10   0.6485
# 10  Feature 11   0.6048
# 11  Feature 12   0.8287
# 12  Feature 13   0.0003
# 13  Feature 14   0.0247
# 14  Feature 15   0.0003
# 15  Feature 16   0.0020
# 16  Feature 17   0.0107
# 17  Feature 18   0.4159
# 18  Feature 19   0.1789
# 19  Feature 20   0.0653
# 20  Feature 21   0.3196
# 21  Feature 22   0.4172
# 22  Feature 23   0.2779
# 23  Feature 24   0.3162

# %% [markdown]
# ### Within-Prediction

# %%
fn = 'pls_pts_adhd.csv'
results_path = join(PLS_RESULTS, fn)
df = pd.read_csv(results_path, index_col=0)
# df['Features'] = df['Target'] + df['Bin']
pvals = df['P-value']
display(df)
# Out:
#    Model Population     Target    Bin     Score   P-value
# 0    pls       adhd  WISC_FSIQ    All  0.373846  0.000333
# 1    pls       adhd  WISC_FSIQ  Bin 1  0.255441  0.014662
# 2    pls       adhd  WISC_FSIQ  Bin 2  0.410544  0.000333
# 3    pls       adhd  WISC_FSIQ  Bin 3  0.076156  0.279573
# 4    pls       adhd   WISC_VSI    All  0.331722  0.000333
# 5    pls       adhd   WISC_VSI  Bin 1  0.235881  0.018994
# 6    pls       adhd   WISC_VSI  Bin 2  0.238640  0.007664
# 7    pls       adhd   WISC_VSI  Bin 3  0.143082  0.119627
# 8    pls       adhd   WISC_VCI    All  0.357835  0.000333
# 9    pls       adhd   WISC_VCI  Bin 1  0.200833  0.041320
# 10   pls       adhd   WISC_VCI  Bin 2  0.396446  0.000666
# 11   pls       adhd   WISC_VCI  Bin 3  0.041413  0.377208
# 12   pls       adhd   WISC_FRI    All  0.308873  0.000333
# 13   pls       adhd   WISC_FRI  Bin 1  0.017405  0.429190
# 14   pls       adhd   WISC_FRI  Bin 2  0.302537  0.001000
# 15   pls       adhd   WISC_FRI  Bin 3  0.062339  0.309563
# 16   pls       adhd   WISC_WMI    All  0.176029  0.004998
# 17   pls       adhd   WISC_WMI  Bin 1  0.048663  0.338221
# 18   pls       adhd   WISC_WMI  Bin 2  0.296202  0.001666
# 19   pls       adhd   WISC_WMI  Bin 3  0.126489  0.152949
# 20   pls       adhd   WISC_PSI    All  0.109169  0.051649
# 21   pls       adhd   WISC_PSI  Bin 1 -0.101896  0.799400
# 22   pls       adhd   WISC_PSI  Bin 2  0.039808  0.359547
# 23   pls       adhd   WISC_PSI  Bin 3  0.090687  0.239254

# %% [markdown]
# ### Cross-Prediction

# %%
fn = 'ridge_pts_age_cross_prediction.csv'
results_path = join(CROSS_PRED_RESULTS, fn)
df = pd.read_csv(results_path, index_col=0)
pvals = df['P-value']
display(df)
# Out:
#     Model     Target  Num Permutations Train Group Test Group   Score  P-value
# 0   ridge  WISC_FSIQ               500       Bin 1      Bin 1  0.2453   0.0220
# 1   ridge  WISC_FSIQ               500       Bin 1      Bin 2  0.3361   0.0020
# 2   ridge  WISC_FSIQ               500       Bin 1      Bin 3  0.1995   0.0080
# 3   ridge  WISC_FSIQ               500       Bin 2      Bin 2  0.3774   0.0020
# 4   ridge  WISC_FSIQ               500       Bin 2      Bin 3  0.2402   0.0040
# 5   ridge  WISC_FSIQ               500       Bin 2      Bin 1  0.3567   0.0020
# 6   ridge  WISC_FSIQ               500       Bin 3      Bin 3  0.0589   0.3214
# 7   ridge  WISC_FSIQ               500       Bin 3      Bin 1  0.2149   0.0060
# 8   ridge  WISC_FSIQ               500       Bin 3      Bin 2  0.3137   0.0020
# 9   ridge   WISC_VSI               500       Bin 1      Bin 1  0.2309   0.0240
# 10  ridge   WISC_VSI               500       Bin 1      Bin 2  0.3958   0.0020
# 11  ridge   WISC_VSI               500       Bin 1      Bin 3  0.1348   0.0719
# 12  ridge   WISC_VSI               500       Bin 2      Bin 2  0.2608   0.0100
# 13  ridge   WISC_VSI               500       Bin 2      Bin 3  0.1753   0.0240
# 14  ridge   WISC_VSI               500       Bin 2      Bin 1  0.3775   0.0020
# 15  ridge   WISC_VSI               500       Bin 3      Bin 3  0.0532   0.3174
# 16  ridge   WISC_VSI               500       Bin 3      Bin 1  0.1447   0.0399
# 17  ridge   WISC_VSI               500       Bin 3      Bin 2  0.2630   0.0020
# 18  ridge   WISC_VCI               500       Bin 1      Bin 1  0.2154   0.0359
# 19  ridge   WISC_VCI               500       Bin 1      Bin 2  0.3202   0.0020
# 20  ridge   WISC_VCI               500       Bin 1      Bin 3  0.2990   0.0020
# 21  ridge   WISC_VCI               500       Bin 2      Bin 2  0.3946   0.0020
# 22  ridge   WISC_VCI               500       Bin 2      Bin 3  0.2016   0.0120
# 23  ridge   WISC_VCI               500       Bin 2      Bin 1  0.3079   0.0020
# 24  ridge   WISC_VCI               500       Bin 3      Bin 3  0.0749   0.3214
# 25  ridge   WISC_VCI               500       Bin 3      Bin 1  0.3761   0.0020
# 26  ridge   WISC_VCI               500       Bin 3      Bin 2  0.2057   0.0040
# 27  ridge   WISC_FRI               500       Bin 1      Bin 1  0.0621   0.3134
# 28  ridge   WISC_FRI               500       Bin 1      Bin 2  0.1595   0.0240
# 29  ridge   WISC_FRI               500       Bin 1      Bin 3  0.1677   0.0399
# 30  ridge   WISC_FRI               500       Bin 2      Bin 2  0.2956   0.0040
# 31  ridge   WISC_FRI               500       Bin 2      Bin 3  0.2905   0.0020
# 32  ridge   WISC_FRI               500       Bin 2      Bin 1  0.1677   0.0319
# 33  ridge   WISC_FRI               500       Bin 3      Bin 3  0.0206   0.4571
# 34  ridge   WISC_FRI               500       Bin 3      Bin 1  0.1023   0.1138
# 35  ridge   WISC_FRI               500       Bin 3      Bin 2  0.3177   0.0020
# 36  ridge   WISC_WMI               500       Bin 1      Bin 1  0.0319   0.4291
# 37  ridge   WISC_WMI               500       Bin 1      Bin 2  0.0332   0.3114
# 38  ridge   WISC_WMI               500       Bin 1      Bin 3  0.1529   0.0439
# 39  ridge   WISC_WMI               500       Bin 2      Bin 2  0.3217   0.0020
# 40  ridge   WISC_WMI               500       Bin 2      Bin 3  0.1634   0.0319
# 41  ridge   WISC_WMI               500       Bin 2      Bin 1  0.0427   0.3333
# 42  ridge   WISC_WMI               500       Bin 3      Bin 3  0.1766   0.0539
# 43  ridge   WISC_WMI               500       Bin 3      Bin 1  0.0276   0.3932
# 44  ridge   WISC_WMI               500       Bin 3      Bin 2  0.2198   0.0060
# 45  ridge   WISC_PSI               500       Bin 1      Bin 1 -0.0605   0.6986
# 46  ridge   WISC_PSI               500       Bin 1      Bin 2  0.0563   0.2315
# 47  ridge   WISC_PSI               500       Bin 1      Bin 3 -0.0283   0.5868
# 48  ridge   WISC_PSI               500       Bin 2      Bin 2  0.0633   0.2675
# 49  ridge   WISC_PSI               500       Bin 2      Bin 3 -0.0210   0.5928
# 50  ridge   WISC_PSI               500       Bin 2      Bin 1  0.0095   0.4391
# 51  ridge   WISC_PSI               500       Bin 3      Bin 3  0.1324   0.1637
# 52  ridge   WISC_PSI               500       Bin 3      Bin 1  0.0302   0.3713
# 53  ridge   WISC_PSI               500       Bin 3      Bin 2 -0.0639   0.8104

# %% [markdown]
# ## Run correction

# %%
a_threshold = 0.05
df['BFR'] = bonferroni(pvals, alpha=a_threshold)
df['FDR'] = lsu(pvals, q=a_threshold)
display(df.round(4))
# Out:
#     Model     Target  Num Permutations Train Group Test Group   Score  \
# 0   ridge  WISC_FSIQ               500       Bin 1      Bin 1  0.2453
# 1   ridge  WISC_FSIQ               500       Bin 1      Bin 2  0.3361
# 2   ridge  WISC_FSIQ               500       Bin 1      Bin 3  0.1995
# 3   ridge  WISC_FSIQ               500       Bin 2      Bin 2  0.3774
# 4   ridge  WISC_FSIQ               500       Bin 2      Bin 3  0.2402
# 5   ridge  WISC_FSIQ               500       Bin 2      Bin 1  0.3567
# 6   ridge  WISC_FSIQ               500       Bin 3      Bin 3  0.0589
# 7   ridge  WISC_FSIQ               500       Bin 3      Bin 1  0.2149
# 8   ridge  WISC_FSIQ               500       Bin 3      Bin 2  0.3137
# 9   ridge   WISC_VSI               500       Bin 1      Bin 1  0.2309
# 10  ridge   WISC_VSI               500       Bin 1      Bin 2  0.3958
# 11  ridge   WISC_VSI               500       Bin 1      Bin 3  0.1348
# 12  ridge   WISC_VSI               500       Bin 2      Bin 2  0.2608
# 13  ridge   WISC_VSI               500       Bin 2      Bin 3  0.1753
# 14  ridge   WISC_VSI               500       Bin 2      Bin 1  0.3775
# 15  ridge   WISC_VSI               500       Bin 3      Bin 3  0.0532
# 16  ridge   WISC_VSI               500       Bin 3      Bin 1  0.1447
# 17  ridge   WISC_VSI               500       Bin 3      Bin 2  0.2630
# 18  ridge   WISC_VCI               500       Bin 1      Bin 1  0.2154
# 19  ridge   WISC_VCI               500       Bin 1      Bin 2  0.3202
# 20  ridge   WISC_VCI               500       Bin 1      Bin 3  0.2990
# 21  ridge   WISC_VCI               500       Bin 2      Bin 2  0.3946
# 22  ridge   WISC_VCI               500       Bin 2      Bin 3  0.2016
# 23  ridge   WISC_VCI               500       Bin 2      Bin 1  0.3079
# 24  ridge   WISC_VCI               500       Bin 3      Bin 3  0.0749
# 25  ridge   WISC_VCI               500       Bin 3      Bin 1  0.3761
# 26  ridge   WISC_VCI               500       Bin 3      Bin 2  0.2057
# 27  ridge   WISC_FRI               500       Bin 1      Bin 1  0.0621
# 28  ridge   WISC_FRI               500       Bin 1      Bin 2  0.1595
# 29  ridge   WISC_FRI               500       Bin 1      Bin 3  0.1677
# 30  ridge   WISC_FRI               500       Bin 2      Bin 2  0.2956
# 31  ridge   WISC_FRI               500       Bin 2      Bin 3  0.2905
# 32  ridge   WISC_FRI               500       Bin 2      Bin 1  0.1677
# 33  ridge   WISC_FRI               500       Bin 3      Bin 3  0.0206
# 34  ridge   WISC_FRI               500       Bin 3      Bin 1  0.1023
# 35  ridge   WISC_FRI               500       Bin 3      Bin 2  0.3177
# 36  ridge   WISC_WMI               500       Bin 1      Bin 1  0.0319
# 37  ridge   WISC_WMI               500       Bin 1      Bin 2  0.0332
# 38  ridge   WISC_WMI               500       Bin 1      Bin 3  0.1529
# 39  ridge   WISC_WMI               500       Bin 2      Bin 2  0.3217
# 40  ridge   WISC_WMI               500       Bin 2      Bin 3  0.1634
# 41  ridge   WISC_WMI               500       Bin 2      Bin 1  0.0427
# 42  ridge   WISC_WMI               500       Bin 3      Bin 3  0.1766
# 43  ridge   WISC_WMI               500       Bin 3      Bin 1  0.0276
# 44  ridge   WISC_WMI               500       Bin 3      Bin 2  0.2198
# 45  ridge   WISC_PSI               500       Bin 1      Bin 1 -0.0605
# 46  ridge   WISC_PSI               500       Bin 1      Bin 2  0.0563
# 47  ridge   WISC_PSI               500       Bin 1      Bin 3 -0.0283
# 48  ridge   WISC_PSI               500       Bin 2      Bin 2  0.0633
# 49  ridge   WISC_PSI               500       Bin 2      Bin 3 -0.0210
# 50  ridge   WISC_PSI               500       Bin 2      Bin 1  0.0095
# 51  ridge   WISC_PSI               500       Bin 3      Bin 3  0.1324
# 52  ridge   WISC_PSI               500       Bin 3      Bin 1  0.0302
# 53  ridge   WISC_PSI               500       Bin 3      Bin 2 -0.0639
#
#     P-value    BFR    FDR
# 0    0.0220  False   True
# 1    0.0020  False   True
# 2    0.0080  False   True
# 3    0.0020  False   True
# 4    0.0040  False   True
# 5    0.0020  False   True
# 6    0.3214  False  False
# 7    0.0060  False   True
# 8    0.0020  False   True
# 9    0.0240  False   True
# 10   0.0020  False   True
# 11   0.0719  False  False
# 12   0.0100  False   True
# 13   0.0240  False   True
# 14   0.0020  False   True
# 15   0.3174  False  False
# 16   0.0399  False  False
# 17   0.0020  False   True
# 18   0.0359  False  False
# 19   0.0020  False   True
# 20   0.0020  False   True
# 21   0.0020  False   True
# 22   0.0120  False   True
# 23   0.0020  False   True
# 24   0.3214  False  False
# 25   0.0020  False   True
# 26   0.0040  False   True
# 27   0.3134  False  False
# 28   0.0240  False   True
# 29   0.0399  False  False
# 30   0.0040  False   True
# 31   0.0020  False   True
# 32   0.0319  False  False
# 33   0.4571  False  False
# 34   0.1138  False  False
# 35   0.0020  False   True
# 36   0.4291  False  False
# 37   0.3114  False  False
# 38   0.0439  False  False
# 39   0.0020  False   True
# 40   0.0319  False  False
# 41   0.3333  False  False
# 42   0.0539  False  False
# 43   0.3932  False  False
# 44   0.0060  False   True
# 45   0.6986  False  False
# 46   0.2315  False  False
# 47   0.5868  False  False
# 48   0.2675  False  False
# 49   0.5928  False  False
# 50   0.4391  False  False
# 51   0.1637  False  False
# 52   0.3713  False  False
# 53   0.8104  False  False

# %% [markdown]
# ## Save and update results file

# %%
df.to_csv(results_path)
