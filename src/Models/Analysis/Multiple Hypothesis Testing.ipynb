# %% [markdown]
# # Multiple Hypothesis Testing

# %%
from os.path import join

import pandas as pd
import numpy as np
from multipy.fwer import bonferroni
from multipy.fdr import lsu

from common.paths import PLS_RESULTS, RIDGE_RESULTS, CROSS_PRED_RESULTS

# %% [markdown]
# ## Get data

# %% [markdown]
# ### Manual Input

# %%
# bin_all = [0.0003, 0.0003, 0.0003, 0.0003, 0.0100, 0.0643]
# bin_1 = [0.0953, 0.0313, 0.0593, 0.6485, 0.6048, 0.8287]
# bin_2 = [0.0003, 0.0247, 0.0003, 0.0020, 0.0107, 0.4159]
# bin_3 = [0.1789, 0.0653, 0.3196, 0.4172, 0.2779, 0.3162]
# pvals = np.array(bin_all + bin_1 + bin_2 + bin_3)
pvals = np.array([0.3214, 0.0140, 0.0200, 0.5309, 0.1497, 0.4950])
df = pd.DataFrame({'Features': ['Feature {}'.format(i) for i in range(1, len(pvals) + 1)], 'P-value':pvals})
display(df)
# Out:
#     Features  P-value
# 0  Feature 1   0.3214
# 1  Feature 2   0.0140
# 2  Feature 3   0.0200
# 3  Feature 4   0.5309
# 4  Feature 5   0.1497
# 5  Feature 6   0.4950

# %% [markdown]
# ### Within-Prediction

# %%
fn = 'ridge_pts_adhd_two_bins.csv'
results_path = join(RIDGE_RESULTS, fn)
df = pd.read_csv(results_path, index_col=0)
# df['Features'] = df['Target'] + df['Bin']
pvals = df['P-value']
display(df)
# Out:
#     Model Population     Target    Bin  Alpha     Score   P-value
# 0   ridge       adhd  WISC_FSIQ  Bin 1   6401  0.320190  0.001996
# 1   ridge       adhd  WISC_FSIQ  Bin 2   9901  0.191331  0.025948
# 2   ridge       adhd   WISC_VSI  Bin 1   9901  0.313330  0.001996
# 3   ridge       adhd   WISC_VSI  Bin 2   9901  0.182058  0.031936
# 4   ridge       adhd   WISC_VCI  Bin 1    701  0.292524  0.001996
# 5   ridge       adhd   WISC_VCI  Bin 2   9901  0.219886  0.011976
# 6   ridge       adhd   WISC_FRI  Bin 1   9901  0.209537  0.009980
# 7   ridge       adhd   WISC_FRI  Bin 2   7301  0.186734  0.021956
# 8   ridge       adhd   WISC_WMI  Bin 1      1  0.100642  0.143713
# 9   ridge       adhd   WISC_WMI  Bin 2      1  0.150171  0.073852
# 10  ridge       adhd   WISC_PSI  Bin 1      1 -0.107218  0.868263
# 11  ridge       adhd   WISC_PSI  Bin 2    301 -0.032323  0.666667

# %% [markdown]
# ### Cross-Prediction

# %%
# fn = 'ridge_pts_age_cross_prediction.csv'
fn = 'ridge_pts_diagnosis_cross_prediction (n=93).csv'
results_path = join(CROSS_PRED_RESULTS, fn)
df = pd.read_csv(results_path, index_col=0)
df = df.reset_index(drop=True)
pvals = df['P-value']
display(df)
# Out:
#     Model     Target     Train      Test     Score   P-value Population  \
# 0   ridge  WISC_FSIQ   Healthy   Healthy  0.092055  0.225549    Healthy
# 1   ridge  WISC_FSIQ   Healthy  ADHD_One  0.183880  0.023952    Healthy
# 2   ridge  WISC_FSIQ   Healthy  ADHD_Two  0.356004  0.001996    Healthy
# 3   ridge  WISC_FSIQ  ADHD_One  ADHD_One  0.170265  0.123752   ADHD_One
# 4   ridge  WISC_FSIQ  ADHD_One  ADHD_Two  0.410550  0.001996   ADHD_One
# 5   ridge  WISC_FSIQ  ADHD_One   Healthy  0.138883  0.077844   ADHD_One
# 6   ridge  WISC_FSIQ  ADHD_Two  ADHD_Two  0.119800  0.179641   ADHD_Two
# 7   ridge  WISC_FSIQ  ADHD_Two   Healthy  0.329807  0.001996   ADHD_Two
# 8   ridge  WISC_FSIQ  ADHD_Two  ADHD_One  0.459970  0.001996   ADHD_Two
# 9   ridge   WISC_VSI   Healthy   Healthy  0.197298  0.081836    Healthy
# 10  ridge   WISC_VSI   Healthy  ADHD_One  0.108825  0.119760    Healthy
# 11  ridge   WISC_VSI   Healthy  ADHD_Two  0.270783  0.001996    Healthy
# 12  ridge   WISC_VSI  ADHD_One  ADHD_One  0.195873  0.063872   ADHD_One
# 13  ridge   WISC_VSI  ADHD_One  ADHD_Two  0.418297  0.001996   ADHD_One
# 14  ridge   WISC_VSI  ADHD_One   Healthy  0.093758  0.143713   ADHD_One
# 15  ridge   WISC_VSI  ADHD_Two  ADHD_Two  0.098413  0.281437   ADHD_Two
# 16  ridge   WISC_VSI  ADHD_Two   Healthy  0.218547  0.009980   ADHD_Two
# 17  ridge   WISC_VSI  ADHD_Two  ADHD_One  0.487448  0.001996   ADHD_Two
# 18  ridge   WISC_VCI   Healthy   Healthy  0.275220  0.015968    Healthy
# 19  ridge   WISC_VCI   Healthy  ADHD_One  0.242818  0.007984    Healthy
# 20  ridge   WISC_VCI   Healthy  ADHD_Two  0.319858  0.001996    Healthy
# 21  ridge   WISC_VCI  ADHD_One  ADHD_One  0.149025  0.123752   ADHD_One
# 22  ridge   WISC_VCI  ADHD_One  ADHD_Two  0.368523  0.001996   ADHD_One
# 23  ridge   WISC_VCI  ADHD_One   Healthy  0.266773  0.005988   ADHD_One
# 24  ridge   WISC_VCI  ADHD_Two  ADHD_Two  0.208274  0.065868   ADHD_Two
# 25  ridge   WISC_VCI  ADHD_Two   Healthy  0.327451  0.001996   ADHD_Two
# 26  ridge   WISC_VCI  ADHD_Two  ADHD_One  0.399767  0.001996   ADHD_Two
# 27  ridge   WISC_FRI   Healthy   Healthy -0.025662  0.566866    Healthy
# 28  ridge   WISC_FRI   Healthy  ADHD_One  0.119205  0.113772    Healthy
# 29  ridge   WISC_FRI   Healthy  ADHD_Two  0.255079  0.003992    Healthy
# 30  ridge   WISC_FRI  ADHD_One  ADHD_One  0.032879  0.391218   ADHD_One
# 31  ridge   WISC_FRI  ADHD_One  ADHD_Two  0.357755  0.001996   ADHD_One
# 32  ridge   WISC_FRI  ADHD_One   Healthy  0.027971  0.375250   ADHD_One
# 33  ridge   WISC_FRI  ADHD_Two  ADHD_Two -0.040080  0.586826   ADHD_Two
# 34  ridge   WISC_FRI  ADHD_Two   Healthy  0.191871  0.015968   ADHD_Two
# 35  ridge   WISC_FRI  ADHD_Two  ADHD_One  0.383506  0.001996   ADHD_Two
# 36  ridge   WISC_WMI   Healthy   Healthy  0.119509  0.197605    Healthy
# 37  ridge   WISC_WMI   Healthy  ADHD_One  0.017578  0.485030    Healthy
# 38  ridge   WISC_WMI   Healthy  ADHD_Two  0.243416  0.005988    Healthy
# 39  ridge   WISC_WMI  ADHD_One  ADHD_One  0.271749  0.025948   ADHD_One
# 40  ridge   WISC_WMI  ADHD_One  ADHD_Two  0.344706  0.003992   ADHD_One
# 41  ridge   WISC_WMI  ADHD_One   Healthy  0.124305  0.119760   ADHD_One
# 42  ridge   WISC_WMI  ADHD_Two  ADHD_Two -0.136311  0.820359   ADHD_Two
# 43  ridge   WISC_WMI  ADHD_Two   Healthy  0.285995  0.003992   ADHD_Two
# 44  ridge   WISC_WMI  ADHD_Two  ADHD_One  0.360624  0.001996   ADHD_Two
# 45  ridge   WISC_PSI   Healthy   Healthy -0.034444  0.628743    Healthy
# 46  ridge   WISC_PSI   Healthy  ADHD_One -0.010950  0.504990    Healthy
# 47  ridge   WISC_PSI   Healthy  ADHD_Two -0.028829  0.620758    Healthy
# 48  ridge   WISC_PSI  ADHD_One  ADHD_One  0.072223  0.283433   ADHD_One
# 49  ridge   WISC_PSI  ADHD_One  ADHD_Two  0.307603  0.001996   ADHD_One
# 50  ridge   WISC_PSI  ADHD_One   Healthy  0.005830  0.489022   ADHD_One
# 51  ridge   WISC_PSI  ADHD_Two  ADHD_Two  0.138673  0.155689   ADHD_Two
# 52  ridge   WISC_PSI  ADHD_Two   Healthy -0.035534  0.598802   ADHD_Two
# 53  ridge   WISC_PSI  ADHD_Two  ADHD_One  0.250503  0.005988   ADHD_Two
#
#     Num Permutations
# 0                500
# 1                500
# 2                500
# 3                500
# 4                500
# 5                500
# 6                500
# 7                500
# 8                500
# 9                500
# 10               500
# 11               500
# 12               500
# 13               500
# 14               500
# 15               500
# 16               500
# 17               500
# 18               500
# 19               500
# 20               500
# 21               500
# 22               500
# 23               500
# 24               500
# 25               500
# 26               500
# 27               500
# 28               500
# 29               500
# 30               500
# 31               500
# 32               500
# 33               500
# 34               500
# 35               500
# 36               500
# 37               500
# 38               500
# 39               500
# 40               500
# 41               500
# 42               500
# 43               500
# 44               500
# 45               500
# 46               500
# 47               500
# 48               500
# 49               500
# 50               500
# 51               500
# 52               500
# 53               500

# %% [markdown]
# ## Run correction

# %%
a_threshold = 0.05
# df['BFR'] = bonferroni(pvals, alpha=a_threshold)
df['FDR'] = lsu(pvals, q=a_threshold)
display(df.round(4))
# Out:
#     Model Population     Target    Bin  Alpha   Score  P-value    FDR
# 0   ridge       adhd  WISC_FSIQ  Bin 1   6401  0.3202   0.0020   True
# 1   ridge       adhd  WISC_FSIQ  Bin 2   9901  0.1913   0.0259   True
# 2   ridge       adhd   WISC_VSI  Bin 1   9901  0.3133   0.0020   True
# 3   ridge       adhd   WISC_VSI  Bin 2   9901  0.1821   0.0319   True
# 4   ridge       adhd   WISC_VCI  Bin 1    701  0.2925   0.0020   True
# 5   ridge       adhd   WISC_VCI  Bin 2   9901  0.2199   0.0120   True
# 6   ridge       adhd   WISC_FRI  Bin 1   9901  0.2095   0.0100   True
# 7   ridge       adhd   WISC_FRI  Bin 2   7301  0.1867   0.0220   True
# 8   ridge       adhd   WISC_WMI  Bin 1      1  0.1006   0.1437  False
# 9   ridge       adhd   WISC_WMI  Bin 2      1  0.1502   0.0739  False
# 10  ridge       adhd   WISC_PSI  Bin 1      1 -0.1072   0.8683  False
# 11  ridge       adhd   WISC_PSI  Bin 2    301 -0.0323   0.6667  False

# %% [markdown]
# ## Save and update results file

# %%
df.to_csv(results_path)

# %% [markdown]
# ## Get FDR q

# %%
m = len(pvals)
sort_ind = np.argsort(pvals)
qs = [(i+1.)*0.05/m for i, p in enumerate(pvals[sort_ind])]
a = pd.DataFrame([(p, q) for p, q in zip(pvals[sort_ind], qs)])
display(a)
# Out:
#            0         1
# 0   0.001996  0.000926
# 1   0.001996  0.001852
# 2   0.001996  0.002778
# 3   0.001996  0.003704
# 4   0.001996  0.004630
# 5   0.001996  0.005556
# 6   0.001996  0.006481
# 7   0.001996  0.007407
# 8   0.001996  0.008333
# 9   0.001996  0.009259
# 10  0.001996  0.010185
# 11  0.001996  0.011111
# 12  0.001996  0.012037
# 13  0.001996  0.012963
# 14  0.001996  0.013889
# 15  0.001996  0.014815
# 16  0.001996  0.015741
# 17  0.001996  0.016667
# 18  0.001996  0.017593
# 19  0.003992  0.018519
# 20  0.005988  0.019444
# 21  0.007984  0.020370
# 22  0.009980  0.021296
# 23  0.009980  0.022222
# 24  0.023952  0.023148
# 25  0.023952  0.024074
# 26  0.023952  0.025000
# 27  0.023952  0.025926
# 28  0.025948  0.026852
# 29  0.027944  0.027778
# 30  0.039920  0.028704
# 31  0.061876  0.029630
# 32  0.083832  0.030556
# 33  0.087824  0.031481
# 34  0.099800  0.032407
# 35  0.125749  0.033333
# 36  0.185629  0.034259
# 37  0.209581  0.035185
# 38  0.221557  0.036111
# 39  0.253493  0.037037
# 40  0.265469  0.037963
# 41  0.301397  0.038889
# 42  0.307385  0.039815
# 43  0.345309  0.040741
# 44  0.349301  0.041667
# 45  0.351297  0.042593
# 46  0.413174  0.043519
# 47  0.417166  0.044444
# 48  0.425150  0.045370
# 49  0.473054  0.046296
# 50  0.574850  0.047222
# 51  0.624750  0.048148
# 52  0.680639  0.049074
# 53  0.722555  0.050000
