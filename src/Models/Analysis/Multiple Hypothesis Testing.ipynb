# %% [markdown]
# # Multiple Hypothesis Testing

# %%
from os.path import join

import pandas as pd
import numpy as np
from multipy.fwer import bonferroni
from multipy.fdr import lsu

from common.paths import PLS_RESULTS, RIDGE_RESULTS, CROSS_PRED_RESULTS

# %% [markdown]
# ## Get data

# %% [markdown]
# ### Manual Input

# %%
bin_all = [0.0003, 0.0003, 0.0003, 0.0003, 0.0100, 0.0643]
bin_1 = [0.0953, 0.0313, 0.0593, 0.6485, 0.6048, 0.8287]
bin_2 = [0.0003, 0.0247, 0.0003, 0.0020, 0.0107, 0.4159]
bin_3 = [0.1789, 0.0653, 0.3196, 0.4172, 0.2779, 0.3162]
pvals = np.array(bin_all + bin_1 + bin_2 + bin_3)
df = pd.DataFrame({'Features': ['Feature {}'.format(i) for i in range(1,len(pvals)+1  )], 'P-value':pvals})
display(df)
# Out:
#       Features  P-value
# 0    Feature 1   0.0003
# 1    Feature 2   0.0003
# 2    Feature 3   0.0003
# 3    Feature 4   0.0003
# 4    Feature 5   0.0100
# 5    Feature 6   0.0643
# 6    Feature 7   0.0953
# 7    Feature 8   0.0313
# 8    Feature 9   0.0593
# 9   Feature 10   0.6485
# 10  Feature 11   0.6048
# 11  Feature 12   0.8287
# 12  Feature 13   0.0003
# 13  Feature 14   0.0247
# 14  Feature 15   0.0003
# 15  Feature 16   0.0020
# 16  Feature 17   0.0107
# 17  Feature 18   0.4159
# 18  Feature 19   0.1789
# 19  Feature 20   0.0653
# 20  Feature 21   0.3196
# 21  Feature 22   0.4172
# 22  Feature 23   0.2779
# 23  Feature 24   0.3162

# %% [markdown]
# ### Within-Prediction

# %%
fn = 'pls_pts_adhd.csv'
results_path = join(PLS_RESULTS, fn)
df = pd.read_csv(results_path, index_col=0)
# df['Features'] = df['Target'] + df['Bin']
pvals = df['P-value']
display(df)
# Out:
#    Model Population     Target    Bin     Score   P-value
# 0    pls       adhd  WISC_FSIQ    All  0.373846  0.000333
# 1    pls       adhd  WISC_FSIQ  Bin 1  0.255441  0.014662
# 2    pls       adhd  WISC_FSIQ  Bin 2  0.410544  0.000333
# 3    pls       adhd  WISC_FSIQ  Bin 3  0.076156  0.279573
# 4    pls       adhd   WISC_VSI    All  0.331722  0.000333
# 5    pls       adhd   WISC_VSI  Bin 1  0.235881  0.018994
# 6    pls       adhd   WISC_VSI  Bin 2  0.238640  0.007664
# 7    pls       adhd   WISC_VSI  Bin 3  0.143082  0.119627
# 8    pls       adhd   WISC_VCI    All  0.357835  0.000333
# 9    pls       adhd   WISC_VCI  Bin 1  0.200833  0.041320
# 10   pls       adhd   WISC_VCI  Bin 2  0.396446  0.000666
# 11   pls       adhd   WISC_VCI  Bin 3  0.041413  0.377208
# 12   pls       adhd   WISC_FRI    All  0.308873  0.000333
# 13   pls       adhd   WISC_FRI  Bin 1  0.017405  0.429190
# 14   pls       adhd   WISC_FRI  Bin 2  0.302537  0.001000
# 15   pls       adhd   WISC_FRI  Bin 3  0.062339  0.309563
# 16   pls       adhd   WISC_WMI    All  0.176029  0.004998
# 17   pls       adhd   WISC_WMI  Bin 1  0.048663  0.338221
# 18   pls       adhd   WISC_WMI  Bin 2  0.296202  0.001666
# 19   pls       adhd   WISC_WMI  Bin 3  0.126489  0.152949
# 20   pls       adhd   WISC_PSI    All  0.109169  0.051649
# 21   pls       adhd   WISC_PSI  Bin 1 -0.101896  0.799400
# 22   pls       adhd   WISC_PSI  Bin 2  0.039808  0.359547
# 23   pls       adhd   WISC_PSI  Bin 3  0.090687  0.239254

# %% [markdown]
# ### Cross-Prediction

# %%
# fn = 'ridge_pts_age_cross_prediction.csv'
fn = 'ridge_pts_diagnosis_cross_prediction.csv'
results_path = join(CROSS_PRED_RESULTS, fn)
df = pd.read_csv(results_path, index_col=0)
df = df.reset_index(drop=True)
pvals = df['P-value']
display(df)
# Out:
#     Model     Target     Train      Test     Score   P-value Population  \
# 0   ridge  WISC_FSIQ   Healthy   Healthy  0.048034  0.361277    Healthy
# 1   ridge  WISC_FSIQ   Healthy  ADHD_One  0.320258  0.001996    Healthy
# 2   ridge  WISC_FSIQ   Healthy  ADHD_Two  0.172506  0.017964    Healthy
# 3   ridge  WISC_FSIQ  ADHD_One  ADHD_One  0.289792  0.013972   ADHD_One
# 4   ridge  WISC_FSIQ  ADHD_One  ADHD_Two  0.360502  0.001996   ADHD_One
# 5   ridge  WISC_FSIQ  ADHD_One   Healthy  0.212173  0.009980   ADHD_One
# 6   ridge  WISC_FSIQ  ADHD_Two  ADHD_Two  0.167873  0.091816   ADHD_Two
# 7   ridge  WISC_FSIQ  ADHD_Two   Healthy  0.095758  0.139721   ADHD_Two
# 8   ridge  WISC_FSIQ  ADHD_Two  ADHD_One  0.438861  0.001996   ADHD_Two
# 9   ridge   WISC_VSI   Healthy   Healthy  0.096726  0.203593    Healthy
# 10  ridge   WISC_VSI   Healthy  ADHD_One  0.247247  0.007984    Healthy
# 11  ridge   WISC_VSI   Healthy  ADHD_Two  0.161637  0.037924    Healthy
# 12  ridge   WISC_VSI  ADHD_One  ADHD_One  0.150585  0.131737   ADHD_One
# 13  ridge   WISC_VSI  ADHD_One  ADHD_Two  0.416669  0.001996   ADHD_One
# 14  ridge   WISC_VSI  ADHD_One   Healthy  0.165758  0.033932   ADHD_One
# 15  ridge   WISC_VSI  ADHD_Two  ADHD_Two  0.305602  0.001996   ADHD_Two
# 16  ridge   WISC_VSI  ADHD_Two   Healthy  0.049199  0.289421   ADHD_Two
# 17  ridge   WISC_VSI  ADHD_Two  ADHD_One  0.413023  0.001996   ADHD_Two
# 18  ridge   WISC_VCI   Healthy   Healthy  0.241846  0.027944    Healthy
# 19  ridge   WISC_VCI   Healthy  ADHD_One  0.396343  0.001996    Healthy
# 20  ridge   WISC_VCI   Healthy  ADHD_Two  0.150757  0.035928    Healthy
# 21  ridge   WISC_VCI  ADHD_One  ADHD_One  0.366820  0.003992   ADHD_One
# 22  ridge   WISC_VCI  ADHD_One  ADHD_Two  0.283140  0.001996   ADHD_One
# 23  ridge   WISC_VCI  ADHD_One   Healthy  0.309107  0.001996   ADHD_One
# 24  ridge   WISC_VCI  ADHD_Two  ADHD_Two -0.012151  0.520958   ADHD_Two
# 25  ridge   WISC_VCI  ADHD_Two   Healthy  0.108962  0.113772   ADHD_Two
# 26  ridge   WISC_VCI  ADHD_Two  ADHD_One  0.291487  0.001996   ADHD_Two
# 27  ridge   WISC_FRI   Healthy   Healthy -0.079647  0.760479    Healthy
# 28  ridge   WISC_FRI   Healthy  ADHD_One  0.237063  0.003992    Healthy
# 29  ridge   WISC_FRI   Healthy  ADHD_Two  0.096355  0.151697    Healthy
# 30  ridge   WISC_FRI  ADHD_One  ADHD_One  0.106688  0.171657   ADHD_One
# 31  ridge   WISC_FRI  ADHD_One  ADHD_Two  0.302634  0.001996   ADHD_One
# 32  ridge   WISC_FRI  ADHD_One   Healthy  0.188399  0.015968   ADHD_One
# 33  ridge   WISC_FRI  ADHD_Two  ADHD_Two  0.117146  0.171657   ADHD_Two
# 34  ridge   WISC_FRI  ADHD_Two   Healthy  0.034208  0.353293   ADHD_Two
# 35  ridge   WISC_FRI  ADHD_Two  ADHD_One  0.329308  0.001996   ADHD_Two
# 36  ridge   WISC_WMI   Healthy   Healthy  0.107360  0.209581    Healthy
# 37  ridge   WISC_WMI   Healthy  ADHD_One  0.167983  0.047904    Healthy
# 38  ridge   WISC_WMI   Healthy  ADHD_Two  0.087758  0.159681    Healthy
# 39  ridge   WISC_WMI  ADHD_One  ADHD_One  0.084543  0.253493   ADHD_One
# 40  ridge   WISC_WMI  ADHD_One  ADHD_Two  0.258087  0.001996   ADHD_One
# 41  ridge   WISC_WMI  ADHD_One   Healthy  0.144607  0.045908   ADHD_One
# 42  ridge   WISC_WMI  ADHD_Two  ADHD_Two  0.144758  0.125749   ADHD_Two
# 43  ridge   WISC_WMI  ADHD_Two   Healthy  0.071584  0.225549   ADHD_Two
# 44  ridge   WISC_WMI  ADHD_Two  ADHD_One  0.223011  0.003992   ADHD_Two
# 45  ridge   WISC_PSI   Healthy   Healthy -0.047594  0.636727    Healthy
# 46  ridge   WISC_PSI   Healthy  ADHD_One -0.137510  0.938124    Healthy
# 47  ridge   WISC_PSI   Healthy  ADHD_Two  0.069964  0.241517    Healthy
# 48  ridge   WISC_PSI  ADHD_One  ADHD_One  0.065316  0.285429   ADHD_One
# 49  ridge   WISC_PSI  ADHD_One  ADHD_Two  0.363425  0.001996   ADHD_One
# 50  ridge   WISC_PSI  ADHD_One   Healthy -0.163697  0.974052   ADHD_One
# 51  ridge   WISC_PSI  ADHD_Two  ADHD_Two  0.057417  0.323353   ADHD_Two
# 52  ridge   WISC_PSI  ADHD_Two   Healthy -0.012084  0.566866   ADHD_Two
# 53  ridge   WISC_PSI  ADHD_Two  ADHD_One  0.419328  0.001996   ADHD_Two
#
#     Num Permutations    BFR    FDR
# 0                500  False  False
# 1                500  False   True
# 2                500  False   True
# 3                500  False   True
# 4                500  False   True
# 5                500  False   True
# 6                500  False  False
# 7                500  False  False
# 8                500  False   True
# 9                500  False  False
# 10               500  False   True
# 11               500  False  False
# 12               500  False  False
# 13               500  False   True
# 14               500  False  False
# 15               500  False   True
# 16               500  False  False
# 17               500  False   True
# 18               500  False  False
# 19               500  False   True
# 20               500  False  False
# 21               500  False   True
# 22               500  False   True
# 23               500  False   True
# 24               500  False  False
# 25               500  False  False
# 26               500  False   True
# 27               500  False  False
# 28               500  False   True
# 29               500  False  False
# 30               500  False  False
# 31               500  False   True
# 32               500  False   True
# 33               500  False  False
# 34               500  False  False
# 35               500  False   True
# 36               500  False  False
# 37               500  False  False
# 38               500  False  False
# 39               500  False  False
# 40               500  False   True
# 41               500  False  False
# 42               500  False  False
# 43               500  False  False
# 44               500  False   True
# 45               500  False  False
# 46               500  False  False
# 47               500  False  False
# 48               500  False  False
# 49               500  False   True
# 50               500  False  False
# 51               500  False  False
# 52               500  False  False
# 53               500  False   True

# %% [markdown]
# ## Run correction

# %%
a_threshold = 0.05
df['BFR'] = bonferroni(pvals, alpha=a_threshold)
df['FDR'] = lsu(pvals, q=a_threshold)
display(df.round(4))
# Out:
#     Model     Target     Train      Test   Score  P-value Population  \
# 0   ridge  WISC_FSIQ   Healthy   Healthy  0.0480   0.3613    Healthy
# 1   ridge  WISC_FSIQ   Healthy  ADHD_One  0.3203   0.0020    Healthy
# 2   ridge  WISC_FSIQ   Healthy  ADHD_Two  0.1725   0.0180    Healthy
# 3   ridge  WISC_FSIQ  ADHD_One  ADHD_One  0.2898   0.0140   ADHD_One
# 4   ridge  WISC_FSIQ  ADHD_One  ADHD_Two  0.3605   0.0020   ADHD_One
# 5   ridge  WISC_FSIQ  ADHD_One   Healthy  0.2122   0.0100   ADHD_One
# 6   ridge  WISC_FSIQ  ADHD_Two  ADHD_Two  0.1679   0.0918   ADHD_Two
# 7   ridge  WISC_FSIQ  ADHD_Two   Healthy  0.0958   0.1397   ADHD_Two
# 8   ridge  WISC_FSIQ  ADHD_Two  ADHD_One  0.4389   0.0020   ADHD_Two
# 9   ridge   WISC_VSI   Healthy   Healthy  0.0967   0.2036    Healthy
# 10  ridge   WISC_VSI   Healthy  ADHD_One  0.2472   0.0080    Healthy
# 11  ridge   WISC_VSI   Healthy  ADHD_Two  0.1616   0.0379    Healthy
# 12  ridge   WISC_VSI  ADHD_One  ADHD_One  0.1506   0.1317   ADHD_One
# 13  ridge   WISC_VSI  ADHD_One  ADHD_Two  0.4167   0.0020   ADHD_One
# 14  ridge   WISC_VSI  ADHD_One   Healthy  0.1658   0.0339   ADHD_One
# 15  ridge   WISC_VSI  ADHD_Two  ADHD_Two  0.3056   0.0020   ADHD_Two
# 16  ridge   WISC_VSI  ADHD_Two   Healthy  0.0492   0.2894   ADHD_Two
# 17  ridge   WISC_VSI  ADHD_Two  ADHD_One  0.4130   0.0020   ADHD_Two
# 18  ridge   WISC_VCI   Healthy   Healthy  0.2418   0.0279    Healthy
# 19  ridge   WISC_VCI   Healthy  ADHD_One  0.3963   0.0020    Healthy
# 20  ridge   WISC_VCI   Healthy  ADHD_Two  0.1508   0.0359    Healthy
# 21  ridge   WISC_VCI  ADHD_One  ADHD_One  0.3668   0.0040   ADHD_One
# 22  ridge   WISC_VCI  ADHD_One  ADHD_Two  0.2831   0.0020   ADHD_One
# 23  ridge   WISC_VCI  ADHD_One   Healthy  0.3091   0.0020   ADHD_One
# 24  ridge   WISC_VCI  ADHD_Two  ADHD_Two -0.0122   0.5210   ADHD_Two
# 25  ridge   WISC_VCI  ADHD_Two   Healthy  0.1090   0.1138   ADHD_Two
# 26  ridge   WISC_VCI  ADHD_Two  ADHD_One  0.2915   0.0020   ADHD_Two
# 27  ridge   WISC_FRI   Healthy   Healthy -0.0796   0.7605    Healthy
# 28  ridge   WISC_FRI   Healthy  ADHD_One  0.2371   0.0040    Healthy
# 29  ridge   WISC_FRI   Healthy  ADHD_Two  0.0964   0.1517    Healthy
# 30  ridge   WISC_FRI  ADHD_One  ADHD_One  0.1067   0.1717   ADHD_One
# 31  ridge   WISC_FRI  ADHD_One  ADHD_Two  0.3026   0.0020   ADHD_One
# 32  ridge   WISC_FRI  ADHD_One   Healthy  0.1884   0.0160   ADHD_One
# 33  ridge   WISC_FRI  ADHD_Two  ADHD_Two  0.1171   0.1717   ADHD_Two
# 34  ridge   WISC_FRI  ADHD_Two   Healthy  0.0342   0.3533   ADHD_Two
# 35  ridge   WISC_FRI  ADHD_Two  ADHD_One  0.3293   0.0020   ADHD_Two
# 36  ridge   WISC_WMI   Healthy   Healthy  0.1074   0.2096    Healthy
# 37  ridge   WISC_WMI   Healthy  ADHD_One  0.1680   0.0479    Healthy
# 38  ridge   WISC_WMI   Healthy  ADHD_Two  0.0878   0.1597    Healthy
# 39  ridge   WISC_WMI  ADHD_One  ADHD_One  0.0845   0.2535   ADHD_One
# 40  ridge   WISC_WMI  ADHD_One  ADHD_Two  0.2581   0.0020   ADHD_One
# 41  ridge   WISC_WMI  ADHD_One   Healthy  0.1446   0.0459   ADHD_One
# 42  ridge   WISC_WMI  ADHD_Two  ADHD_Two  0.1448   0.1257   ADHD_Two
# 43  ridge   WISC_WMI  ADHD_Two   Healthy  0.0716   0.2255   ADHD_Two
# 44  ridge   WISC_WMI  ADHD_Two  ADHD_One  0.2230   0.0040   ADHD_Two
# 45  ridge   WISC_PSI   Healthy   Healthy -0.0476   0.6367    Healthy
# 46  ridge   WISC_PSI   Healthy  ADHD_One -0.1375   0.9381    Healthy
# 47  ridge   WISC_PSI   Healthy  ADHD_Two  0.0700   0.2415    Healthy
# 48  ridge   WISC_PSI  ADHD_One  ADHD_One  0.0653   0.2854   ADHD_One
# 49  ridge   WISC_PSI  ADHD_One  ADHD_Two  0.3634   0.0020   ADHD_One
# 50  ridge   WISC_PSI  ADHD_One   Healthy -0.1637   0.9741   ADHD_One
# 51  ridge   WISC_PSI  ADHD_Two  ADHD_Two  0.0574   0.3234   ADHD_Two
# 52  ridge   WISC_PSI  ADHD_Two   Healthy -0.0121   0.5669   ADHD_Two
# 53  ridge   WISC_PSI  ADHD_Two  ADHD_One  0.4193   0.0020   ADHD_Two
#
#     Num Permutations    BFR    FDR
# 0                500  False  False
# 1                500  False   True
# 2                500  False   True
# 3                500  False   True
# 4                500  False   True
# 5                500  False   True
# 6                500  False  False
# 7                500  False  False
# 8                500  False   True
# 9                500  False  False
# 10               500  False   True
# 11               500  False  False
# 12               500  False  False
# 13               500  False   True
# 14               500  False  False
# 15               500  False   True
# 16               500  False  False
# 17               500  False   True
# 18               500  False  False
# 19               500  False   True
# 20               500  False  False
# 21               500  False   True
# 22               500  False   True
# 23               500  False   True
# 24               500  False  False
# 25               500  False  False
# 26               500  False   True
# 27               500  False  False
# 28               500  False   True
# 29               500  False  False
# 30               500  False  False
# 31               500  False   True
# 32               500  False   True
# 33               500  False  False
# 34               500  False  False
# 35               500  False   True
# 36               500  False  False
# 37               500  False  False
# 38               500  False  False
# 39               500  False  False
# 40               500  False   True
# 41               500  False  False
# 42               500  False  False
# 43               500  False  False
# 44               500  False   True
# 45               500  False  False
# 46               500  False  False
# 47               500  False  False
# 48               500  False  False
# 49               500  False   True
# 50               500  False  False
# 51               500  False  False
# 52               500  False  False
# 53               500  False   True

# %% [markdown]
# ## Save and update results file

# %%
df.to_csv(results_path)
