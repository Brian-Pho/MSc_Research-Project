# %% [markdown]
# # Multiple Hypothesis Testing

# %%
from os.path import join

import pandas as pd
import numpy as np
from multipy.fwer import bonferroni
from multipy.fdr import lsu

from common.paths import PLS_RESULTS, RIDGE_RESULTS, CROSS_PRED_RESULTS

# %% [markdown]
# ## Get data

# %% [markdown]
# ### Manual Input

# %%
bin_all = [0.0003, 0.0003, 0.0003, 0.0003, 0.0100, 0.0643]
bin_1 = [0.0953, 0.0313, 0.0593, 0.6485, 0.6048, 0.8287]
bin_2 = [0.0003, 0.0247, 0.0003, 0.0020, 0.0107, 0.4159]
bin_3 = [0.1789, 0.0653, 0.3196, 0.4172, 0.2779, 0.3162]
pvals = np.array(bin_all + bin_1 + bin_2 + bin_3)
df = pd.DataFrame({'Features': ['Feature {}'.format(i) for i in range(1,len(pvals)+1  )], 'P-value':pvals})
display(df)
# Out:
#       Features  P-value
# 0    Feature 1   0.0003
# 1    Feature 2   0.0003
# 2    Feature 3   0.0003
# 3    Feature 4   0.0003
# 4    Feature 5   0.0100
# 5    Feature 6   0.0643
# 6    Feature 7   0.0953
# 7    Feature 8   0.0313
# 8    Feature 9   0.0593
# 9   Feature 10   0.6485
# 10  Feature 11   0.6048
# 11  Feature 12   0.8287
# 12  Feature 13   0.0003
# 13  Feature 14   0.0247
# 14  Feature 15   0.0003
# 15  Feature 16   0.0020
# 16  Feature 17   0.0107
# 17  Feature 18   0.4159
# 18  Feature 19   0.1789
# 19  Feature 20   0.0653
# 20  Feature 21   0.3196
# 21  Feature 22   0.4172
# 22  Feature 23   0.2779
# 23  Feature 24   0.3162

# %% [markdown]
# ### Within-Prediction

# %%
fn = 'pls_pts_adhd.csv'
results_path = join(PLS_RESULTS, fn)
df = pd.read_csv(results_path, index_col=0)
# df['Features'] = df['Target'] + df['Bin']
pvals = df['P-value']
display(df)
# Out:
#    Model Population     Target    Bin     Score   P-value
# 0    pls       adhd  WISC_FSIQ    All  0.373846  0.000333
# 1    pls       adhd  WISC_FSIQ  Bin 1  0.255441  0.014662
# 2    pls       adhd  WISC_FSIQ  Bin 2  0.410544  0.000333
# 3    pls       adhd  WISC_FSIQ  Bin 3  0.076156  0.279573
# 4    pls       adhd   WISC_VSI    All  0.331722  0.000333
# 5    pls       adhd   WISC_VSI  Bin 1  0.235881  0.018994
# 6    pls       adhd   WISC_VSI  Bin 2  0.238640  0.007664
# 7    pls       adhd   WISC_VSI  Bin 3  0.143082  0.119627
# 8    pls       adhd   WISC_VCI    All  0.357835  0.000333
# 9    pls       adhd   WISC_VCI  Bin 1  0.200833  0.041320
# 10   pls       adhd   WISC_VCI  Bin 2  0.396446  0.000666
# 11   pls       adhd   WISC_VCI  Bin 3  0.041413  0.377208
# 12   pls       adhd   WISC_FRI    All  0.308873  0.000333
# 13   pls       adhd   WISC_FRI  Bin 1  0.017405  0.429190
# 14   pls       adhd   WISC_FRI  Bin 2  0.302537  0.001000
# 15   pls       adhd   WISC_FRI  Bin 3  0.062339  0.309563
# 16   pls       adhd   WISC_WMI    All  0.176029  0.004998
# 17   pls       adhd   WISC_WMI  Bin 1  0.048663  0.338221
# 18   pls       adhd   WISC_WMI  Bin 2  0.296202  0.001666
# 19   pls       adhd   WISC_WMI  Bin 3  0.126489  0.152949
# 20   pls       adhd   WISC_PSI    All  0.109169  0.051649
# 21   pls       adhd   WISC_PSI  Bin 1 -0.101896  0.799400
# 22   pls       adhd   WISC_PSI  Bin 2  0.039808  0.359547
# 23   pls       adhd   WISC_PSI  Bin 3  0.090687  0.239254

# %% [markdown]
# ### Cross-Prediction

# %%
fn = 'ridge_pts_age_cross_prediction.csv'
# fn = 'ridge_pts_diagnosis_cross_prediction.csv'
results_path = join(CROSS_PRED_RESULTS, fn)
df = pd.read_csv(results_path, index_col=0)
df = df.reset_index(drop=True)
pvals = df['P-value']
display(df)
# Out:
#     Model     Target  Train   Test     Score   P-value Population  \
# 0   ridge  WISC_FSIQ  Bin 1  Bin 1  0.240653  0.023952       adhd
# 1   ridge  WISC_FSIQ  Bin 1  Bin 2  0.329501  0.001996       adhd
# 2   ridge  WISC_FSIQ  Bin 1  Bin 3  0.212915  0.007984       adhd
# 3   ridge  WISC_FSIQ  Bin 2  Bin 2  0.392312  0.001996       adhd
# 4   ridge  WISC_FSIQ  Bin 2  Bin 3  0.222423  0.005988       adhd
# 5   ridge  WISC_FSIQ  Bin 2  Bin 1  0.329306  0.001996       adhd
# 6   ridge  WISC_FSIQ  Bin 3  Bin 3  0.061523  0.307385       adhd
# 7   ridge  WISC_FSIQ  Bin 3  Bin 1  0.269970  0.001996       adhd
# 8   ridge  WISC_FSIQ  Bin 3  Bin 2  0.281861  0.001996       adhd
# 9   ridge   WISC_VSI  Bin 1  Bin 1  0.227449  0.023952       adhd
# 10  ridge   WISC_VSI  Bin 1  Bin 2  0.398080  0.001996       adhd
# 11  ridge   WISC_VSI  Bin 1  Bin 3  0.121911  0.087824       adhd
# 12  ridge   WISC_VSI  Bin 2  Bin 2  0.241980  0.003992       adhd
# 13  ridge   WISC_VSI  Bin 2  Bin 3  0.172007  0.023952       adhd
# 14  ridge   WISC_VSI  Bin 2  Bin 1  0.366033  0.001996       adhd
# 15  ridge   WISC_VSI  Bin 3  Bin 3  0.053159  0.345309       adhd
# 16  ridge   WISC_VSI  Bin 3  Bin 1  0.148258  0.039920       adhd
# 17  ridge   WISC_VSI  Bin 3  Bin 2  0.264556  0.001996       adhd
# 18  ridge   WISC_VCI  Bin 1  Bin 1  0.219549  0.023952       adhd
# 19  ridge   WISC_VCI  Bin 1  Bin 2  0.337715  0.001996       adhd
# 20  ridge   WISC_VCI  Bin 1  Bin 3  0.285562  0.001996       adhd
# 21  ridge   WISC_VCI  Bin 2  Bin 2  0.385554  0.001996       adhd
# 22  ridge   WISC_VCI  Bin 2  Bin 3  0.207712  0.009980       adhd
# 23  ridge   WISC_VCI  Bin 2  Bin 1  0.296648  0.001996       adhd
# 24  ridge   WISC_VCI  Bin 3  Bin 3  0.072412  0.265469       adhd
# 25  ridge   WISC_VCI  Bin 3  Bin 1  0.373706  0.001996       adhd
# 26  ridge   WISC_VCI  Bin 3  Bin 2  0.235742  0.001996       adhd
# 27  ridge   WISC_FRI  Bin 1  Bin 1  0.096284  0.209581       adhd
# 28  ridge   WISC_FRI  Bin 1  Bin 2  0.156510  0.025948       adhd
# 29  ridge   WISC_FRI  Bin 1  Bin 3  0.116023  0.083832       adhd
# 30  ridge   WISC_FRI  Bin 2  Bin 2  0.310268  0.001996       adhd
# 31  ridge   WISC_FRI  Bin 2  Bin 3  0.286919  0.001996       adhd
# 32  ridge   WISC_FRI  Bin 2  Bin 1  0.178400  0.027944       adhd
# 33  ridge   WISC_FRI  Bin 3  Bin 3  0.030927  0.413174       adhd
# 34  ridge   WISC_FRI  Bin 3  Bin 1  0.104988  0.099800       adhd
# 35  ridge   WISC_FRI  Bin 3  Bin 2  0.313186  0.001996       adhd
# 36  ridge   WISC_WMI  Bin 1  Bin 1  0.073594  0.253493       adhd
# 37  ridge   WISC_WMI  Bin 1  Bin 2  0.036969  0.301397       adhd
# 38  ridge   WISC_WMI  Bin 1  Bin 3  0.134087  0.061876       adhd
# 39  ridge   WISC_WMI  Bin 2  Bin 2  0.296515  0.001996       adhd
# 40  ridge   WISC_WMI  Bin 2  Bin 3  0.205749  0.009980       adhd
# 41  ridge   WISC_WMI  Bin 2  Bin 1  0.037300  0.351297       adhd
# 42  ridge   WISC_WMI  Bin 3  Bin 3  0.136209  0.125749       adhd
# 43  ridge   WISC_WMI  Bin 3  Bin 1 -0.000112  0.473054       adhd
# 44  ridge   WISC_WMI  Bin 3  Bin 2  0.240506  0.001996       adhd
# 45  ridge   WISC_PSI  Bin 1  Bin 1 -0.062387  0.680639       adhd
# 46  ridge   WISC_PSI  Bin 1  Bin 2  0.051284  0.221557       adhd
# 47  ridge   WISC_PSI  Bin 1  Bin 3 -0.026665  0.624750       adhd
# 48  ridge   WISC_PSI  Bin 2  Bin 2  0.046467  0.349301       adhd
# 49  ridge   WISC_PSI  Bin 2  Bin 3 -0.014537  0.574850       adhd
# 50  ridge   WISC_PSI  Bin 2  Bin 1  0.017999  0.417166       adhd
# 51  ridge   WISC_PSI  Bin 3  Bin 3  0.104819  0.185629       adhd
# 52  ridge   WISC_PSI  Bin 3  Bin 1  0.013411  0.425150       adhd
# 53  ridge   WISC_PSI  Bin 3  Bin 2 -0.044998  0.722555       adhd
#
#     Num Permutations    BFR    FDR
# 0                500  False   True
# 1                500  False   True
# 2                500  False   True
# 3                500  False   True
# 4                500  False   True
# 5                500  False   True
# 6                500  False  False
# 7                500  False   True
# 8                500  False   True
# 9                500  False   True
# 10               500  False   True
# 11               500  False  False
# 12               500  False   True
# 13               500  False   True
# 14               500  False   True
# 15               500  False  False
# 16               500  False  False
# 17               500  False   True
# 18               500  False   True
# 19               500  False   True
# 20               500  False   True
# 21               500  False   True
# 22               500  False   True
# 23               500  False   True
# 24               500  False  False
# 25               500  False   True
# 26               500  False   True
# 27               500  False  False
# 28               500  False   True
# 29               500  False  False
# 30               500  False   True
# 31               500  False   True
# 32               500  False  False
# 33               500  False  False
# 34               500  False  False
# 35               500  False   True
# 36               500  False  False
# 37               500  False  False
# 38               500  False  False
# 39               500  False   True
# 40               500  False   True
# 41               500  False  False
# 42               500  False  False
# 43               500  False  False
# 44               500  False   True
# 45               500  False  False
# 46               500  False  False
# 47               500  False  False
# 48               500  False  False
# 49               500  False  False
# 50               500  False  False
# 51               500  False  False
# 52               500  False  False
# 53               500  False  False

# %% [markdown]
# ## Run correction

# %%
a_threshold = 0.05
df['BFR'] = bonferroni(pvals, alpha=a_threshold)
df['FDR'] = lsu(pvals, q=a_threshold)
display(df.round(4))
# Out:
#     Model     Target  Train   Test   Score  P-value Population  \
# 0   ridge  WISC_FSIQ  Bin 1  Bin 1  0.2407   0.0240       adhd
# 1   ridge  WISC_FSIQ  Bin 1  Bin 2  0.3295   0.0020       adhd
# 2   ridge  WISC_FSIQ  Bin 1  Bin 3  0.2129   0.0080       adhd
# 3   ridge  WISC_FSIQ  Bin 2  Bin 2  0.3923   0.0020       adhd
# 4   ridge  WISC_FSIQ  Bin 2  Bin 3  0.2224   0.0060       adhd
# 5   ridge  WISC_FSIQ  Bin 2  Bin 1  0.3293   0.0020       adhd
# 6   ridge  WISC_FSIQ  Bin 3  Bin 3  0.0615   0.3074       adhd
# 7   ridge  WISC_FSIQ  Bin 3  Bin 1  0.2700   0.0020       adhd
# 8   ridge  WISC_FSIQ  Bin 3  Bin 2  0.2819   0.0020       adhd
# 9   ridge   WISC_VSI  Bin 1  Bin 1  0.2274   0.0240       adhd
# 10  ridge   WISC_VSI  Bin 1  Bin 2  0.3981   0.0020       adhd
# 11  ridge   WISC_VSI  Bin 1  Bin 3  0.1219   0.0878       adhd
# 12  ridge   WISC_VSI  Bin 2  Bin 2  0.2420   0.0040       adhd
# 13  ridge   WISC_VSI  Bin 2  Bin 3  0.1720   0.0240       adhd
# 14  ridge   WISC_VSI  Bin 2  Bin 1  0.3660   0.0020       adhd
# 15  ridge   WISC_VSI  Bin 3  Bin 3  0.0532   0.3453       adhd
# 16  ridge   WISC_VSI  Bin 3  Bin 1  0.1483   0.0399       adhd
# 17  ridge   WISC_VSI  Bin 3  Bin 2  0.2646   0.0020       adhd
# 18  ridge   WISC_VCI  Bin 1  Bin 1  0.2195   0.0240       adhd
# 19  ridge   WISC_VCI  Bin 1  Bin 2  0.3377   0.0020       adhd
# 20  ridge   WISC_VCI  Bin 1  Bin 3  0.2856   0.0020       adhd
# 21  ridge   WISC_VCI  Bin 2  Bin 2  0.3856   0.0020       adhd
# 22  ridge   WISC_VCI  Bin 2  Bin 3  0.2077   0.0100       adhd
# 23  ridge   WISC_VCI  Bin 2  Bin 1  0.2966   0.0020       adhd
# 24  ridge   WISC_VCI  Bin 3  Bin 3  0.0724   0.2655       adhd
# 25  ridge   WISC_VCI  Bin 3  Bin 1  0.3737   0.0020       adhd
# 26  ridge   WISC_VCI  Bin 3  Bin 2  0.2357   0.0020       adhd
# 27  ridge   WISC_FRI  Bin 1  Bin 1  0.0963   0.2096       adhd
# 28  ridge   WISC_FRI  Bin 1  Bin 2  0.1565   0.0259       adhd
# 29  ridge   WISC_FRI  Bin 1  Bin 3  0.1160   0.0838       adhd
# 30  ridge   WISC_FRI  Bin 2  Bin 2  0.3103   0.0020       adhd
# 31  ridge   WISC_FRI  Bin 2  Bin 3  0.2869   0.0020       adhd
# 32  ridge   WISC_FRI  Bin 2  Bin 1  0.1784   0.0279       adhd
# 33  ridge   WISC_FRI  Bin 3  Bin 3  0.0309   0.4132       adhd
# 34  ridge   WISC_FRI  Bin 3  Bin 1  0.1050   0.0998       adhd
# 35  ridge   WISC_FRI  Bin 3  Bin 2  0.3132   0.0020       adhd
# 36  ridge   WISC_WMI  Bin 1  Bin 1  0.0736   0.2535       adhd
# 37  ridge   WISC_WMI  Bin 1  Bin 2  0.0370   0.3014       adhd
# 38  ridge   WISC_WMI  Bin 1  Bin 3  0.1341   0.0619       adhd
# 39  ridge   WISC_WMI  Bin 2  Bin 2  0.2965   0.0020       adhd
# 40  ridge   WISC_WMI  Bin 2  Bin 3  0.2057   0.0100       adhd
# 41  ridge   WISC_WMI  Bin 2  Bin 1  0.0373   0.3513       adhd
# 42  ridge   WISC_WMI  Bin 3  Bin 3  0.1362   0.1257       adhd
# 43  ridge   WISC_WMI  Bin 3  Bin 1 -0.0001   0.4731       adhd
# 44  ridge   WISC_WMI  Bin 3  Bin 2  0.2405   0.0020       adhd
# 45  ridge   WISC_PSI  Bin 1  Bin 1 -0.0624   0.6806       adhd
# 46  ridge   WISC_PSI  Bin 1  Bin 2  0.0513   0.2216       adhd
# 47  ridge   WISC_PSI  Bin 1  Bin 3 -0.0267   0.6248       adhd
# 48  ridge   WISC_PSI  Bin 2  Bin 2  0.0465   0.3493       adhd
# 49  ridge   WISC_PSI  Bin 2  Bin 3 -0.0145   0.5749       adhd
# 50  ridge   WISC_PSI  Bin 2  Bin 1  0.0180   0.4172       adhd
# 51  ridge   WISC_PSI  Bin 3  Bin 3  0.1048   0.1856       adhd
# 52  ridge   WISC_PSI  Bin 3  Bin 1  0.0134   0.4251       adhd
# 53  ridge   WISC_PSI  Bin 3  Bin 2 -0.0450   0.7226       adhd
#
#     Num Permutations    BFR    FDR
# 0                500  False   True
# 1                500  False   True
# 2                500  False   True
# 3                500  False   True
# 4                500  False   True
# 5                500  False   True
# 6                500  False  False
# 7                500  False   True
# 8                500  False   True
# 9                500  False   True
# 10               500  False   True
# 11               500  False  False
# 12               500  False   True
# 13               500  False   True
# 14               500  False   True
# 15               500  False  False
# 16               500  False  False
# 17               500  False   True
# 18               500  False   True
# 19               500  False   True
# 20               500  False   True
# 21               500  False   True
# 22               500  False   True
# 23               500  False   True
# 24               500  False  False
# 25               500  False   True
# 26               500  False   True
# 27               500  False  False
# 28               500  False   True
# 29               500  False  False
# 30               500  False   True
# 31               500  False   True
# 32               500  False  False
# 33               500  False  False
# 34               500  False  False
# 35               500  False   True
# 36               500  False  False
# 37               500  False  False
# 38               500  False  False
# 39               500  False   True
# 40               500  False   True
# 41               500  False  False
# 42               500  False  False
# 43               500  False  False
# 44               500  False   True
# 45               500  False  False
# 46               500  False  False
# 47               500  False  False
# 48               500  False  False
# 49               500  False  False
# 50               500  False  False
# 51               500  False  False
# 52               500  False  False
# 53               500  False  False

# %%
m = len(pvals)
sort_ind = np.argsort(pvals)
qs = [(i+1.)*0.05/m for i, p in enumerate(pvals[sort_ind])]
a = pd.DataFrame([(p, q) for p, q in zip(pvals[sort_ind], qs)])
display(a)
# Out:
#            0         1
# 0   0.001996  0.000926
# 1   0.001996  0.001852
# 2   0.001996  0.002778
# 3   0.001996  0.003704
# 4   0.001996  0.004630
# 5   0.001996  0.005556
# 6   0.001996  0.006481
# 7   0.001996  0.007407
# 8   0.001996  0.008333
# 9   0.001996  0.009259
# 10  0.001996  0.010185
# 11  0.001996  0.011111
# 12  0.001996  0.012037
# 13  0.001996  0.012963
# 14  0.001996  0.013889
# 15  0.001996  0.014815
# 16  0.001996  0.015741
# 17  0.001996  0.016667
# 18  0.001996  0.017593
# 19  0.003992  0.018519
# 20  0.005988  0.019444
# 21  0.007984  0.020370
# 22  0.009980  0.021296
# 23  0.009980  0.022222
# 24  0.023952  0.023148
# 25  0.023952  0.024074
# 26  0.023952  0.025000
# 27  0.023952  0.025926
# 28  0.025948  0.026852
# 29  0.027944  0.027778
# 30  0.039920  0.028704
# 31  0.061876  0.029630
# 32  0.083832  0.030556
# 33  0.087824  0.031481
# 34  0.099800  0.032407
# 35  0.125749  0.033333
# 36  0.185629  0.034259
# 37  0.209581  0.035185
# 38  0.221557  0.036111
# 39  0.253493  0.037037
# 40  0.265469  0.037963
# 41  0.301397  0.038889
# 42  0.307385  0.039815
# 43  0.345309  0.040741
# 44  0.349301  0.041667
# 45  0.351297  0.042593
# 46  0.413174  0.043519
# 47  0.417166  0.044444
# 48  0.425150  0.045370
# 49  0.473054  0.046296
# 50  0.574850  0.047222
# 51  0.624750  0.048148
# 52  0.680639  0.049074
# 53  0.722555  0.050000

# %% [markdown]
# ## Save and update results file

# %%
df.to_csv(results_path)
