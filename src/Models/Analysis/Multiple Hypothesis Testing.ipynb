# %% [markdown]
# # Multiple Hypothesis Testing

# %%
from os.path import join

import pandas as pd
import numpy as np
from multipy.fwer import bonferroni
from multipy.fdr import lsu

from common.paths import PLS_RESULTS, RIDGE_RESULTS, CROSS_PRED_RESULTS

# %% [markdown]
# ## Get data

# %% [markdown]
# ### Manual Input

# %%
bin_all = [0.0003, 0.0003, 0.0003, 0.0003, 0.0100, 0.0643]
bin_1 = [0.0953, 0.0313, 0.0593, 0.6485, 0.6048, 0.8287]
bin_2 = [0.0003, 0.0247, 0.0003, 0.0020, 0.0107, 0.4159]
bin_3 = [0.1789, 0.0653, 0.3196, 0.4172, 0.2779, 0.3162]
pvals = np.array(bin_all + bin_1 + bin_2 + bin_3)
df = pd.DataFrame({'Features': ['Feature {}'.format(i) for i in range(1,len(pvals)+1  )], 'P-value':pvals})
display(df)
# Out:
#       Features  P-value
# 0    Feature 1   0.0003
# 1    Feature 2   0.0003
# 2    Feature 3   0.0003
# 3    Feature 4   0.0003
# 4    Feature 5   0.0100
# 5    Feature 6   0.0643
# 6    Feature 7   0.0953
# 7    Feature 8   0.0313
# 8    Feature 9   0.0593
# 9   Feature 10   0.6485
# 10  Feature 11   0.6048
# 11  Feature 12   0.8287
# 12  Feature 13   0.0003
# 13  Feature 14   0.0247
# 14  Feature 15   0.0003
# 15  Feature 16   0.0020
# 16  Feature 17   0.0107
# 17  Feature 18   0.4159
# 18  Feature 19   0.1789
# 19  Feature 20   0.0653
# 20  Feature 21   0.3196
# 21  Feature 22   0.4172
# 22  Feature 23   0.2779
# 23  Feature 24   0.3162

# %% [markdown]
# ### Within-Prediction

# %%
fn = 'pls_pts_adhd.csv'
results_path = join(PLS_RESULTS, fn)
df = pd.read_csv(results_path, index_col=0)
# df['Features'] = df['Target'] + df['Bin']
pvals = df['P-value']
display(df)
# Out:
#    Model Population     Target    Bin     Score   P-value
# 0    pls       adhd  WISC_FSIQ    All  0.373846  0.000333
# 1    pls       adhd  WISC_FSIQ  Bin 1  0.255441  0.014662
# 2    pls       adhd  WISC_FSIQ  Bin 2  0.410544  0.000333
# 3    pls       adhd  WISC_FSIQ  Bin 3  0.076156  0.279573
# 4    pls       adhd   WISC_VSI    All  0.331722  0.000333
# 5    pls       adhd   WISC_VSI  Bin 1  0.235881  0.018994
# 6    pls       adhd   WISC_VSI  Bin 2  0.238640  0.007664
# 7    pls       adhd   WISC_VSI  Bin 3  0.143082  0.119627
# 8    pls       adhd   WISC_VCI    All  0.357835  0.000333
# 9    pls       adhd   WISC_VCI  Bin 1  0.200833  0.041320
# 10   pls       adhd   WISC_VCI  Bin 2  0.396446  0.000666
# 11   pls       adhd   WISC_VCI  Bin 3  0.041413  0.377208
# 12   pls       adhd   WISC_FRI    All  0.308873  0.000333
# 13   pls       adhd   WISC_FRI  Bin 1  0.017405  0.429190
# 14   pls       adhd   WISC_FRI  Bin 2  0.302537  0.001000
# 15   pls       adhd   WISC_FRI  Bin 3  0.062339  0.309563
# 16   pls       adhd   WISC_WMI    All  0.176029  0.004998
# 17   pls       adhd   WISC_WMI  Bin 1  0.048663  0.338221
# 18   pls       adhd   WISC_WMI  Bin 2  0.296202  0.001666
# 19   pls       adhd   WISC_WMI  Bin 3  0.126489  0.152949
# 20   pls       adhd   WISC_PSI    All  0.109169  0.051649
# 21   pls       adhd   WISC_PSI  Bin 1 -0.101896  0.799400
# 22   pls       adhd   WISC_PSI  Bin 2  0.039808  0.359547
# 23   pls       adhd   WISC_PSI  Bin 3  0.090687  0.239254

# %% [markdown]
# ### Cross-Prediction

# %%
# fn = 'ridge_pts_age_cross_prediction.csv'
fn = 'ridge_pts_diagnosis_cross_prediction.csv'
results_path = join(CROSS_PRED_RESULTS, fn)
df = pd.read_csv(results_path, index_col=0)
pvals = df['P-value']
display(df)
# Out:
#     Model     Target  Num Permutations Train Group Test Group     Score  \
# 0   ridge  WISC_FSIQ               500     Healthy    Healthy  0.037646
# 1   ridge  WISC_FSIQ               500     Healthy   ADHD_One  0.190637
# 2   ridge  WISC_FSIQ               500     Healthy   ADHD_Two  0.355227
# 3   ridge  WISC_FSIQ               500    ADHD_One   ADHD_One  0.227197
# 4   ridge  WISC_FSIQ               500    ADHD_One   ADHD_Two  0.367681
# 5   ridge  WISC_FSIQ               500    ADHD_One    Healthy  0.207824
# 6   ridge  WISC_FSIQ               500    ADHD_Two   ADHD_Two  0.347670
# 7   ridge  WISC_FSIQ               500    ADHD_Two    Healthy  0.338976
# 8   ridge  WISC_FSIQ               500    ADHD_Two   ADHD_One  0.287581
# 9   ridge   WISC_VSI               500     Healthy    Healthy  0.122553
# 10  ridge   WISC_VSI               500     Healthy   ADHD_One  0.163075
# 11  ridge   WISC_VSI               500     Healthy   ADHD_Two  0.389912
# 12  ridge   WISC_VSI               500    ADHD_One   ADHD_One  0.195562
# 13  ridge   WISC_VSI               500    ADHD_One   ADHD_Two  0.289886
# 14  ridge   WISC_VSI               500    ADHD_One    Healthy  0.138721
# 15  ridge   WISC_VSI               500    ADHD_Two   ADHD_Two  0.362287
# 16  ridge   WISC_VSI               500    ADHD_Two    Healthy  0.332301
# 17  ridge   WISC_VSI               500    ADHD_Two   ADHD_One  0.231898
# 18  ridge   WISC_VCI               500     Healthy    Healthy  0.241568
# 19  ridge   WISC_VCI               500     Healthy   ADHD_One  0.282255
# 20  ridge   WISC_VCI               500     Healthy   ADHD_Two  0.379624
# 21  ridge   WISC_VCI               500    ADHD_One   ADHD_One  0.228798
# 22  ridge   WISC_VCI               500    ADHD_One   ADHD_Two  0.365261
# 23  ridge   WISC_VCI               500    ADHD_One    Healthy  0.317154
# 24  ridge   WISC_VCI               500    ADHD_Two   ADHD_Two  0.346974
# 25  ridge   WISC_VCI               500    ADHD_Two    Healthy  0.399625
# 26  ridge   WISC_VCI               500    ADHD_Two   ADHD_One  0.289852
# 27  ridge   WISC_FRI               500     Healthy    Healthy -0.098462
# 28  ridge   WISC_FRI               500     Healthy   ADHD_One  0.059023
# 29  ridge   WISC_FRI               500     Healthy   ADHD_Two  0.211176
# 30  ridge   WISC_FRI               500    ADHD_One   ADHD_One  0.120777
# 31  ridge   WISC_FRI               500    ADHD_One   ADHD_Two  0.297933
# 32  ridge   WISC_FRI               500    ADHD_One    Healthy  0.022868
# 33  ridge   WISC_FRI               500    ADHD_Two   ADHD_Two  0.304814
# 34  ridge   WISC_FRI               500    ADHD_Two    Healthy  0.179072
# 35  ridge   WISC_FRI               500    ADHD_Two   ADHD_One  0.207982
# 36  ridge   WISC_WMI               500     Healthy    Healthy  0.113139
# 37  ridge   WISC_WMI               500     Healthy   ADHD_One  0.093647
# 38  ridge   WISC_WMI               500     Healthy   ADHD_Two  0.187696
# 39  ridge   WISC_WMI               500    ADHD_One   ADHD_One  0.198991
# 40  ridge   WISC_WMI               500    ADHD_One   ADHD_Two  0.173989
# 41  ridge   WISC_WMI               500    ADHD_One    Healthy  0.203519
# 42  ridge   WISC_WMI               500    ADHD_Two   ADHD_Two  0.043186
# 43  ridge   WISC_WMI               500    ADHD_Two    Healthy  0.246292
# 44  ridge   WISC_WMI               500    ADHD_Two   ADHD_One  0.191770
# 45  ridge   WISC_PSI               500     Healthy    Healthy -0.035577
# 46  ridge   WISC_PSI               500     Healthy   ADHD_One  0.075753
# 47  ridge   WISC_PSI               500     Healthy   ADHD_Two  0.008548
# 48  ridge   WISC_PSI               500    ADHD_One   ADHD_One  0.015628
# 49  ridge   WISC_PSI               500    ADHD_One   ADHD_Two  0.053795
# 50  ridge   WISC_PSI               500    ADHD_One    Healthy  0.028144
# 51  ridge   WISC_PSI               500    ADHD_Two   ADHD_Two  0.002665
# 52  ridge   WISC_PSI               500    ADHD_Two    Healthy  0.052512
# 53  ridge   WISC_PSI               500    ADHD_Two   ADHD_One  0.077288
#
#      P-value
# 0   0.371257
# 1   0.003992
# 2   0.001996
# 3   0.013972
# 4   0.001996
# 5   0.007984
# 6   0.001996
# 7   0.001996
# 8   0.001996
# 9   0.165669
# 10  0.011976
# 11  0.001996
# 12  0.029940
# 13  0.001996
# 14  0.051896
# 15  0.001996
# 16  0.001996
# 17  0.001996
# 18  0.017964
# 19  0.001996
# 20  0.001996
# 21  0.003992
# 22  0.001996
# 23  0.001996
# 24  0.001996
# 25  0.001996
# 26  0.001996
# 27  0.800399
# 28  0.173653
# 29  0.003992
# 30  0.107784
# 31  0.001996
# 32  0.415170
# 33  0.001996
# 34  0.031936
# 35  0.001996
# 36  0.209581
# 37  0.095808
# 38  0.001996
# 39  0.013972
# 40  0.001996
# 41  0.007984
# 42  0.339321
# 43  0.005988
# 44  0.003992
# 45  0.582834
# 46  0.109780
# 47  0.455090
# 48  0.457086
# 49  0.207585
# 50  0.397206
# 51  0.522954
# 52  0.283433
# 53  0.113772

# %% [markdown]
# ## Run correction

# %%
a_threshold = 0.05
df['BFR'] = bonferroni(pvals, alpha=a_threshold)
df['FDR'] = lsu(pvals, q=a_threshold)
display(df.round(4))
# Out:
#     Model     Target  Num Permutations Train Group Test Group   Score  \
# 0   ridge  WISC_FSIQ               500     Healthy    Healthy  0.0376
# 1   ridge  WISC_FSIQ               500     Healthy   ADHD_One  0.1906
# 2   ridge  WISC_FSIQ               500     Healthy   ADHD_Two  0.3552
# 3   ridge  WISC_FSIQ               500    ADHD_One   ADHD_One  0.2272
# 4   ridge  WISC_FSIQ               500    ADHD_One   ADHD_Two  0.3677
# 5   ridge  WISC_FSIQ               500    ADHD_One    Healthy  0.2078
# 6   ridge  WISC_FSIQ               500    ADHD_Two   ADHD_Two  0.3477
# 7   ridge  WISC_FSIQ               500    ADHD_Two    Healthy  0.3390
# 8   ridge  WISC_FSIQ               500    ADHD_Two   ADHD_One  0.2876
# 9   ridge   WISC_VSI               500     Healthy    Healthy  0.1226
# 10  ridge   WISC_VSI               500     Healthy   ADHD_One  0.1631
# 11  ridge   WISC_VSI               500     Healthy   ADHD_Two  0.3899
# 12  ridge   WISC_VSI               500    ADHD_One   ADHD_One  0.1956
# 13  ridge   WISC_VSI               500    ADHD_One   ADHD_Two  0.2899
# 14  ridge   WISC_VSI               500    ADHD_One    Healthy  0.1387
# 15  ridge   WISC_VSI               500    ADHD_Two   ADHD_Two  0.3623
# 16  ridge   WISC_VSI               500    ADHD_Two    Healthy  0.3323
# 17  ridge   WISC_VSI               500    ADHD_Two   ADHD_One  0.2319
# 18  ridge   WISC_VCI               500     Healthy    Healthy  0.2416
# 19  ridge   WISC_VCI               500     Healthy   ADHD_One  0.2823
# 20  ridge   WISC_VCI               500     Healthy   ADHD_Two  0.3796
# 21  ridge   WISC_VCI               500    ADHD_One   ADHD_One  0.2288
# 22  ridge   WISC_VCI               500    ADHD_One   ADHD_Two  0.3653
# 23  ridge   WISC_VCI               500    ADHD_One    Healthy  0.3172
# 24  ridge   WISC_VCI               500    ADHD_Two   ADHD_Two  0.3470
# 25  ridge   WISC_VCI               500    ADHD_Two    Healthy  0.3996
# 26  ridge   WISC_VCI               500    ADHD_Two   ADHD_One  0.2899
# 27  ridge   WISC_FRI               500     Healthy    Healthy -0.0985
# 28  ridge   WISC_FRI               500     Healthy   ADHD_One  0.0590
# 29  ridge   WISC_FRI               500     Healthy   ADHD_Two  0.2112
# 30  ridge   WISC_FRI               500    ADHD_One   ADHD_One  0.1208
# 31  ridge   WISC_FRI               500    ADHD_One   ADHD_Two  0.2979
# 32  ridge   WISC_FRI               500    ADHD_One    Healthy  0.0229
# 33  ridge   WISC_FRI               500    ADHD_Two   ADHD_Two  0.3048
# 34  ridge   WISC_FRI               500    ADHD_Two    Healthy  0.1791
# 35  ridge   WISC_FRI               500    ADHD_Two   ADHD_One  0.2080
# 36  ridge   WISC_WMI               500     Healthy    Healthy  0.1131
# 37  ridge   WISC_WMI               500     Healthy   ADHD_One  0.0936
# 38  ridge   WISC_WMI               500     Healthy   ADHD_Two  0.1877
# 39  ridge   WISC_WMI               500    ADHD_One   ADHD_One  0.1990
# 40  ridge   WISC_WMI               500    ADHD_One   ADHD_Two  0.1740
# 41  ridge   WISC_WMI               500    ADHD_One    Healthy  0.2035
# 42  ridge   WISC_WMI               500    ADHD_Two   ADHD_Two  0.0432
# 43  ridge   WISC_WMI               500    ADHD_Two    Healthy  0.2463
# 44  ridge   WISC_WMI               500    ADHD_Two   ADHD_One  0.1918
# 45  ridge   WISC_PSI               500     Healthy    Healthy -0.0356
# 46  ridge   WISC_PSI               500     Healthy   ADHD_One  0.0758
# 47  ridge   WISC_PSI               500     Healthy   ADHD_Two  0.0085
# 48  ridge   WISC_PSI               500    ADHD_One   ADHD_One  0.0156
# 49  ridge   WISC_PSI               500    ADHD_One   ADHD_Two  0.0538
# 50  ridge   WISC_PSI               500    ADHD_One    Healthy  0.0281
# 51  ridge   WISC_PSI               500    ADHD_Two   ADHD_Two  0.0027
# 52  ridge   WISC_PSI               500    ADHD_Two    Healthy  0.0525
# 53  ridge   WISC_PSI               500    ADHD_Two   ADHD_One  0.0773
#
#     P-value    BFR    FDR
# 0    0.3713  False  False
# 1    0.0040  False   True
# 2    0.0020  False   True
# 3    0.0140  False   True
# 4    0.0020  False   True
# 5    0.0080  False   True
# 6    0.0020  False   True
# 7    0.0020  False   True
# 8    0.0020  False   True
# 9    0.1657  False  False
# 10   0.0120  False   True
# 11   0.0020  False   True
# 12   0.0299  False   True
# 13   0.0020  False   True
# 14   0.0519  False  False
# 15   0.0020  False   True
# 16   0.0020  False   True
# 17   0.0020  False   True
# 18   0.0180  False   True
# 19   0.0020  False   True
# 20   0.0020  False   True
# 21   0.0040  False   True
# 22   0.0020  False   True
# 23   0.0020  False   True
# 24   0.0020  False   True
# 25   0.0020  False   True
# 26   0.0020  False   True
# 27   0.8004  False  False
# 28   0.1737  False  False
# 29   0.0040  False   True
# 30   0.1078  False  False
# 31   0.0020  False   True
# 32   0.4152  False  False
# 33   0.0020  False   True
# 34   0.0319  False   True
# 35   0.0020  False   True
# 36   0.2096  False  False
# 37   0.0958  False  False
# 38   0.0020  False   True
# 39   0.0140  False   True
# 40   0.0020  False   True
# 41   0.0080  False   True
# 42   0.3393  False  False
# 43   0.0060  False   True
# 44   0.0040  False   True
# 45   0.5828  False  False
# 46   0.1098  False  False
# 47   0.4551  False  False
# 48   0.4571  False  False
# 49   0.2076  False  False
# 50   0.3972  False  False
# 51   0.5230  False  False
# 52   0.2834  False  False
# 53   0.1138  False  False

# %% [markdown]
# ## Save and update results file

# %%
df.to_csv(results_path)
