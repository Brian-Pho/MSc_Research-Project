# %% [markdown]
# # Multiple Hypothesis Testing Correction

# %%
import pandas as pd
import numpy as np

# %load_ext autoreload
# %autoreload 2

import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns
sns.set_theme(
    context="paper", 
    style="whitegrid", 
    font_scale=1.2,
    rc={'figure.figsize': (10, 10), 'figure.dpi': 300}
)

from common.paths import PLS_RESULTS, RIDGE_RESULTS, CROSS_PRED_RESULTS
from common.results import load_results

from multipy.fwer import bonferroni
from multipy.fdr import lsu

# %% [markdown]
# ## Get data

# %% [markdown]
# ### Manual Input

# %%
# bin_all = [0.0003, 0.0003, 0.0003, 0.0003, 0.0100, 0.0643]
# bin_1 = [0.0953, 0.0313, 0.0593, 0.6485, 0.6048, 0.8287]
# bin_2 = [0.0003, 0.0247, 0.0003, 0.0020, 0.0107, 0.4159]
# bin_3 = [0.1789, 0.0653, 0.3196, 0.4172, 0.2779, 0.3162]
# pvals = np.array(bin_all + bin_1 + bin_2 + bin_3)
pvals = np.array([0.3214, 0.0140, 0.0200, 0.5309, 0.1497, 0.4950])
df = pd.DataFrame({'Features': ['Feature {}'.format(i) for i in range(1, len(pvals) + 1)], 'P-value':pvals})
display(df)
# Out:
#     Features  P-value
# 0  Feature 1   0.3214
# 1  Feature 2   0.0140
# 2  Feature 3   0.0200
# 3  Feature 4   0.5309
# 4  Feature 5   0.1497
# 5  Feature 6   0.4950

# %% [markdown]
# ### Within-Prediction

# %%
fn = 'ridge_pts_adhd_two_bins'
df, results_path = load_results(fn, RIDGE_RESULTS)
pvals = df['P-value']
display(df)
# Out:
#     Model Population     Target    Bin  Alpha     Score   P-value
# 0   ridge       adhd  WISC_FSIQ  Bin 1   6401  0.320190  0.001996
# 1   ridge       adhd  WISC_FSIQ  Bin 2   9901  0.191331  0.025948
# 2   ridge       adhd   WISC_VSI  Bin 1   9901  0.313330  0.001996
# 3   ridge       adhd   WISC_VSI  Bin 2   9901  0.182058  0.031936
# 4   ridge       adhd   WISC_VCI  Bin 1    701  0.292524  0.001996
# 5   ridge       adhd   WISC_VCI  Bin 2   9901  0.219886  0.011976
# 6   ridge       adhd   WISC_FRI  Bin 1   9901  0.209537  0.009980
# 7   ridge       adhd   WISC_FRI  Bin 2   7301  0.186734  0.021956
# 8   ridge       adhd   WISC_WMI  Bin 1      1  0.100642  0.143713
# 9   ridge       adhd   WISC_WMI  Bin 2      1  0.150171  0.073852
# 10  ridge       adhd   WISC_PSI  Bin 1      1 -0.107218  0.868263
# 11  ridge       adhd   WISC_PSI  Bin 2    301 -0.032323  0.666667

# %% [markdown]
# ### Cross-Prediction

# %%
# fn = 'ridge_pts_age_cross_prediction'
fn = 'ridge_pts_age_cross_prediction_bin_two_equal_samples'
df, results_path = load_results(fn, CROSS_PRED_RESULTS)
df = df.reset_index(drop=True)
pvals = df['P-value']
display(df)
# Out:
#     Model     Target        Train         Test     Score   P-value Population  \
# 0   ridge  WISC_FSIQ        Bin 1        Bin 1  0.230310  0.023952       adhd
# 1   ridge  WISC_FSIQ        Bin 1  Bin 2 Equal  0.350181  0.001996       adhd
# 2   ridge  WISC_FSIQ        Bin 1        Bin 3  0.207953  0.015968       adhd
# 3   ridge  WISC_FSIQ  Bin 2 Equal  Bin 2 Equal  0.213853  0.033932       adhd
# 4   ridge  WISC_FSIQ  Bin 2 Equal        Bin 3  0.121881  0.079840       adhd
# 5   ridge  WISC_FSIQ  Bin 2 Equal        Bin 1  0.270841  0.001996       adhd
# 6   ridge  WISC_FSIQ        Bin 3        Bin 3  0.090251  0.209581       adhd
# 7   ridge  WISC_FSIQ        Bin 3        Bin 1  0.256395  0.005988       adhd
# 8   ridge  WISC_FSIQ        Bin 3  Bin 2 Equal  0.220301  0.003992       adhd
# 9   ridge   WISC_VSI        Bin 1        Bin 1  0.229323  0.025948       adhd
# 10  ridge   WISC_VSI        Bin 1  Bin 2 Equal  0.221738  0.005988       adhd
# 11  ridge   WISC_VSI        Bin 1        Bin 3  0.022823  0.359281       adhd
# 12  ridge   WISC_VSI  Bin 2 Equal  Bin 2 Equal  0.184109  0.063872       adhd
# 13  ridge   WISC_VSI  Bin 2 Equal        Bin 3  0.101466  0.131737       adhd
# 14  ridge   WISC_VSI  Bin 2 Equal        Bin 1  0.275375  0.001996       adhd
# 15  ridge   WISC_VSI        Bin 3        Bin 3  0.030365  0.437126       adhd
# 16  ridge   WISC_VSI        Bin 3        Bin 1  0.066872  0.225549       adhd
# 17  ridge   WISC_VSI        Bin 3  Bin 2 Equal  0.161490  0.041916       adhd
# 18  ridge   WISC_VCI        Bin 1        Bin 1  0.217868  0.027944       adhd
# 19  ridge   WISC_VCI        Bin 1  Bin 2 Equal  0.368869  0.001996       adhd
# 20  ridge   WISC_VCI        Bin 1        Bin 3  0.253498  0.003992       adhd
# 21  ridge   WISC_VCI  Bin 2 Equal  Bin 2 Equal  0.219027  0.029940       adhd
# 22  ridge   WISC_VCI  Bin 2 Equal        Bin 3  0.211386  0.019960       adhd
# 23  ridge   WISC_VCI  Bin 2 Equal        Bin 1  0.260426  0.003992       adhd
# 24  ridge   WISC_VCI        Bin 3        Bin 3 -0.014559  0.556886       adhd
# 25  ridge   WISC_VCI        Bin 3        Bin 1  0.317421  0.001996       adhd
# 26  ridge   WISC_VCI        Bin 3  Bin 2 Equal  0.228075  0.009980       adhd
# 27  ridge   WISC_FRI        Bin 1        Bin 1  0.005482  0.475050       adhd
# 28  ridge   WISC_FRI        Bin 1  Bin 2 Equal  0.194453  0.007984       adhd
# 29  ridge   WISC_FRI        Bin 1        Bin 3  0.086005  0.151697       adhd
# 30  ridge   WISC_FRI  Bin 2 Equal  Bin 2 Equal  0.215926  0.025948       adhd
# 31  ridge   WISC_FRI  Bin 2 Equal        Bin 3  0.132537  0.073852       adhd
# 32  ridge   WISC_FRI  Bin 2 Equal        Bin 1  0.076650  0.191617       adhd
# 33  ridge   WISC_FRI        Bin 3        Bin 3  0.022186  0.465070       adhd
# 34  ridge   WISC_FRI        Bin 3        Bin 1  0.159073  0.025948       adhd
# 35  ridge   WISC_FRI        Bin 3  Bin 2 Equal  0.286199  0.001996       adhd
# 36  ridge   WISC_WMI        Bin 1        Bin 1  0.054298  0.369261       adhd
# 37  ridge   WISC_WMI        Bin 1  Bin 2 Equal  0.083799  0.167665       adhd
# 38  ridge   WISC_WMI        Bin 1        Bin 3  0.146088  0.051896       adhd
# 39  ridge   WISC_WMI  Bin 2 Equal  Bin 2 Equal  0.171601  0.085828       adhd
# 40  ridge   WISC_WMI  Bin 2 Equal        Bin 3  0.174260  0.029940       adhd
# 41  ridge   WISC_WMI  Bin 2 Equal        Bin 1 -0.002327  0.491018       adhd
# 42  ridge   WISC_WMI        Bin 3        Bin 3  0.157869  0.093812       adhd
# 43  ridge   WISC_WMI        Bin 3        Bin 1 -0.025930  0.624750       adhd
# 44  ridge   WISC_WMI        Bin 3  Bin 2 Equal  0.140916  0.047904       adhd
# 45  ridge   WISC_PSI        Bin 1        Bin 1  0.157869  0.115768       adhd
# 46  ridge   WISC_PSI        Bin 1  Bin 2 Equal -0.025930  0.602794       adhd
# 47  ridge   WISC_PSI        Bin 1        Bin 3  0.140916  0.039920       adhd
# 48  ridge   WISC_PSI  Bin 2 Equal  Bin 2 Equal -0.073607  0.702595       adhd
# 49  ridge   WISC_PSI  Bin 2 Equal        Bin 3  0.009186  0.463074       adhd
# 50  ridge   WISC_PSI  Bin 2 Equal        Bin 1 -0.005219  0.504990       adhd
# 51  ridge   WISC_PSI        Bin 3        Bin 3  0.272045  0.011976       adhd
# 52  ridge   WISC_PSI        Bin 3        Bin 1  0.102195  0.107784       adhd
# 53  ridge   WISC_PSI        Bin 3  Bin 2 Equal  0.070210  0.233533       adhd
#
#     Num Permutations  FDR
# 0                500  NaN
# 1                500  NaN
# 2                500  NaN
# 3                500  NaN
# 4                500  NaN
# 5                500  NaN
# 6                500  NaN
# 7                500  NaN
# 8                500  NaN
# 9                500  NaN
# 10               500  NaN
# 11               500  NaN
# 12               500  NaN
# 13               500  NaN
# 14               500  NaN
# 15               500  NaN
# 16               500  NaN
# 17               500  NaN
# 18               500  NaN
# 19               500  NaN
# 20               500  NaN
# 21               500  NaN
# 22               500  NaN
# 23               500  NaN
# 24               500  NaN
# 25               500  NaN
# 26               500  NaN
# 27               500  NaN
# 28               500  NaN
# 29               500  NaN
# 30               500  NaN
# 31               500  NaN
# 32               500  NaN
# 33               500  NaN
# 34               500  NaN
# 35               500  NaN
# 36               500  NaN
# 37               500  NaN
# 38               500  NaN
# 39               500  NaN
# 40               500  NaN
# 41               500  NaN
# 42               500  NaN
# 43               500  NaN
# 44               500  NaN
# 45               500  NaN
# 46               500  NaN
# 47               500  NaN
# 48               500  NaN
# 49               500  NaN
# 50               500  NaN
# 51               500  NaN
# 52               500  NaN
# 53               500  NaN

# %% [markdown]
# ## Run correction

# %%
a_threshold = 0.05
df['Uncorrected'] = pvals < a_threshold
df['BFR'] = bonferroni(pvals, alpha=a_threshold)
df['FDR'] = lsu(pvals, q=a_threshold)
display(df.round(4))
# Out:
#     Model     Target        Train         Test   Score  P-value Population  \
# 0   ridge  WISC_FSIQ        Bin 1        Bin 1  0.2303   0.0240       adhd
# 1   ridge  WISC_FSIQ        Bin 1  Bin 2 Equal  0.3502   0.0020       adhd
# 2   ridge  WISC_FSIQ        Bin 1        Bin 3  0.2080   0.0160       adhd
# 3   ridge  WISC_FSIQ  Bin 2 Equal  Bin 2 Equal  0.2139   0.0339       adhd
# 4   ridge  WISC_FSIQ  Bin 2 Equal        Bin 3  0.1219   0.0798       adhd
# 5   ridge  WISC_FSIQ  Bin 2 Equal        Bin 1  0.2708   0.0020       adhd
# 6   ridge  WISC_FSIQ        Bin 3        Bin 3  0.0903   0.2096       adhd
# 7   ridge  WISC_FSIQ        Bin 3        Bin 1  0.2564   0.0060       adhd
# 8   ridge  WISC_FSIQ        Bin 3  Bin 2 Equal  0.2203   0.0040       adhd
# 9   ridge   WISC_VSI        Bin 1        Bin 1  0.2293   0.0259       adhd
# 10  ridge   WISC_VSI        Bin 1  Bin 2 Equal  0.2217   0.0060       adhd
# 11  ridge   WISC_VSI        Bin 1        Bin 3  0.0228   0.3593       adhd
# 12  ridge   WISC_VSI  Bin 2 Equal  Bin 2 Equal  0.1841   0.0639       adhd
# 13  ridge   WISC_VSI  Bin 2 Equal        Bin 3  0.1015   0.1317       adhd
# 14  ridge   WISC_VSI  Bin 2 Equal        Bin 1  0.2754   0.0020       adhd
# 15  ridge   WISC_VSI        Bin 3        Bin 3  0.0304   0.4371       adhd
# 16  ridge   WISC_VSI        Bin 3        Bin 1  0.0669   0.2255       adhd
# 17  ridge   WISC_VSI        Bin 3  Bin 2 Equal  0.1615   0.0419       adhd
# 18  ridge   WISC_VCI        Bin 1        Bin 1  0.2179   0.0279       adhd
# 19  ridge   WISC_VCI        Bin 1  Bin 2 Equal  0.3689   0.0020       adhd
# 20  ridge   WISC_VCI        Bin 1        Bin 3  0.2535   0.0040       adhd
# 21  ridge   WISC_VCI  Bin 2 Equal  Bin 2 Equal  0.2190   0.0299       adhd
# 22  ridge   WISC_VCI  Bin 2 Equal        Bin 3  0.2114   0.0200       adhd
# 23  ridge   WISC_VCI  Bin 2 Equal        Bin 1  0.2604   0.0040       adhd
# 24  ridge   WISC_VCI        Bin 3        Bin 3 -0.0146   0.5569       adhd
# 25  ridge   WISC_VCI        Bin 3        Bin 1  0.3174   0.0020       adhd
# 26  ridge   WISC_VCI        Bin 3  Bin 2 Equal  0.2281   0.0100       adhd
# 27  ridge   WISC_FRI        Bin 1        Bin 1  0.0055   0.4750       adhd
# 28  ridge   WISC_FRI        Bin 1  Bin 2 Equal  0.1945   0.0080       adhd
# 29  ridge   WISC_FRI        Bin 1        Bin 3  0.0860   0.1517       adhd
# 30  ridge   WISC_FRI  Bin 2 Equal  Bin 2 Equal  0.2159   0.0259       adhd
# 31  ridge   WISC_FRI  Bin 2 Equal        Bin 3  0.1325   0.0739       adhd
# 32  ridge   WISC_FRI  Bin 2 Equal        Bin 1  0.0766   0.1916       adhd
# 33  ridge   WISC_FRI        Bin 3        Bin 3  0.0222   0.4651       adhd
# 34  ridge   WISC_FRI        Bin 3        Bin 1  0.1591   0.0259       adhd
# 35  ridge   WISC_FRI        Bin 3  Bin 2 Equal  0.2862   0.0020       adhd
# 36  ridge   WISC_WMI        Bin 1        Bin 1  0.0543   0.3693       adhd
# 37  ridge   WISC_WMI        Bin 1  Bin 2 Equal  0.0838   0.1677       adhd
# 38  ridge   WISC_WMI        Bin 1        Bin 3  0.1461   0.0519       adhd
# 39  ridge   WISC_WMI  Bin 2 Equal  Bin 2 Equal  0.1716   0.0858       adhd
# 40  ridge   WISC_WMI  Bin 2 Equal        Bin 3  0.1743   0.0299       adhd
# 41  ridge   WISC_WMI  Bin 2 Equal        Bin 1 -0.0023   0.4910       adhd
# 42  ridge   WISC_WMI        Bin 3        Bin 3  0.1579   0.0938       adhd
# 43  ridge   WISC_WMI        Bin 3        Bin 1 -0.0259   0.6248       adhd
# 44  ridge   WISC_WMI        Bin 3  Bin 2 Equal  0.1409   0.0479       adhd
# 45  ridge   WISC_PSI        Bin 1        Bin 1  0.1579   0.1158       adhd
# 46  ridge   WISC_PSI        Bin 1  Bin 2 Equal -0.0259   0.6028       adhd
# 47  ridge   WISC_PSI        Bin 1        Bin 3  0.1409   0.0399       adhd
# 48  ridge   WISC_PSI  Bin 2 Equal  Bin 2 Equal -0.0736   0.7026       adhd
# 49  ridge   WISC_PSI  Bin 2 Equal        Bin 3  0.0092   0.4631       adhd
# 50  ridge   WISC_PSI  Bin 2 Equal        Bin 1 -0.0052   0.5050       adhd
# 51  ridge   WISC_PSI        Bin 3        Bin 3  0.2720   0.0120       adhd
# 52  ridge   WISC_PSI        Bin 3        Bin 1  0.1022   0.1078       adhd
# 53  ridge   WISC_PSI        Bin 3  Bin 2 Equal  0.0702   0.2335       adhd
#
#     Num Permutations    FDR  Uncorrected
# 0                500  False         True
# 1                500   True         True
# 2                500  False         True
# 3                500  False         True
# 4                500  False        False
# 5                500   True         True
# 6                500  False        False
# 7                500   True         True
# 8                500   True         True
# 9                500  False         True
# 10               500   True         True
# 11               500  False        False
# 12               500  False        False
# 13               500  False        False
# 14               500   True         True
# 15               500  False        False
# 16               500  False        False
# 17               500  False         True
# 18               500  False         True
# 19               500   True         True
# 20               500   True         True
# 21               500  False         True
# 22               500  False         True
# 23               500   True         True
# 24               500  False        False
# 25               500   True         True
# 26               500   True         True
# 27               500  False        False
# 28               500   True         True
# 29               500  False        False
# 30               500  False         True
# 31               500  False        False
# 32               500  False        False
# 33               500  False        False
# 34               500  False         True
# 35               500   True         True
# 36               500  False        False
# 37               500  False        False
# 38               500  False        False
# 39               500  False        False
# 40               500  False         True
# 41               500  False        False
# 42               500  False        False
# 43               500  False        False
# 44               500  False         True
# 45               500  False        False
# 46               500  False        False
# 47               500  False         True
# 48               500  False        False
# 49               500  False        False
# 50               500  False        False
# 51               500   True         True
# 52               500  False        False
# 53               500  False        False

# %% [markdown]
# ## Save and update results file

# %%
df.to_csv(results_path)

# %% [markdown]
# ## Get FDR q

# %%
m = len(pvals)
sort_ind = np.argsort(pvals)
qs = [(i+1.)*0.05/m for i, p in enumerate(pvals[sort_ind])]
a = pd.DataFrame([(p, q) for p, q in zip(pvals[sort_ind], qs)])
display(a)
# Out:
#            0         1
# 0   0.001996  0.000926
# 1   0.001996  0.001852
# 2   0.001996  0.002778
# 3   0.001996  0.003704
# 4   0.001996  0.004630
# 5   0.001996  0.005556
# 6   0.001996  0.006481
# 7   0.001996  0.007407
# 8   0.001996  0.008333
# 9   0.001996  0.009259
# 10  0.001996  0.010185
# 11  0.001996  0.011111
# 12  0.001996  0.012037
# 13  0.001996  0.012963
# 14  0.001996  0.013889
# 15  0.001996  0.014815
# 16  0.001996  0.015741
# 17  0.001996  0.016667
# 18  0.001996  0.017593
# 19  0.003992  0.018519
# 20  0.005988  0.019444
# 21  0.007984  0.020370
# 22  0.009980  0.021296
# 23  0.009980  0.022222
# 24  0.023952  0.023148
# 25  0.023952  0.024074
# 26  0.023952  0.025000
# 27  0.023952  0.025926
# 28  0.025948  0.026852
# 29  0.027944  0.027778
# 30  0.039920  0.028704
# 31  0.061876  0.029630
# 32  0.083832  0.030556
# 33  0.087824  0.031481
# 34  0.099800  0.032407
# 35  0.125749  0.033333
# 36  0.185629  0.034259
# 37  0.209581  0.035185
# 38  0.221557  0.036111
# 39  0.253493  0.037037
# 40  0.265469  0.037963
# 41  0.301397  0.038889
# 42  0.307385  0.039815
# 43  0.345309  0.040741
# 44  0.349301  0.041667
# 45  0.351297  0.042593
# 46  0.413174  0.043519
# 47  0.417166  0.044444
# 48  0.425150  0.045370
# 49  0.473054  0.046296
# 50  0.574850  0.047222
# 51  0.624750  0.048148
# 52  0.680639  0.049074
# 53  0.722555  0.050000

# %% [markdown]
# ## Max Statistic Method

# %%
from common.binning import BIN_LABELS
from common.paths import RIDGE_RESULTS, RIDGE_PSCORES, PLS_RESULTS, PLS_PSCORES
from common.results import save_perm_score, load_perm_score, load_results
from common.wisc import WISC_LEVEL

# %% [markdown]
# ### Merge permutation scores per age bin

# %%
# Only need to run this code block once per model/population to generate merged permutation array
model = 'ridge'
population = 'adhd'

for bin_label in BIN_LABELS:
    bin_perm_scores = []
    
    for target in WISC_LEVEL[5]:
        perm_score = load_perm_score(f'{model}_{population}_{target}_{bin_label}_perm_scores', RIDGE_PSCORES)
        bin_perm_scores.append(perm_score)
    
    bin_perm_scores = np.concatenate(bin_perm_scores)
    print(bin_label, bin_perm_scores.shape)
    save_perm_score(bin_perm_scores, f'{model}_{population}_{bin_label}_perm_scores', RIDGE_PSCORES)
# Out:
# All (3000,)
# Bin 1 (3000,)
# Bin 2 (3000,)
# Bin 3 (3000,)

# %% [markdown]
# ### Load results (true scores)

# %%
model = 'ridge'
population = 'adhd'

df, results_path = load_results(f'{model}_pts_{population}', RIDGE_RESULTS)
# display(df)
# Out:
#     Model Population     Target    Bin  Alpha     Score   P-value    FDR
# 0   ridge       adhd  WISC_FSIQ    All   9901  0.376543  0.001996   True
# 1   ridge       adhd  WISC_FSIQ  Bin 1    701  0.265258  0.019960   True
# 2   ridge       adhd  WISC_FSIQ  Bin 2   5701  0.351665  0.001996   True
# 3   ridge       adhd  WISC_FSIQ  Bin 3      1  0.105539  0.177645  False
# 4   ridge       adhd   WISC_VSI    All   9901  0.311192  0.001996   True
# 5   ridge       adhd   WISC_VSI  Bin 1   9901  0.244930  0.017964   True
# 6   ridge       adhd   WISC_VSI  Bin 2   9901  0.208465  0.021956   True
# 7   ridge       adhd   WISC_VSI  Bin 3   9901  0.087823  0.229541  False
# 8   ridge       adhd   WISC_VCI    All   9601  0.385864  0.001996   True
# 9   ridge       adhd   WISC_VCI  Bin 1      1  0.223335  0.027944  False
# 10  ridge       adhd   WISC_VCI  Bin 2   9901  0.351989  0.001996   True
# 11  ridge       adhd   WISC_VCI  Bin 3   7101  0.037333  0.403194  False
# 12  ridge       adhd   WISC_FRI    All   9901  0.298382  0.001996   True
# 13  ridge       adhd   WISC_FRI  Bin 1   2301  0.047483  0.347305  False
# 14  ridge       adhd   WISC_FRI  Bin 2   8401  0.314251  0.003992   True
# 15  ridge       adhd   WISC_FRI  Bin 3      1 -0.013023  0.518962  False
# 16  ridge       adhd   WISC_WMI    All   5501  0.208207  0.003992   True
# 17  ridge       adhd   WISC_WMI  Bin 1      1  0.048400  0.357285  False
# 18  ridge       adhd   WISC_WMI  Bin 2   4401  0.288574  0.003992   True
# 19  ridge       adhd   WISC_WMI  Bin 3   9901  0.104052  0.183633  False
# 20  ridge       adhd   WISC_PSI    All   9901  0.046321  0.257485  False
# 21  ridge       adhd   WISC_PSI  Bin 1   9901 -0.094083  0.792415  False
# 22  ridge       adhd   WISC_PSI  Bin 2   4401  0.061772  0.263473  False
# 23  ridge       adhd   WISC_PSI  Bin 3      1  0.090228  0.257485  False

# %%
a_threshold = 0.05
bin_threshold_scores = {k: None for k in BIN_LABELS}
max_stat_temp = pd.Series(dtype='bool')

for bin_label in BIN_LABELS:
    bin_perm_scores = load_perm_score(f'{model}_{population}_{bin_label}_perm_scores', RIDGE_PSCORES)
    threshold_index = int(bin_perm_scores.shape[0] * (1 - a_threshold))
    threshold_score = np.sort(bin_perm_scores)[threshold_index]
    bin_threshold_scores[bin_label] = threshold_score
    
    bin_results = df[df['Bin'] == bin_label]
    max_stat_temp = pd.concat([max_stat_temp, threshold_score < bin_results['Score']])

df['Max-stat'] = max_stat_temp
# df.sort_values('Bin')
display(df)
# Out:
#     Model Population     Target    Bin  Alpha     Score   P-value    FDR  \
# 0   ridge       adhd  WISC_FSIQ    All   9901  0.376543  0.001996   True
# 1   ridge       adhd  WISC_FSIQ  Bin 1    701  0.265258  0.019960   True
# 2   ridge       adhd  WISC_FSIQ  Bin 2   5701  0.351665  0.001996   True
# 3   ridge       adhd  WISC_FSIQ  Bin 3      1  0.105539  0.177645  False
# 4   ridge       adhd   WISC_VSI    All   9901  0.311192  0.001996   True
# 5   ridge       adhd   WISC_VSI  Bin 1   9901  0.244930  0.017964   True
# 6   ridge       adhd   WISC_VSI  Bin 2   9901  0.208465  0.021956   True
# 7   ridge       adhd   WISC_VSI  Bin 3   9901  0.087823  0.229541  False
# 8   ridge       adhd   WISC_VCI    All   9601  0.385864  0.001996   True
# 9   ridge       adhd   WISC_VCI  Bin 1      1  0.223335  0.027944  False
# 10  ridge       adhd   WISC_VCI  Bin 2   9901  0.351989  0.001996   True
# 11  ridge       adhd   WISC_VCI  Bin 3   7101  0.037333  0.403194  False
# 12  ridge       adhd   WISC_FRI    All   9901  0.298382  0.001996   True
# 13  ridge       adhd   WISC_FRI  Bin 1   2301  0.047483  0.347305  False
# 14  ridge       adhd   WISC_FRI  Bin 2   8401  0.314251  0.003992   True
# 15  ridge       adhd   WISC_FRI  Bin 3      1 -0.013023  0.518962  False
# 16  ridge       adhd   WISC_WMI    All   5501  0.208207  0.003992   True
# 17  ridge       adhd   WISC_WMI  Bin 1      1  0.048400  0.357285  False
# 18  ridge       adhd   WISC_WMI  Bin 2   4401  0.288574  0.003992   True
# 19  ridge       adhd   WISC_WMI  Bin 3   9901  0.104052  0.183633  False
# 20  ridge       adhd   WISC_PSI    All   9901  0.046321  0.257485  False
# 21  ridge       adhd   WISC_PSI  Bin 1   9901 -0.094083  0.792415  False
# 22  ridge       adhd   WISC_PSI  Bin 2   4401  0.061772  0.263473  False
# 23  ridge       adhd   WISC_PSI  Bin 3      1  0.090228  0.257485  False
#
#     Max-stat
# 0       True
# 1       True
# 2       True
# 3      False
# 4       True
# 5       True
# 6       True
# 7      False
# 8       True
# 9       True
# 10      True
# 11     False
# 12      True
# 13     False
# 14      True
# 15     False
# 16      True
# 17     False
# 18      True
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False

# %% [markdown]
# ### Save and update results file

# %%
df.to_csv(results_path)

# %% [markdown]
# ### Visualize

# %%
for bin_label in BIN_LABELS:
    threshold_score = bin_threshold_scores[bin_label]
    
    g = sns.displot(bin_perm_scores, color='lightgrey', element="step")
    g.fig.subplots_adjust(top=0.9)
    g.fig.suptitle(f'Model: {model}, Population: {population}, {bin_label}, Num Perm: {bin_perm_scores.shape[0]}')
    g.ax.axvline(threshold_score, label='95th', color='black')
    
    for target_idx, target in enumerate(WISC_LEVEL[5]):
        target_score = df.loc[(results['Bin'] == bin_label) & (df['Target'] == target)]['Score']
        target_score = target_score.to_list()[0]
#         print(bin_label, target, target_score)
        g.ax.axvline(target_score, label=target, ls=(0, (3, np.random.randint(1, 6))), color=sns.color_palette()[target_idx])
    g.fig.legend(loc='center left', bbox_to_anchor=(1, 0.5))
