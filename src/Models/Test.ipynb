# %%
import pandas as pd
import numpy as np
#Import the data samples
from multipy.data import neuhaus
#Import the FWER methods 
from multipy.fwer import bonferroni, holm_bonferroni
#Import the FDR methods (LSU is the other name for BH method)
from multipy.fdr import lsu

# %%
a = [0.0003, 0.0003, 0.0003, 0.0003, 0.0100, 0.0643]
b = [0.0953, 0.0313, 0.0593, 0.6485, 0.6048, 0.8287]
c = [0.0003, 0.0247, 0.0003, 0.0020, 0.0107, 0.4159]
d = [0.1789, 0.0653, 0.3196, 0.4172, 0.2779, 0.3162]
pvals = np.array(a + b + c + d)
df = pd.DataFrame({'Features': ['Feature {}'.format(i) for i in range(1,len(pvals)+1  )], 'P-value':pvals})
display(df)
# Out:
#       Features  P-value
# 0    Feature 1   0.0003
# 1    Feature 2   0.0003
# 2    Feature 3   0.0003
# 3    Feature 4   0.0003
# 4    Feature 5   0.0100
# 5    Feature 6   0.0643
# 6    Feature 7   0.0953
# 7    Feature 8   0.0313
# 8    Feature 9   0.0593
# 9   Feature 10   0.6485
# 10  Feature 11   0.6048
# 11  Feature 12   0.8287
# 12  Feature 13   0.0003
# 13  Feature 14   0.0247
# 14  Feature 15   0.0003
# 15  Feature 16   0.0020
# 16  Feature 17   0.0107
# 17  Feature 18   0.4159
# 18  Feature 19   0.1789
# 19  Feature 20   0.0653
# 20  Feature 21   0.3196
# 21  Feature 22   0.4172
# 22  Feature 23   0.2779
# 23  Feature 24   0.3162

# %%
#Set the alpha level for your desired significant level
df['BFR'] = bonferroni(pvals, alpha=0.05)
# df['HBFR'] = holm_bonferroni(pvals, alpha=0.05)
df['FDR'] = lsu(pvals, q=0.05)
display(df)
# Out:
#       Features  P-value    BFR    FDR
# 0    Feature 1   0.0003   True   True
# 1    Feature 2   0.0003   True   True
# 2    Feature 3   0.0003   True   True
# 3    Feature 4   0.0003   True   True
# 4    Feature 5   0.0100  False   True
# 5    Feature 6   0.0643  False  False
# 6    Feature 7   0.0953  False  False
# 7    Feature 8   0.0313  False  False
# 8    Feature 9   0.0593  False  False
# 9   Feature 10   0.6485  False  False
# 10  Feature 11   0.6048  False  False
# 11  Feature 12   0.8287  False  False
# 12  Feature 13   0.0003   True   True
# 13  Feature 14   0.0247  False  False
# 14  Feature 15   0.0003   True   True
# 15  Feature 16   0.0020   True   True
# 16  Feature 17   0.0107  False   True
# 17  Feature 18   0.4159  False  False
# 18  Feature 19   0.1789  False  False
# 19  Feature 20   0.0653  False  False
# 20  Feature 21   0.3196  False  False
# 21  Feature 22   0.4172  False  False
# 22  Feature 23   0.2779  False  False
# 23  Feature 24   0.3162  False  False
