# %% [markdown]
# # Linear Models

# %%
import glob
import os

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Get Data

# %%
def get_subject_from_path(path):
    normalized_path = os.path.normpath(path)
    path_components = normalized_path.split(os.sep)
    return path_components[-2][4:]

# %%
# Search for all functional connectivity files and read them into a
# numpy array.
fc_path = '/imaging3/owenlab/bpho/python_power_fc'
fc_paths = glob.glob(fc_path + '/**/power_fc.npy', recursive=True)

fcs = {}
for path in fc_paths:
    subject_id = get_subject_from_path(path)
    # print(subject_id)
    subject_fc = np.load(path)
    fcs[subject_id] = subject_fc[np.triu_indices(264, k=1)]
print("Number of functional connectivities:", len(fcs))
# Out:
# Number of functional connectivities: 722

# %%
print("Number of features (connections):", fcs["NDARAP912JK3"].shape[0])
# Out:
# Number of features (connections): 34716

# %% [markdown]
# ## Get Labels

# %%
wisc_label_path = "/imaging3/owenlab/bpho/Biobank Labels/Subjects with WISC.csv"
wisc_labels = pd.read_csv(wisc_label_path)
wisc_labels.set_index(keys='assessment WISC,EID', inplace=True)
display(wisc_labels)
# Out:
#                     assessment WISC,Administration  \
# assessment WISC,EID
# NDARAC331VEH                                   All
# NDARAC462DZH                                   All
# NDARAF440XWG                                   All
# NDARAF535XK6                                   All
# NDARAG115LZP                                   All
# ...                                            ...
# NDARPL406KX4                                   All
# NDARRL426AD5                                   All
# NDARTT272WT5                                   All
# NDARVB842ZM8                                   All
# NDARWM848AKP                                   All
#
#                      assessment WISC,Comment_ID assessment WISC,Data_entry  \
# assessment WISC,EID
# NDARAC331VEH                                NaN                   Complete
# NDARAC462DZH                                NaN                   Complete
# NDARAF440XWG                                NaN                   Complete
# NDARAF535XK6                                NaN                   Complete
# NDARAG115LZP                                NaN                   Complete
# ...                                         ...                        ...
# NDARPL406KX4                                NaN                   Complete
# NDARRL426AD5                                NaN                   Complete
# NDARTT272WT5                                NaN                   Complete
# NDARVB842ZM8                                NaN                   Complete
# NDARWM848AKP                                NaN                   Complete
#
#                      assessment WISC,Days_Baseline  assessment WISC,PSCID  \
# assessment WISC,EID
# NDARAC331VEH                                     2                    NaN
# NDARAC462DZH                                    74                    NaN
# NDARAF440XWG                                   104                    NaN
# NDARAF535XK6                                    77                    NaN
# NDARAG115LZP                                   135                    NaN
# ...                                            ...                    ...
# NDARPL406KX4                                   522                    NaN
# NDARRL426AD5                                   119                    NaN
# NDARTT272WT5                                   385                    NaN
# NDARVB842ZM8                                   307                    NaN
# NDARWM848AKP                                   175                    NaN
#
#                     assessment WISC,START_DATE assessment WISC,Season  \
# assessment WISC,EID
# NDARAC331VEH              1901-01-01T07:00:00Z                 Spring
# NDARAC462DZH              1901-01-01T07:00:00Z                 Spring
# NDARAF440XWG              1901-01-01T07:00:00Z                 Spring
# NDARAF535XK6              1901-01-01T07:00:00Z                 Spring
# NDARAG115LZP              1901-01-01T07:00:00Z                 Spring
# ...                                        ...                    ...
# NDARPL406KX4              1901-01-01T07:00:00Z                   Fall
# NDARRL426AD5              1901-01-01T07:00:00Z                   Fall
# NDARTT272WT5              1901-01-01T07:00:00Z                 Summer
# NDARVB842ZM8              1901-01-01T07:00:00Z                 Summer
# NDARWM848AKP              1901-01-01T07:00:00Z                 Spring
#
#                      assessment WISC,Site assessment WISC,Study  \
# assessment WISC,EID
# NDARAC331VEH                            3                   HBN
# NDARAC462DZH                            1                   HBN
# NDARAF440XWG                            3                   HBN
# NDARAF535XK6                            3                   HBN
# NDARAG115LZP                            3                   HBN
# ...                                   ...                   ...
# NDARPL406KX4                            1                   HBN
# NDARRL426AD5                            1                   HBN
# NDARTT272WT5                            1                   HBN
# NDARVB842ZM8                            1                   HBN
# NDARWM848AKP                            3                   HBN
#
#                      assessment WISC,Visit_label  ...  \
# assessment WISC,EID                               ...
# NDARAC331VEH                                 NaN  ...
# NDARAC462DZH                                 NaN  ...
# NDARAF440XWG                                 NaN  ...
# NDARAF535XK6                                 NaN  ...
# NDARAG115LZP                                 NaN  ...
# ...                                          ...  ...
# NDARPL406KX4                                 NaN  ...
# NDARRL426AD5                                 NaN  ...
# NDARTT272WT5                                 NaN  ...
# NDARVB842ZM8                                 NaN  ...
# NDARWM848AKP                                 NaN  ...
#
#                      assessment WISC,WISC_VSI_Sum  \
# assessment WISC,EID
# NDARAC331VEH                                   30
# NDARAC462DZH                                    9
# NDARAF440XWG                                   27
# NDARAF535XK6                                   13
# NDARAG115LZP                                   29
# ...                                           ...
# NDARPL406KX4                                   18
# NDARRL426AD5                                   13
# NDARTT272WT5                                   21
# NDARVB842ZM8                                   12
# NDARWM848AKP                                   10
#
#                      assessment WISC,WISC_Vocab_Raw  \
# assessment WISC,EID
# NDARAC331VEH                                     40
# NDARAC462DZH                                     18
# NDARAF440XWG                                     15
# NDARAF535XK6                                     18
# NDARAG115LZP                                     32
# ...                                             ...
# NDARPL406KX4                                     16
# NDARRL426AD5                                     25
# NDARTT272WT5                                     34
# NDARVB842ZM8                                     26
# NDARWM848AKP                                     37
#
#                      assessment WISC,WISC_Vocab_Scaled  \
# assessment WISC,EID
# NDARAC331VEH                                        13
# NDARAC462DZH                                        10
# NDARAF440XWG                                         9
# NDARAF535XK6                                         4
# NDARAG115LZP                                         9
# ...                                                ...
# NDARPL406KX4                                         7
# NDARRL426AD5                                         9
# NDARTT272WT5                                        11
# NDARVB842ZM8                                         9
# NDARWM848AKP                                        11
#
#                      assessment WISC,WISC_WMI  \
# assessment WISC,EID
# NDARAC331VEH                              110
# NDARAC462DZH                               76
# NDARAF440XWG                              110
# NDARAF535XK6                               97
# NDARAG115LZP                               91
# ...                                       ...
# NDARPL406KX4                               88
# NDARRL426AD5                               91
# NDARTT272WT5                              100
# NDARVB842ZM8                              117
# NDARWM848AKP                               74
#
#                      assessment WISC,WISC_WMI_Percentile  \
# assessment WISC,EID
# NDARAC331VEH                                        75.0
# NDARAC462DZH                                         5.0
# NDARAF440XWG                                        75.0
# NDARAF535XK6                                        42.0
# NDARAG115LZP                                        27.0
# ...                                                  ...
# NDARPL406KX4                                        21.0
# NDARRL426AD5                                        27.0
# NDARTT272WT5                                        50.0
# NDARVB842ZM8                                        87.0
# NDARWM848AKP                                         4.0
#
#                      assessment WISC,WISC_WMI_Sum  \
# assessment WISC,EID
# NDARAC331VEH                                   23
# NDARAC462DZH                                   12
# NDARAF440XWG                                   23
# NDARAF535XK6                                   19
# NDARAG115LZP                                   17
# ...                                           ...
# NDARPL406KX4                                   16
# NDARRL426AD5                                   17
# NDARTT272WT5                                   20
# NDARVB842ZM8                                   26
# NDARWM848AKP                                   11
#
#                      assessment WISC,WISC_complete  \
# assessment WISC,EID
# NDARAC331VEH                                     1
# NDARAC462DZH                                     1
# NDARAF440XWG                                     1
# NDARAF535XK6                                     1
# NDARAG115LZP                                     1
# ...                                            ...
# NDARPL406KX4                                     1
# NDARRL426AD5                                     1
# NDARTT272WT5                                     1
# NDARVB842ZM8                                     1
# NDARWM848AKP                                     1
#
#                      assessment WISC,WISC_incomplete_reason  \
# assessment WISC,EID
# NDARAC331VEH                                            NaN
# NDARAC462DZH                                            NaN
# NDARAF440XWG                                            NaN
# NDARAF535XK6                                            NaN
# NDARAG115LZP                                            NaN
# ...                                                     ...
# NDARPL406KX4                                            NaN
# NDARRL426AD5                                            NaN
# NDARTT272WT5                                            NaN
# NDARVB842ZM8                                            NaN
# NDARWM848AKP                                            NaN
#
#                      assessment WISC,Year  assessment Basic_Demos,Age
# assessment WISC,EID
# NDARAC331VEH                         2019                   14.167351
# NDARAC462DZH                         2019                    7.957449
# NDARAF440XWG                         2019                    7.253593
# NDARAF535XK6                         2019                   13.121492
# NDARAG115LZP                         2018                   14.167351
# ...                                   ...                         ...
# NDARPL406KX4                         2018                    8.672370
# NDARRL426AD5                         2018                   11.234998
# NDARTT272WT5                         2019                   12.537759
# NDARVB842ZM8                         2019                   11.243326
# NDARWM848AKP                         2018                   15.032511
#
# [425 rows x 52 columns]

# %%
label_subject_ids = wisc_labels.index
subject_ages = wisc_labels["assessment Basic_Demos,Age"].to_numpy()
subjects_with_wisc = {}

for subject_id in label_subject_ids:
    if subject_id not in fcs:
        continue
    
    subject_wisc_fsiq_sum = wisc_labels.at[subject_id, 'assessment WISC,WISC_FSIQ_Sum']
    subjects_with_wisc[subject_id] = (fcs[subject_id], subject_wisc_fsiq_sum)

print(subjects_with_wisc['NDARAC331VEH'])
# Out:
# (array([ 0.58186466, -0.05859981,  0.08431777, ...,  0.39561737,
#         0.3742862 ,  0.6218255 ], dtype=float32), 89)

# %%
fc_matrices = []
wisc_measure = []

for features in subjects_with_wisc.values():
    fc_matrices.append(features[0])
    wisc_measure.append(features[1])

X = np.array(fc_matrices)
y = np.array(wisc_measure)

print("X shape:", X.shape, "y shape:", y.shape)
# Out:
# X shape: (425, 34716) y shape: (425,)

# %% [markdown]
# ## Display Age with Score

# %%
print("Average IQ:", np.mean(y))

plt.figure(1, figsize=(10, 10))
plt.scatter(subject_ages, y, alpha=0.3, label='Ground Truth')
plt.title("Age vs IQ")
plt.xlabel('Age')
plt.ylabel('IQ')
plt.show()
# Out:
# Average IQ: 70.84941176470588

# %% [markdown]
# ## Dimensionality Reduction
# I'm following the guide here: <https://scikit-learn.org/stable/auto_examples/cross_decomposition/plot_pcr_vs_pls.html>.

# %%
from sklearn.linear_model import LinearRegression
from sklearn.cross_decomposition import PLSRegression
from sklearn.decomposition import PCA, FastICA
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler

# %%
pcr = make_pipeline(StandardScaler(), PCA(n_components=1), LinearRegression())
pcr.fit(X, y)

pls = PLSRegression(n_components=1)
pls.fit(X, y)
# Out:
# PLSRegression(n_components=1)

# %%
pca = pcr.named_steps['pca']
X_pca = pca.transform(X)

print(pca.explained_variance_ratio_, np.sum(pca.explained_variance_ratio_))
print(pca.components_.shape)
print(X_pca.shape)

X_pls = pls.transform(X)
print(X_pls.shape)
# Out:
# [0.21051498] 0.21051498
# (1, 34716)
# (425, 1)
# (425, 1)

# %%
reg = pcr.named_steps['linearregression']
y_pcr_pred = reg.predict(X_pca)
y_pls_pred = pls.predict(X)

print("PCR Coef:", reg.coef_)
print("PCR r^2:", reg.score(X_pca, y))
print("PLS r^2:", pls.score(X, y))
# Out:
# PCR Coef: [-0.01682519]
# PCR r^2: 0.0017985146684365017
# PLS r^2: 0.0576099785179951

# %%
plt.figure(1, figsize=(10, 10))
scatter = plt.scatter(X_pca, y, c=subject_ages, alpha=0.3, label='Ground Truth')
plt.plot(X_pca, y_pcr_pred, alpha=0.5, color='red', label="Predictions")
plt.title("PCR / PCA")
plt.xlabel('Data projected onto first PCA component')
plt.ylabel('IQ')
plt.legend(*scatter.legend_elements())
plt.show()

# %%
plt.figure(1, figsize=(10, 10))
plt.scatter(X_pls, y, c=subject_ages, alpha=0.3, label='Ground Truth')
plt.plot(X_pls, y_pls_pred, alpha=0.5, color='red', label="Predictions")
plt.title("PLS")
plt.xlabel('Data projected data onto first PLS component')
plt.ylabel('IQ')
plt.legend(*scatter.legend_elements())
plt.show()

# %% [markdown]
# ## Feature Selection

# %%
from sklearn.feature_selection import (
    VarianceThreshold, SelectKBest, chi2, mutual_info_regression)

# %%
var_thres = VarianceThreshold(threshold=0.12)
X_var_thres = var_thres.fit_transform(X)

print(X_var_thres.shape)
# Out:
# (425, 1)

# %%
reg = LinearRegression().fit(X_var_thres, y)
y_var_thres = reg.predict(X_var_thres)

print("LR w/ Variance Threshold:", reg.score(X_var_thres, y))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-e8ba3b70a740> in <module>
# ----> 1 reg = LinearRegression().fit(X_var_thres, y)
#       2 y_var_thres = reg.predict(X_var_thres)
#       3
#       4 print("LR w/ Variance Threshold:", reg.score(X_var_thres, y))
#
# NameError: name 'LinearRegression' is not defined

# %%
plt.figure(1, figsize=(10, 10))
plt.scatter(X_var_thres, y, c=subject_ages, alpha=0.3, label='Ground Truth')
plt.plot(X_var_thres, y_var_thres, alpha=0.5, color='red', label="Predictions")
plt.title("Variance Threshold")
plt.xlabel('Feature with highest variance')
plt.ylabel('y')
plt.legend(*scatter.legend_elements())
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-f6acb41eee93> in <module>
#       1 plt.figure(1, figsize=(10, 10))
#       2 plt.scatter(X_var_thres, y, c=subject_ages, alpha=0.3, label='Ground Truth')
# ----> 3 plt.plot(X_var_thres, y_var_thres, alpha=0.5, color='red', label="Predictions")
#       4 plt.title("Variance Threshold")
#       5 plt.xlabel('Feature with highest variance')
#
# NameError: name 'y_var_thres' is not defined

# %%
X_mutual_info = SelectKBest(
    mutual_info_regression, k=1).fit_transform(X, y)

print(X_mutual_info.shape)
# Out:
# (425, 1)

# %%
reg = LinearRegression().fit(X_mutual_info, y)
y_mutual_info = reg.predict(X_mutual_info)

print("LR w/ Mutual Information:", reg.score(X_mutual_info, y))
# Out:
# LR w/ Mutual Information: 0.00221883796764466

# %%
plt.figure(1, figsize=(10, 10))
plt.scatter(X_mutual_info, y, c=subject_ages, alpha=0.3, label='Ground Truth')
plt.plot(X_mutual_info, y_mutual_info, alpha=0.5, color='red', label="Predictions")
plt.title("Mutual Information")
plt.xlabel('Feature with highest mutual information')
plt.ylabel('y') 
plt.legend(*scatter.legend_elements())
plt.show()
