# %% [markdown]
# # Dataset Statistics

# %%
import pandas as pd
import numpy as np

# %load_ext autoreload
# %autoreload 2

import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import seaborn as sns
sns.set_context("poster")
sns.set(rc={'figure.figsize': (10, 10)})
sns.set_style("whitegrid")

# %% [markdown]
# ## Get Data

# %%
from common.data import get_data

X, y, ages = get_data()

selected_measure = "WISC_FSIQ"
y = np.array(y[selected_measure])

print("X shape:", X.shape, "y shape:", y.shape)
# Out:
# X shape: (577, 34716) y shape: (577,)

# %%
X_mean, X_std = np.mean(X, axis=0), np.std(X, axis=0)
y_mean, y_std = np.mean(y), np.std(y)

print(X_mean[:5], X_std[:5])
print(y_mean, y_std)
# Out:
# [0.6564762  0.21296296 0.22696462 0.195556   0.09254488] [0.20114204 0.23459214 0.2545439  0.25206465 0.20614325]
# 101.10225303292894 16.948436790902335

# %%
plt.hist(y, density=True)
plt.show()
