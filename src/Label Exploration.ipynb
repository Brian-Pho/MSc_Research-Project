# %% [markdown]
# # Label Exploration

# %% [markdown]
# ## Count the number of subjects with labels

# %%
import csv
from os import listdir
from os.path import exists

import pandas as pd
import matplotlib.pyplot as plt

# %%
# label_file_path = r"/imaging3/owenlab/bpho/Biobank Labels/BehavData.csv"
label_file_path = r"/imaging3/owenlab/bpho/Biobank Labels/data-2020-07-21T15_31_07.904Z.csv"

# %%
label_subject_ids = set()

with open(label_file_path) as csvfile:
    reader = csv.DictReader(csvfile)
    label_subject_ids = label_subject_ids.union(
        {row['assessment WISC,EID'] for row in reader})

# print(label_subject_ids)
print("Number of labels:", len(label_subject_ids))
# Out:
# Number of labels: 2279

# %%
data_subject_ids = set()

for age in range(5, 19):
    age_dir = f'/imaging3/owenlab/bpho/python_power_fc/Age{age}'
    
    if not exists(age_dir):
        continue
    
    data_subject_ids = data_subject_ids.union(
        {folder[4:] for folder in listdir(age_dir) if folder.startswith("sub-")})

    
print("Number of subjects:", len(data_subject_ids))
# Out:
# Number of subjects: 722

# %%
subjects_with_labels = label_subject_ids.intersection(data_subject_ids)
# print(subjects_with_labels)
print("Number of subjects with labels:", len(subjects_with_labels))
# Out:
# Number of subjects with labels: 438

# %% [markdown]
# ## Pandas Section (Write Labels to CSV)

# %%
subjects = pd.DataFrame(data_subject_ids, columns=['assessment WISC,EID'], dtype='str')
labels = pd.read_csv(label_file_path, dtype='str')
ages = labels["assessment Basic_Demos,Age"]
labels = labels.filter(like="WISC").join(ages)

display(subjects)
display(labels)
# Out:
#     assessment WISC,EID
# 0          NDARXD907ZJL
# 1          NDARFX508WPN
# 2          NDARER379GTP
# 3          NDARKD590VF4
# 4          NDARNT225UVD
# ..                  ...
# 717        NDARLB671TLU
# 718        NDARPJ001BVE
# 719        NDARHM611GDR
# 720        NDARUC715YN4
# 721        NDARCG785NND
#
# [722 rows x 1 columns]
#      assessment WISC,Administration assessment WISC,Comment_ID  \
# 0                               All                        NaN
# 1                               All                        NaN
# 2                                 .                          .
# 3                               All                        NaN
# 4                               All                        NaN
# ...                             ...                        ...
# 4186                              .                          .
# 4187                              .                          .
# 4188                              .                          .
# 4189                              .                          .
# 4190                              .                          .
#
#      assessment WISC,Data_entry assessment WISC,Days_Baseline  \
# 0                      Complete                           NaN
# 1                      Complete                            15
# 2                             .                             .
# 3                      Complete                            70
# 4                      Complete                             5
# ...                         ...                           ...
# 4186                          .                             .
# 4187                          .                             .
# 4188                          .                             .
# 4189                          .                             .
# 4190                          .                             .
#
#      assessment WISC,EID assessment WISC,PSCID assessment WISC,START_DATE  \
# 0                    NaN                   NaN                        NaN
# 1           NDARAA075AMK                   NaN       1901-01-01T07:00:00Z
# 2                      .                     .                          .
# 3           NDARAA117NEJ                   NaN       1901-01-01T07:00:00Z
# 4           NDARAA504CRN                   NaN       1901-01-01T07:00:00Z
# ...                  ...                   ...                        ...
# 4186                   .                     .                          .
# 4187                   .                     .                          .
# 4188                   .                     .                          .
# 4189                   .                     .                          .
# 4190                   .                     .                          .
#
#      assessment WISC,Season assessment WISC,Site assessment WISC,Study  ...  \
# 0                       NaN                  NaN                   NaN  ...
# 1                    Summer                    2                   HBN  ...
# 2                         .                    .                     .  ...
# 3                    Winter                    1                   HBN  ...
# 4                    Spring                    3                   HBN  ...
# ...                     ...                  ...                   ...  ...
# 4186                      .                    .                     .  ...
# 4187                      .                    .                     .  ...
# 4188                      .                    .                     .  ...
# 4189                      .                    .                     .  ...
# 4190                      .                    .                     .  ...
#
#      assessment WISC,WISC_VSI_Sum assessment WISC,WISC_Vocab_Raw  \
# 0                             NaN                            NaN
# 1                              28                             32
# 2                               .                              .
# 3                              14                             18
# 4                              21                             21
# ...                           ...                            ...
# 4186                            .                              .
# 4187                            .                              .
# 4188                            .                              .
# 4189                            .                              .
# 4190                            .                              .
#
#      assessment WISC,WISC_Vocab_Scaled assessment WISC,WISC_WMI  \
# 0                                  NaN                      NaN
# 1                                   18                      155
# 2                                    .                        .
# 3                                   11                       85
# 4                                    9                       97
# ...                                ...                      ...
# 4186                                 .                        .
# 4187                                 .                        .
# 4188                                 .                        .
# 4189                                 .                        .
# 4190                                 .                        .
#
#      assessment WISC,WISC_WMI_Percentile assessment WISC,WISC_WMI_Sum  \
# 0                                    NaN                          NaN
# 1                                   99.9                           38
# 2                                      .                            .
# 3                                     16                           15
# 4                                     42                           19
# ...                                  ...                          ...
# 4186                                   .                            .
# 4187                                   .                            .
# 4188                                   .                            .
# 4189                                   .                            .
# 4190                                   .                            .
#
#      assessment WISC,WISC_complete assessment WISC,WISC_incomplete_reason  \
# 0                              NaN                                    NaN
# 1                                1                                    NaN
# 2                                .                                      .
# 3                                1                                    NaN
# 4                                1                                    NaN
# ...                            ...                                    ...
# 4186                             .                                      .
# 4187                             .                                      .
# 4188                             .                                      .
# 4189                             .                                      .
# 4190                             .                                      .
#
#      assessment WISC,Year assessment Basic_Demos,Age
# 0                     NaN                          .
# 1                    2016                    6.72804
# 2                       .                   5.545744
# 3                    2017                   7.475929
# 4                    2019                   9.165297
# ...                   ...                        ...
# 4186                    .                          .
# 4187                    .                          .
# 4188                    .                          .
# 4189                    .                          .
# 4190                    .                          .
#
# [4191 rows x 53 columns]

# %%
subjects_with_labels = labels.merge(subjects, on='assessment WISC,EID')
subjects_with_labels.set_index(keys='assessment WISC,EID', inplace=True)
display(subjects_with_labels)
# Out:
#                     assessment WISC,Administration assessment WISC,Comment_ID  \
# assessment WISC,EID
# NDARAC331VEH                                   All                        NaN
# NDARAC462DZH                                   All                        NaN
# NDARAF440XWG                                   All                        NaN
# NDARAF535XK6                                   All                        NaN
# NDARAG115LZP                                   All                        NaN
# ...                                            ...                        ...
# NDARRL426AD5                                   All                        NaN
# NDARTT272WT5                                   All                        NaN
# NDARVB842ZM8                                   All                        NaN
# NDARWM848AKP                                   All                        NaN
# NDARYB392JWP                                   All                        NaN
#
#                     assessment WISC,Data_entry assessment WISC,Days_Baseline  \
# assessment WISC,EID
# NDARAC331VEH                          Complete                             2
# NDARAC462DZH                          Complete                            74
# NDARAF440XWG                          Complete                           104
# NDARAF535XK6                          Complete                            77
# NDARAG115LZP                          Complete                           135
# ...                                        ...                           ...
# NDARRL426AD5                          Complete                           119
# NDARTT272WT5                          Complete                           385
# NDARVB842ZM8                          Complete                           307
# NDARWM848AKP                          Complete                           175
# NDARYB392JWP                          Complete                           128
#
#                     assessment WISC,PSCID assessment WISC,START_DATE  \
# assessment WISC,EID
# NDARAC331VEH                          NaN       1901-01-01T07:00:00Z
# NDARAC462DZH                          NaN       1901-01-01T07:00:00Z
# NDARAF440XWG                          NaN       1901-01-01T07:00:00Z
# NDARAF535XK6                          NaN       1901-01-01T07:00:00Z
# NDARAG115LZP                          NaN       1901-01-01T07:00:00Z
# ...                                   ...                        ...
# NDARRL426AD5                          NaN       1901-01-01T07:00:00Z
# NDARTT272WT5                          NaN       1901-01-01T07:00:00Z
# NDARVB842ZM8                          NaN       1901-01-01T07:00:00Z
# NDARWM848AKP                          NaN       1901-01-01T07:00:00Z
# NDARYB392JWP                          NaN       1901-01-01T07:00:00Z
#
#                     assessment WISC,Season assessment WISC,Site  \
# assessment WISC,EID
# NDARAC331VEH                        Spring                    3
# NDARAC462DZH                        Spring                    1
# NDARAF440XWG                        Spring                    3
# NDARAF535XK6                        Spring                    3
# NDARAG115LZP                        Spring                    3
# ...                                    ...                  ...
# NDARRL426AD5                          Fall                    1
# NDARTT272WT5                        Summer                    1
# NDARVB842ZM8                        Summer                    1
# NDARWM848AKP                        Spring                    3
# NDARYB392JWP                        Winter                    1
#
#                     assessment WISC,Study assessment WISC,Visit_label  ...  \
# assessment WISC,EID                                                    ...
# NDARAC331VEH                          HBN                         NaN  ...
# NDARAC462DZH                          HBN                         NaN  ...
# NDARAF440XWG                          HBN                         NaN  ...
# NDARAF535XK6                          HBN                         NaN  ...
# NDARAG115LZP                          HBN                         NaN  ...
# ...                                   ...                         ...  ...
# NDARRL426AD5                          HBN                         NaN  ...
# NDARTT272WT5                          HBN                         NaN  ...
# NDARVB842ZM8                          HBN                         NaN  ...
# NDARWM848AKP                          HBN                         NaN  ...
# NDARYB392JWP                          HBN                         NaN  ...
#
#                     assessment WISC,WISC_VSI_Sum  \
# assessment WISC,EID
# NDARAC331VEH                                  30
# NDARAC462DZH                                   9
# NDARAF440XWG                                  27
# NDARAF535XK6                                  13
# NDARAG115LZP                                  29
# ...                                          ...
# NDARRL426AD5                                  13
# NDARTT272WT5                                  21
# NDARVB842ZM8                                  12
# NDARWM848AKP                                  10
# NDARYB392JWP                                 NaN
#
#                     assessment WISC,WISC_Vocab_Raw  \
# assessment WISC,EID
# NDARAC331VEH                                    40
# NDARAC462DZH                                    18
# NDARAF440XWG                                    15
# NDARAF535XK6                                    18
# NDARAG115LZP                                    32
# ...                                            ...
# NDARRL426AD5                                    25
# NDARTT272WT5                                    34
# NDARVB842ZM8                                    26
# NDARWM848AKP                                    37
# NDARYB392JWP                                   NaN
#
#                     assessment WISC,WISC_Vocab_Scaled  \
# assessment WISC,EID
# NDARAC331VEH                                       13
# NDARAC462DZH                                       10
# NDARAF440XWG                                        9
# NDARAF535XK6                                        4
# NDARAG115LZP                                        9
# ...                                               ...
# NDARRL426AD5                                        9
# NDARTT272WT5                                       11
# NDARVB842ZM8                                        9
# NDARWM848AKP                                       11
# NDARYB392JWP                                      NaN
#
#                     assessment WISC,WISC_WMI  \
# assessment WISC,EID
# NDARAC331VEH                             110
# NDARAC462DZH                              76
# NDARAF440XWG                             110
# NDARAF535XK6                              97
# NDARAG115LZP                              91
# ...                                      ...
# NDARRL426AD5                              91
# NDARTT272WT5                             100
# NDARVB842ZM8                             117
# NDARWM848AKP                              74
# NDARYB392JWP                             NaN
#
#                     assessment WISC,WISC_WMI_Percentile  \
# assessment WISC,EID
# NDARAC331VEH                                         75
# NDARAC462DZH                                          5
# NDARAF440XWG                                         75
# NDARAF535XK6                                         42
# NDARAG115LZP                                         27
# ...                                                 ...
# NDARRL426AD5                                         27
# NDARTT272WT5                                         50
# NDARVB842ZM8                                         87
# NDARWM848AKP                                          4
# NDARYB392JWP                                        NaN
#
#                     assessment WISC,WISC_WMI_Sum  \
# assessment WISC,EID
# NDARAC331VEH                                  23
# NDARAC462DZH                                  12
# NDARAF440XWG                                  23
# NDARAF535XK6                                  19
# NDARAG115LZP                                  17
# ...                                          ...
# NDARRL426AD5                                  17
# NDARTT272WT5                                  20
# NDARVB842ZM8                                  26
# NDARWM848AKP                                  11
# NDARYB392JWP                                 NaN
#
#                     assessment WISC,WISC_complete  \
# assessment WISC,EID
# NDARAC331VEH                                    1
# NDARAC462DZH                                    1
# NDARAF440XWG                                    1
# NDARAF535XK6                                    1
# NDARAG115LZP                                    1
# ...                                           ...
# NDARRL426AD5                                    1
# NDARTT272WT5                                    1
# NDARVB842ZM8                                    1
# NDARWM848AKP                                    1
# NDARYB392JWP                                    0
#
#                     assessment WISC,WISC_incomplete_reason  \
# assessment WISC,EID
# NDARAC331VEH                                           NaN
# NDARAC462DZH                                           NaN
# NDARAF440XWG                                           NaN
# NDARAF535XK6                                           NaN
# NDARAG115LZP                                           NaN
# ...                                                    ...
# NDARRL426AD5                                           NaN
# NDARTT272WT5                                           NaN
# NDARVB842ZM8                                           NaN
# NDARWM848AKP                                           NaN
# NDARYB392JWP                                   Dropped HBN
#
#                     assessment WISC,Year assessment Basic_Demos,Age
# assessment WISC,EID
# NDARAC331VEH                        2019                  14.167351
# NDARAC462DZH                        2019                   7.957449
# NDARAF440XWG                        2019                   7.253593
# NDARAF535XK6                        2019                  13.121492
# NDARAG115LZP                        2018                  14.167351
# ...                                  ...                        ...
# NDARRL426AD5                        2018                  11.234998
# NDARTT272WT5                        2019                  12.537759
# NDARVB842ZM8                        2019                  11.243326
# NDARWM848AKP                        2018                  15.032511
# NDARYB392JWP                        2018                  12.521332
#
# [438 rows x 52 columns]

# %%
subjects_with_labels = subjects_with_labels.loc[
    subjects_with_labels['assessment WISC,WISC_complete'] == '1']
print("Number of subjects with WISC labels:", len(subjects_with_labels))
# Out:
# Number of subjects with WISC labels: 425

# %%
n, bins, patches = plt.hist(x=subjects_with_labels['assessment WISC,WISC_FSIQ'].astype(int),
                            bins=range(40, 160, 5))

# %%
n, bins, patches = plt.hist(x=subjects_with_labels['assessment Basic_Demos,Age'].astype(float))

# %%
csv_output_path = "/imaging3/owenlab/bpho/Biobank Labels/Subjects with WISC.csv"
subjects_with_labels.to_csv(csv_output_path)
