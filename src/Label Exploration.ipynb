# %% [markdown]
# # Label Exploration

# %% [markdown]
# ## Count the number of subjects with labels

# %%
import csv
from os import listdir
from os.path import exists

import pandas as pd
import matplotlib.pyplot as plt

# %%
# label_file_path = r"/imaging3/owenlab/bpho/Biobank Labels/BehavData.csv"
label_file_path = r"/imaging3/owenlab/bpho/Biobank Labels/data-2020-07-21T15_31_07.904Z.csv"

# %%
label_subject_ids = set()

with open(label_file_path) as csvfile:
    reader = csv.DictReader(csvfile)
    label_subject_ids = label_subject_ids.union(
        {row['assessment WISC,EID'] for row in reader})

# print(label_subject_ids)
print("Number of labels:", len(label_subject_ids))
# Out:
# Number of labels: 2279

# %%
data_subject_ids = set()

for age in range(5, 19):
    age_dir = f'/imaging3/owenlab/bpho/python_power_fc/Age{age}'
    
    if not exists(age_dir):
        continue
    
    data_subject_ids = data_subject_ids.union(
        {folder[4:] for folder in listdir(age_dir) if folder.startswith("sub-")})

    
print("Number of subjects:", len(data_subject_ids))
# Out:
# Number of subjects: 722

# %%
subjects_with_labels = label_subject_ids.intersection(data_subject_ids)
# print(subjects_with_labels)
print("Number of subjects with labels:", len(subjects_with_labels))
# Out:
# Number of subjects with labels: 438

# %% [markdown]
# ## Pandas Section (Write Labels to CSV)

# %%
subjects = pd.DataFrame(data_subject_ids, columns=['assessment WISC,EID'], dtype='str')
labels = pd.read_csv(label_file_path, dtype='str')
labels = labels.filter(like="WISC")

display(subjects)
display(labels)
# Out:
#     assessment WISC,EID
# 0          NDARFX508WPN
# 1          NDARXL697DA6
# 2          NDARDW711NYZ
# 3          NDARJG494YDY
# 4          NDARDA656RBN
# ..                  ...
# 717        NDARXU376FDN
# 718        NDARUP132ADW
# 719        NDARBV167RMU
# 720        NDARCA050RZL
# 721        NDARKC220LZG
#
# [722 rows x 1 columns]
#      assessment WISC,Administration assessment WISC,Comment_ID  \
# 0                               All                        NaN
# 1                               All                        NaN
# 2                                 .                          .
# 3                               All                        NaN
# 4                               All                        NaN
# ...                             ...                        ...
# 4186                              .                          .
# 4187                              .                          .
# 4188                              .                          .
# 4189                              .                          .
# 4190                              .                          .
#
#      assessment WISC,Data_entry assessment WISC,Days_Baseline  \
# 0                      Complete                           NaN
# 1                      Complete                            15
# 2                             .                             .
# 3                      Complete                            70
# 4                      Complete                             5
# ...                         ...                           ...
# 4186                          .                             .
# 4187                          .                             .
# 4188                          .                             .
# 4189                          .                             .
# 4190                          .                             .
#
#      assessment WISC,EID assessment WISC,PSCID assessment WISC,START_DATE  \
# 0                    NaN                   NaN                        NaN
# 1           NDARAA075AMK                   NaN       1901-01-01T07:00:00Z
# 2                      .                     .                          .
# 3           NDARAA117NEJ                   NaN       1901-01-01T07:00:00Z
# 4           NDARAA504CRN                   NaN       1901-01-01T07:00:00Z
# ...                  ...                   ...                        ...
# 4186                   .                     .                          .
# 4187                   .                     .                          .
# 4188                   .                     .                          .
# 4189                   .                     .                          .
# 4190                   .                     .                          .
#
#      assessment WISC,Season assessment WISC,Site assessment WISC,Study  ...  \
# 0                       NaN                  NaN                   NaN  ...
# 1                    Summer                    2                   HBN  ...
# 2                         .                    .                     .  ...
# 3                    Winter                    1                   HBN  ...
# 4                    Spring                    3                   HBN  ...
# ...                     ...                  ...                   ...  ...
# 4186                      .                    .                     .  ...
# 4187                      .                    .                     .  ...
# 4188                      .                    .                     .  ...
# 4189                      .                    .                     .  ...
# 4190                      .                    .                     .  ...
#
#      assessment WISC,WISC_VSI_Percentile assessment WISC,WISC_VSI_Sum  \
# 0                                    NaN                          NaN
# 1                                     93                           28
# 2                                      .                            .
# 3                                     14                           14
# 4                                     55                           21
# ...                                  ...                          ...
# 4186                                   .                            .
# 4187                                   .                            .
# 4188                                   .                            .
# 4189                                   .                            .
# 4190                                   .                            .
#
#      assessment WISC,WISC_Vocab_Raw assessment WISC,WISC_Vocab_Scaled  \
# 0                               NaN                               NaN
# 1                                32                                18
# 2                                 .                                 .
# 3                                18                                11
# 4                                21                                 9
# ...                             ...                               ...
# 4186                              .                                 .
# 4187                              .                                 .
# 4188                              .                                 .
# 4189                              .                                 .
# 4190                              .                                 .
#
#      assessment WISC,WISC_WMI assessment WISC,WISC_WMI_Percentile  \
# 0                         NaN                                 NaN
# 1                         155                                99.9
# 2                           .                                   .
# 3                          85                                  16
# 4                          97                                  42
# ...                       ...                                 ...
# 4186                        .                                   .
# 4187                        .                                   .
# 4188                        .                                   .
# 4189                        .                                   .
# 4190                        .                                   .
#
#      assessment WISC,WISC_WMI_Sum assessment WISC,WISC_complete  \
# 0                             NaN                           NaN
# 1                              38                             1
# 2                               .                             .
# 3                              15                             1
# 4                              19                             1
# ...                           ...                           ...
# 4186                            .                             .
# 4187                            .                             .
# 4188                            .                             .
# 4189                            .                             .
# 4190                            .                             .
#
#      assessment WISC,WISC_incomplete_reason assessment WISC,Year
# 0                                       NaN                  NaN
# 1                                       NaN                 2016
# 2                                         .                    .
# 3                                       NaN                 2017
# 4                                       NaN                 2019
# ...                                     ...                  ...
# 4186                                      .                    .
# 4187                                      .                    .
# 4188                                      .                    .
# 4189                                      .                    .
# 4190                                      .                    .
#
# [4191 rows x 52 columns]

# %%
subjects_with_labels = labels.merge(subjects, on='assessment WISC,EID')
subjects_with_labels.set_index(keys='assessment WISC,EID', inplace=True)
display(subjects_with_labels)
# Out:
#     assessment WISC,Administration assessment WISC,Comment_ID  \
# 0                              All                        NaN
# 1                              All                        NaN
# 2                              All                        NaN
# 3                              All                        NaN
# 4                              All                        NaN
# ..                             ...                        ...
# 433                            All                        NaN
# 434                            All                        NaN
# 435                            All                        NaN
# 436                            All                        NaN
# 437                            All                        NaN
#
#     assessment WISC,Data_entry assessment WISC,Days_Baseline  \
# 0                     Complete                             2
# 1                     Complete                            74
# 2                     Complete                           104
# 3                     Complete                            77
# 4                     Complete                           135
# ..                         ...                           ...
# 433                   Complete                           119
# 434                   Complete                           385
# 435                   Complete                           307
# 436                   Complete                           175
# 437                   Complete                           128
#
#     assessment WISC,EID assessment WISC,PSCID assessment WISC,START_DATE  \
# 0          NDARAC331VEH                   NaN       1901-01-01T07:00:00Z
# 1          NDARAC462DZH                   NaN       1901-01-01T07:00:00Z
# 2          NDARAF440XWG                   NaN       1901-01-01T07:00:00Z
# 3          NDARAF535XK6                   NaN       1901-01-01T07:00:00Z
# 4          NDARAG115LZP                   NaN       1901-01-01T07:00:00Z
# ..                  ...                   ...                        ...
# 433        NDARRL426AD5                   NaN       1901-01-01T07:00:00Z
# 434        NDARTT272WT5                   NaN       1901-01-01T07:00:00Z
# 435        NDARVB842ZM8                   NaN       1901-01-01T07:00:00Z
# 436        NDARWM848AKP                   NaN       1901-01-01T07:00:00Z
# 437        NDARYB392JWP                   NaN       1901-01-01T07:00:00Z
#
#     assessment WISC,Season assessment WISC,Site assessment WISC,Study  ...  \
# 0                   Spring                    3                   HBN  ...
# 1                   Spring                    1                   HBN  ...
# 2                   Spring                    3                   HBN  ...
# 3                   Spring                    3                   HBN  ...
# 4                   Spring                    3                   HBN  ...
# ..                     ...                  ...                   ...  ...
# 433                   Fall                    1                   HBN  ...
# 434                 Summer                    1                   HBN  ...
# 435                 Summer                    1                   HBN  ...
# 436                 Spring                    3                   HBN  ...
# 437                 Winter                    1                   HBN  ...
#
#     assessment WISC,WISC_VSI_Percentile assessment WISC,WISC_VSI_Sum  \
# 0                                    97                           30
# 1                                     2                            9
# 2                                    90                           27
# 3                                    10                           13
# 4                                    96                           29
# ..                                  ...                          ...
# 433                                  10                           13
# 434                                  55                           21
# 435                                   7                           12
# 436                                   3                           10
# 437                                 NaN                          NaN
#
#     assessment WISC,WISC_Vocab_Raw assessment WISC,WISC_Vocab_Scaled  \
# 0                               40                                13
# 1                               18                                10
# 2                               15                                 9
# 3                               18                                 4
# 4                               32                                 9
# ..                             ...                               ...
# 433                             25                                 9
# 434                             34                                11
# 435                             26                                 9
# 436                             37                                11
# 437                            NaN                               NaN
#
#     assessment WISC,WISC_WMI assessment WISC,WISC_WMI_Percentile  \
# 0                        110                                  75
# 1                         76                                   5
# 2                        110                                  75
# 3                         97                                  42
# 4                         91                                  27
# ..                       ...                                 ...
# 433                       91                                  27
# 434                      100                                  50
# 435                      117                                  87
# 436                       74                                   4
# 437                      NaN                                 NaN
#
#     assessment WISC,WISC_WMI_Sum assessment WISC,WISC_complete  \
# 0                             23                             1
# 1                             12                             1
# 2                             23                             1
# 3                             19                             1
# 4                             17                             1
# ..                           ...                           ...
# 433                           17                             1
# 434                           20                             1
# 435                           26                             1
# 436                           11                             1
# 437                          NaN                             0
#
#     assessment WISC,WISC_incomplete_reason assessment WISC,Year
# 0                                      NaN                 2019
# 1                                      NaN                 2019
# 2                                      NaN                 2019
# 3                                      NaN                 2019
# 4                                      NaN                 2018
# ..                                     ...                  ...
# 433                                    NaN                 2018
# 434                                    NaN                 2019
# 435                                    NaN                 2019
# 436                                    NaN                 2018
# 437                            Dropped HBN                 2018
#
# [438 rows x 52 columns]

# %%
subjects_with_labels = subjects_with_labels.loc[
    subjects_with_labels['assessment WISC,WISC_complete'] == '1']
print("Number of subjects with WISC labels:", len(subjects_with_labels))
# Out:
# 425

# %%
n, bins, patches = plt.hist(x=subjects_with_labels['assessment WISC,WISC_FSIQ'].astype(int),
                            bins=range(40, 160, 5))

# %%
csv_output_path = "/imaging3/owenlab/bpho/Biobank Labels/Subjects with WISC.csv"
subjects_with_labels.to_csv(csv_output_path)
